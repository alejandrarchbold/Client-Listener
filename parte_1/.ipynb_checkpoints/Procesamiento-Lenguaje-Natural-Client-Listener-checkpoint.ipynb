# %% [markdown]
# # Detecting cybercrimes using similarity models

# %% [markdown]
# ## OS

# %%
import os # The OS module in Python provides a way of using operating system dependent functionality
import pandas as pd # Read data from file

# %%
 # Reads and shows files in entered location
os.chdir("C:/Users/Alejandra/Desktop/NLP-Model-for-prevention-of-Cybercrimes/Project/")

# %% [markdown]
# ## Data

# %%
data = pd.read_excel("Bancolombia.xlsx",sheet_name="Archive") # Importing the database (tweets)

# %%
data.head() # Returns the first rows of the database
# Out:
#                 id_str       from_user  \
# 0  1316907621371314176   Mimi_UVasquez
# 1  1316906522295869445       fredysend
# 2  1316905865040068609  LuchoCandanoza
# 3  1316902640786300930   Mimi_UVasquez
# 4  1316854660121219073     betoacevedo
#
#                                                 text  \
# 0  @Bancolombia El ya radicó la queja, lo que hag...
# 1  @Bancolombia Ya no pudieron eso es de hace muc...
# 2                       @Bancolombia @jose_caicedo10
# 3  @Bancolombia varios amigos me reportan que la ...
# 4  RT @CAMT_1_4: @Bancolombia @OracleLatam  encon...
#
#                        created_at                time  geo_coordinates  \
# 0  Fri Oct 16 01:03:38 +0000 2020 2020-10-16 02:03:38              NaN
# 1  Fri Oct 16 00:59:16 +0000 2020 2020-10-16 01:59:16              NaN
# 2  Fri Oct 16 00:56:39 +0000 2020 2020-10-16 01:56:39              NaN
# 3  Fri Oct 16 00:43:51 +0000 2020 2020-10-16 01:43:51              NaN
# 4  Thu Oct 15 21:33:11 +0000 2020 2020-10-15 22:33:11              NaN
#
#    user_lang  in_reply_to_user_id_str in_reply_to_screen_name  \
# 0        NaN               48014813.0             Bancolombia
# 1        NaN               48014813.0             Bancolombia
# 2        NaN               48014813.0             Bancolombia
# 3        NaN               48014813.0             Bancolombia
# 4        NaN                      NaN                     NaN
#
#    from_user_id_str  in_reply_to_status_id_str  \
# 0         330669613               1.316907e+18
# 1         517679766               1.316900e+18
# 2         109031390               1.316008e+18
# 3         330669613                        NaN
# 4          70786127                        NaN
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/android" ...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                    profile_image_url  user_followers_count  \
# 0  http://pbs.twimg.com/profile_images/1299536154...                3906.0
# 1  http://pbs.twimg.com/profile_images/8776703045...                  23.0
# 2  http://pbs.twimg.com/profile_images/1280200494...                 116.0
# 3  http://pbs.twimg.com/profile_images/1299536154...                3906.0
# 4  http://pbs.twimg.com/profile_images/6193437655...                 120.0
#
#    user_friends_count user_location  \
# 0              1104.0     Ravenclaw
# 1               131.0           NaN
# 2               539.0           NaN
# 3              1104.0     Ravenclaw
# 4               188.0        Bogota
#
#                                           status_url  \
# 0  http://twitter.com/Mimi_UVasquez/statuses/1316...
# 1  http://twitter.com/fredysend/statuses/13169065...
# 2  http://twitter.com/LuchoCandanoza/statuses/131...
# 3  http://twitter.com/Mimi_UVasquez/statuses/1316...
# 4  http://twitter.com/betoacevedo/statuses/131685...
#
#                                         entities_str
# 0  {"hashtags":[],"symbols":[],"user_mentions":[{...
# 1  {"hashtags":[],"symbols":[],"user_mentions":[{...
# 2  {"hashtags":[],"symbols":[],"user_mentions":[{...
# 3  {"hashtags":[],"symbols":[],"user_mentions":[{...
# 4  {"hashtags":[],"symbols":[],"user_mentions":[{...

# %%
# converting to list the column "text" where it contains the tweets
cols = ['from_user', 'text']
text = data[cols].values.tolist()

# %%
print(text) # printing the tweets
# Out:
# [['Mimi_UVasquez', '@Bancolombia El ya radicó la queja, lo que hago es avisar a mis amigos de redes que su app es super insegura'], ['fredysend', '@Bancolombia Ya no pudieron eso es de hace mucho tiempo ,toco llevarnos la cuenta empresa para otro banco.muy regulares en todos los aspectos'], ['LuchoCandanoza', '@Bancolombia @jose_caicedo10'], ['Mimi_UVasquez', '@Bancolombia varios amigos me reportan que la actualización de la app es muy insegura. Ayer a un amigo le robaron un iPhone y seguido de eso le robaron dinero de su cuenta bancaria por transferencia desde la app. Pilas con eso'], ['betoacevedo', 'RT @CAMT_1_4: @Bancolombia @OracleLatam  encontré con sorpresa la implementación de una dmp dentro del portal transaccional de personas quisiera conocer las políticas de manejo de datos digitales y que información nombrada con exactitud está guardando la dmp y para que la están utilizando https://t.co/kWAZClLZ9o'], ['midasmckalister', '@Bancolombia Señores @Bancolombia llevan dañados los cajeros automáticos de La Calera 8 días co de sus noches, pésimo servicio, cambien esas máquinas obsoletas'], ['redactor24', '@Bancolombia: paren ya su ACOSO. Ya les dije que no me interesa su cupo de crédito. ¿Cómo más hay que decirlo para que dejen de bombardearme con su publicidad telefónica y de mensajería?'], ['todoparati23', '@Bancolombia Por que mi tarjeta débito no tiene cvv ?'], ['Bancolombia', 'Creemos más que nunca en su fortaleza y queremos acompañarlas a conseguir un mejor futuro. Por eso creamos la línea de crédito Agro para Todas, una oportunidad para que puedan alcanzar sus sueños y tener un mayor bienestar.'], ['JehanAliC', '@Bancolombia y su mundo digital: Para facilitar su trámite imprima el documento, llene a mano, ponga su huella (quien tiene huellero en su casa!!!), después escaneé...\nLes falta poner “Por último radique en el banco” 🤣\nSÚPER digital 👏👍 #FelizJueves'], ['caritoalegria91', '@Bancolombia  La app de ustedes la mayoría del tiempo está fallando. Mala cosa!!!'], ['zerrrrrrep', '@Bancolombia Malo el servicio en el banco físico y ni hablar del soporte por este medio. Ahí estoy esperando soporte hace horas.…!'], ['midasmckalister', '@Bancolombia Ustedes el mismo cuento de siempre, escriba por DM, lo concreto y lea todos los Twittear, es que los tres cajeros que hay en La Calera, llevan una semana sin funcionar'], ['fredysend', '@Bancolombia es triste que cada quincena sea lo mismo con uds esa sucursal virtual caída estamos mamaos de eso ,'], ['CAMT_1_4', '@Bancolombia @OracleLatam  encontré con sorpresa la implementación de una dmp dentro del portal transaccional de personas quisiera conocer las políticas de manejo de datos digitales y que información nombrada con exactitud está guardando la dmp y para que la están utilizando https://t.co/kWAZClLZ9o'], ['mauriciorodas00', '@Bancolombia #BamcolombiaMeAcosa ya ajusto 20 llamadas en un solo día, que fastidio de banco!'], ['jorgehestradag', '@Bancolombia Pero entonces no es en este momento... ha sido en varios momentos ya que el mismo error tanto desde sucursal personas o empresas, lo he tenido en más de una oportunidad.. @ACH_Informa'], ['cegatron89', '@Bancolombia Le han estado cobrando el 4x1000 a mi madre desde que abrió la cuenta en diciembre, y no se ha llegado a ese tope. ¿Lo hacen con todas las cuentas para pensión? A padres de otros amigos le han realizado lo mismo. @SFCsupervisor'], ['Daniieel1983', '@Bancolombia Claro que si Tatiana 😉'], ['davidescobar73', '@Bancolombia precisamente día de pago de nómina y la sucursal virtual empresas caída.'], ['Briam_Gutierrez', '@Bancolombia yo le llamaria falsa publicidad, porque no estan dando este tipo de credito. @sicsuper @TalCualOficial https://t.co/WyPUUWcv2o'], ['AndresZ85755720', '@Bancolombia A qué horas se cae la app de Bancolombia ?'], ['Fg535', '@Bancolombia pueden hacer una bendita aplicación que no se muera cada quincena??'], ['Solano', '@Bancolombia @Divagando_ando @AskPayPal @PayPal @Davivienda Gracias, An ...

# %%
text[0][0] # accessing to the first tweet from the list 'text'
# Out:
# 'Mimi_UVasquez'

# %%
len(text) # number of tweets
# Out:
# 783

# %%
tweets = [text[i][1] for i in range(len(text))]
tweets
len(tweets) # length of tweets
# Out:
# 783

# %%
users = [text[i][0] for i in range(len(text))]
users
len(users) # length of users
# Out:
# 783

# %% [markdown]
# ## Data Preparation
#
# - ## Functions to remove URL links, @mention, #hashtags

# %%
import string # String contains methods that allow the use of characters which are considered punctuation characters, 
                # digits, uppercase, lowercase, etc.
import re # Regular expression operations

# %%
def strip_links(text): # function to remove/strip URL links
    link_regular_expression = re.compile('((https?):((//)|(\\\\))+([\w\d:#@%/;$()~_?\+-=\\\.&](#!)?)*)', re.DOTALL)
    links = re.findall(link_regular_expression, text)
    for link in links:
        text = text.replace(link[0], ', ')   
    return text

# %%
def strip_all_entities(text): # function to remove/strip mentions, hashtags, characters from some users
    entity_prefixes = ['@','#','\\','_']
    for separator in  string.punctuation:
        if separator not in entity_prefixes :
            text = text.replace(separator,' ')
    words = []
    for word in text.split():
        word = word.strip()
        if word:
            if word[0] not in entity_prefixes:
                words.append(word)
    return ' '.join(words)

# %% [markdown]
# source: https://stackoverflow.com/questions/8376691/how-to-remove-hashtag-user-link-of-a-tweet-using-regular-expression

# %%
def strip_all(list_text): # function that removes all URL links, @mention, #hashtags
    list_stripped = []
    for t in list_text:
        word = strip_all_entities(strip_links(t))
        list_stripped.append(word)
    return(list_stripped)

# %%
tweets = strip_all([text[i][1] for i in range(len(text))])
text = [[users[i],tweets[i]] for i in range(len(users))]
text
# Out:
# [['Mimi_UVasquez',
#   'El ya radicó la queja lo que hago es avisar a mis amigos de redes que su app es super insegura'],
#  ['fredysend',
#   'Ya no pudieron eso es de hace mucho tiempo toco llevarnos la cuenta empresa para otro banco muy regulares en todos los aspectos'],
#  ['LuchoCandanoza', ''],
#  ['Mimi_UVasquez',
#   'varios amigos me reportan que la actualización de la app es muy insegura Ayer a un amigo le robaron un iPhone y seguido de eso le robaron dinero de su cuenta bancaria por transferencia desde la app Pilas con eso'],
#  ['betoacevedo',
#   'RT encontré con sorpresa la implementación de una dmp dentro del portal transaccional de personas quisiera conocer las políticas de manejo de datos digitales y que información nombrada con exactitud está guardando la dmp y para que la están utilizando'],
#  ['midasmckalister',
#   'Señores llevan dañados los cajeros automáticos de La Calera 8 días co de sus noches pésimo servicio cambien esas máquinas obsoletas'],
#  ['redactor24',
#   'paren ya su ACOSO Ya les dije que no me interesa su cupo de crédito ¿Cómo más hay que decirlo para que dejen de bombardearme con su publicidad telefónica y de mensajería'],
#  ['todoparati23', 'Por que mi tarjeta débito no tiene cvv'],
#  ['Bancolombia',
#   'Creemos más que nunca en su fortaleza y queremos acompañarlas a conseguir un mejor futuro Por eso creamos la línea de crédito Agro para Todas una oportunidad para que puedan alcanzar sus sueños y tener un mayor bienestar'],
#  ['JehanAliC',
#   'y su mundo digital Para facilitar su trámite imprima el documento llene a mano ponga su huella quien tiene huellero en su casa después escaneé Les falta poner “Por último radique en el banco” 🤣 SÚPER digital 👏👍'],
#  ['caritoalegria91',
#   'La app de ustedes la mayoría del tiempo está fallando Mala cosa'],
#  ['zerrrrrrep',
#   'Malo el servicio en el banco físico y ni hablar del soporte por este medio Ahí estoy esperando soporte hace horas …'],
#  ['midasmckalister',
#   'Ustedes el mismo cuento de siempre escriba por DM lo concreto y lea todos los Twittear es que los tres cajeros que hay en La Calera llevan una semana sin funcionar'],
#  ['fredysend',
#   'es triste que cada quincena sea lo mismo con uds esa sucursal virtual caída estamos mamaos de eso'],
#  ['CAMT_1_4',
#   'encontré con sorpresa la implementación de una dmp dentro del portal transaccional de personas quisiera conocer las políticas de manejo de datos digitales y que información nombrada con exactitud está guardando la dmp y para que la están utilizando'],
#  ['mauriciorodas00',
#   'ya ajusto 20 llamadas en un solo día que fastidio de banco'],
#  ['jorgehestradag',
#   'Pero entonces no es en este momento ha sido en varios momentos ya que el mismo error tanto desde sucursal personas o empresas lo he tenido en más de una oportunidad'],
#  ['cegatron89',
#   'Le han estado cobrando el 4x1000 a mi madre desde que abrió la cuenta en diciembre y no se ha llegado a ese tope ¿Lo hacen con todas las cuentas para pensión A padres de otros amigos le han realizado lo mismo'],
#  ['Daniieel1983', 'Claro que si Tatiana 😉'],
#  ['davidescobar73',
#   'precisamente día de pago de nómina y la sucursal virtual empresas caída'],
#  ['Briam_Gutierrez',
#   'yo le llamaria falsa publicidad porque no estan dando este tipo de credito'],
#  ['AndresZ85755720', 'A qué horas se cae la app de Bancolombia'],
#  ['Fg535',
#   'pueden hacer una bendita aplicación que no se muera cada quincena'],
#  ['Solano', 'Gracias Angie ya respondí por DM'],
#  ['linajarabo',
#   'Cómo es posible que pague el total de mi crédito hipotecario hace más de 1 mes y ahora resultan cobrando sin saber qué es y nadie responde'],
#  ['edyjo_',
#   'Gracias Estefa eres muy amable Sin embargo el tiempo se ha extendido más de la cuenta cuando la solución debió ser más oportuna Temo que el Banco me informes que mi dinero se perdió y me toque emprender un proceso judicial'],
#  ['edyjo_',
#   'Muchas Gracias por comunicarte conmigo Estefa pero tu respuesta no satisface mis pretensiones Es posible que me informes las causas o motivos de la demora en resolver mi caso'],
#  ['MotoRatona_',
#   'Gracias aunque ni siquiera tengo productos con ustedes y eso lo hace aún más gracioso 😂'],
#  ['Sebastian_G14',
#   'buenas tardes me podrían brindar asesoría realicé un pago de mi tarjeta de crédito Mastercard que tengo con ustedes en el banco pero la pague desde la app de otro banco el pago salió y me confirmó pero la tarjeta en la App personas me aparece la deuda aún'],
#  ['MotoRatona_',
#   'Claramente ya bloqueé la cuenta que envía esos mensajes me causa gracia que ni siquiera se esfuerzan en cambiar el dominio del remitente y dejan Banco Falabella 🤣🤣🤦\u200d♀️'],
#  ['davidmtnz27',
#   'ellos cajeros fallan y se quedan con la plata los aplicativos de consulta en el call Center no funcionan de la personal cero actitud de servicio Disculpen srs que les sirve'],
#  ['Eduardo34501436',
#   'Buenas tardes bancolombia Yo cobro por modalidad de giro con ustedes y hace 1 mes abrí una cuenta de ahorro a la mano en este pago que se aproxima ya me empezan a pagar x cuenta o me van a trasladar a supergiros Gracias'],
#  ['Aliceresponde',
#   'por favor me confirma si el tiene el absurdo cobro por retirar de cajero en otras ciudades por favor explicar ese atropello cómo validar los topes de estas injustificadas y desmotivantes políticas de la banca en colombia'],
#  ['YAG_C', 'Que ya la tengo inscrita'],
#  ['aldairvelasque1', 'Yo te escribí por Dm'],
#  ['dianymarr', 'No me solicitaron pago mínimo'],
#  ['aiztferonitro',
#   'DeisyB si alguna vez te hace una marranada financiera recuerda muy bien este tw es un sentimiento de impotencia solo espero hacer lo posible para pagar y nunca mas volver a verlos la gente sabe que como banco no tienen nada que perder que nadie les pague'],
#  ['aldairvelasque1', 'Reexpedición'],
#  ['rodolfo20961215',
#   'buenas tardes me gustaría saber el horario de atención de la sucursal en zipaquira Gracias'],
#  ['MshadowsMCR',
#   'No amiguitos Esas excusas ya no valen Ustedes reflejaron las porquerias que son con los colombianos No les importo que muchos estuvieran endeudados Otros pasando necesidades pero vaya uno no pague lo que ustedes dicen y verá Asco de banco'],
#  ['TuConsonante', 'Si lo lamentan pero no hacen nada para solucionar 🙄'],
#  ['YAG_C',
#   'Ya estoy inscrito estoy tratando de hacer un pago pero la clave dinámica no llega o llega media hora después cuando ya no sirve'],
#  ['super_chata',
#   'Buenas Tardes Ya les respondí por DM toda la información q solicitan para q de manera INMEDIATA me devuelvan mi dinero información que Ustedes deben tener pero por su INEFICIENCIA y para ganar tiempo se les hace más fácil que EL CLIENTE se las suministre'],
#  ['Adriana88541440', 'Ajaaaaaaaaaaaajaaaaa'],
#  ['AnnieLaBanani',
#   'Me ayudan Tengo que activar una cuenta que abrí por medios digitales y no he podido'],
#  ['dianymarr', 'Respondí por DM'],
#  ['Luret_',
#   'Un crédito de libre inversión interpuse un DP con uno de sus asesores telefónicos después de que alguien de redes sociales me llamará y no pueden encontrar el requerimiento sin el número de radicado en pleno siglo XXI que empresa no puedo encontrar un radicado con otros datos'],
#  ['Felipextilla',
#   'la gerente dice que es el protocolo de bioseguridad le pregunto donde esta exhibido y dice lo tengo en el computador'],
#  ['Felipextilla',
#   'bancolombia sucursal parway media hora para que la gerente salga brava a atender y decir que nonabre la puerta no dejan entrar al banco'],
#  ['Luret_',
#   'Es el 4to mes en donde estoy pagando los intereses de un periodo de gracia de 3 meses que no pedí hasta cuándo voy a pagar esos intereses'],
#  ['dianymarr', 'Ya le escribí por DM Espero su pronta respuesta'],
#  ['ElcoyoteLpez', 'reyes del pésimo servicio Cambian para empeorar'],
#  ['YAG_C', 'hay problemas con clave dinamica'],
#  ['GustavierPB',
#   'Buenos días una pregunta ¿Que es el Débito sucursal Bancolombia Y ¿Cuánto e el monto máximo a descontar Gracias'],
#  ['johanagt88', 'No funciona esa clave dinámica'],
#  ['VGLARA2', 'que fea mala lenta En 15na Bancolombia muere'],
#  ['mauriciorodas00',
#   'cuando me acerco a sus oficinas a buscar una alternativa y me dicen que ya no hay turnos que llame que llame a los que me dicen que lo único que tengo que hacer es pagar qué fastidio de banco'],
#  ['mauriciorodas00',
#   'cuando llaman y me piden una cantidad de datos que cada llamada les tengo que suministrar para que la única información que dan es que o pago o me reportan qué fastidio de banco'],
#  ['betobaena27',
#   'Quincena o fin de mes la plataforma caída Que raro no 😆😆😆😆😆'],
#  ['mauriciorodas00',
#   'cuando solo llaman y dice que si no pago me reportan como si en esta situación eso fuera realmente preocupante antes que otras prioridades qué fastidio de banco'],
#  ['Juli_abad89', 'Alivio para ustedes será'],
#  ['ElBienhumorado',
#   'Bla bla bla llevamos 5 veces hablando con el banco y no dan solución Es un descaro'],
#  ['_danielmqz_', 'se llama Camila'],
#  ['_danielmqz_',
#   'RT Asuman su responsabilidad y dejen de robarle a la gente No sean descarados'],
#  ['YamitGarcia1', 'Perdón que es DM'],
#  ['isa_garrido1', 'Ya les escribí por DM'],
#  ['mauriciorodas00',
#   'con hasta 20 llamadas diarias de cobro y siempre se les dice lo mismo qué fastidio de banco'],
#  ['NestorLlanoSal1', 'vergüenza de banco ladrones con permiso para robar'],
#  ['isa_garrido1',
#   'necesito comunicarme vía telefónica con un asesor y no atienden las llamadas 😩😩 que rabia el caos de'],
#  ['TavoAcevedo',
#   'Me dieron hoy una respuesta por cierto carente de información para un evento que terminó ayer Mejor dicho de nada sirvieron los canales de comunicación con ustedes'],
#  ['froyuc', ''],
#  ['ilegi2',
#   'RT Que van a revisar si ya descontaron el dinero 🤷🏻\u200d♀️ acaso lo piensan devolver 🤷🏻\u200d♀️'],
#  ['ilegi2',
#   'RT No se preocupe me tomé el trabajo de ir hasta una oficina y ni soluciones ni respuestas claras cuando les pregunté por qué nunca me explicaron desde el principio el escenario real de la situación ustedes son un karma para el usario'],
#  ['Tico92588258',
#   'mala mala mala esa App siempre arroja error hasta para hacer el pago de un producto'],
#  ['froyuc',
#   'que es lo que pasa com esa APP no sirve para nada ¿como novedad hoy tambien esta caída'],
#  ['ManuelEsp30',
#   'lo he dicho el banco más ladrón de Colombia junto a los del nadie los controla roban a pueblo multiplican el dinero que usaron para comprar la presidencia y mantener el poder de hacer lo que quieran sin control'],
#  ['fabianacuna1',
#   'Escribí hace rato y ahí me quedé igual que en las llamadas que ineptitud la cacha del culo estos pingos'],
#  ['OSCARACALDEROND',
#   'Esto lo he realizado por DM en varias ocasiones y ha todos les explico y luego me dejan disque esperando respuesta del area encargada y así ha pasado casi 3 meses quiero que me contacte un asesor por vía telefónica'],
#  ['mauriciorodas00',
#   'indolentes y alejados de la realidad mundial acosan y lastiman la salud mental de sus clientes que fastidio de banco'],
#  ['MariadelCCB',
#   'Siempre me mandan al DM para no darme ninguna respuesta exacta y correcta me habían dicho una cosa y hoy que llamo a preguntar por el radicado me dicen otra no se quién es más ratero si o'],
#  ['mauriciorodas00',
#   'deberles a ustedes es peor que matar un cura que karma que fastidio'],
#  ['mauriciorodas00',
#   'que desespero tener una mora con ustedes 15 llamadas al día para decir que pague Respeten'],
#  ['fabianacuna1',
#   'Yo llevo 9 llamadas a ese dizque centro de ayuda para cancelar una puta tarjeta de crédito que ni la tengo porque me cancelaron el plástico y no lo mandaron pero igual cobran la cuota de manejo después preguntan porque uno apoya los vándalos'],
#  ['ZulyMoz', 'Para qué si no hay respuesta'],
#  ['MOISDI',
#   'Es que cualquiera puede estrar a mi cuenta un día cualquiera y cogerme lo que les de la gana quien me dice a mi que no fueron ustedes ustedes se lavan las manos Que seguridad le están brindando a uno uno no es adivino para saber que era 7n fraude En la semana m'],
#  ['OSCARACALDEROND',
#   'pido la respuesta formal a mi reclamo de reintegro de hace 2 meses y me envía un email con una respuesta de otro reclamo de hace 3 meses Negligencia o burla'],
#  ['OSCARACALDEROND',
#   'estoy intentando que me envíen un email con la respuesta adjunta de un reclamo de hace 2 meses y mandan el email vacío es una burla o es negligencia del asesor Pero igual no logro tener solución a mi reclamo'],
#  ['OSCARACALDEROND',
#   '3 llamadas a la línea de atención al cliente pero el asesor me deja esperando hasta que se corta la llamada y se pierde todo lo adelantado y lo peor es que los asesores no tienen el mínimo detalle para devolver la llamada y dar solución al problema del cliente'],
#  ['FitoHndz95',
#   'En el barrio San Luis también pasa lo mismo de los dos cajeros sólo está funcionando uno Frente al supermercado la canasta campesina'],
#  ['JoaoelJugador',
#   'Perdone Gustavo la palabra pero mas pendejo usted que no siguió pagando normalmente el tal alívio nunca existió porque simplemente debía seguir acumulando intereses sobre toda el capital desde el inicio cuando lo escuché me pareció la estupidez mas grande'],
#  ['aiztferonitro',
#   'me van a devolver es una pendejada escribir al interno no solucionan nada solo les preocupa la mala publicidad no van a solucionar nada'],
#  ['_art_hur__', 'cómo sería'],
#  ['Galaxy_Waltz', 'Necesito ayuda por favor DM'],
#  ['MarianaSolano3',
#   'increíble que presten un servicio tan malo no son capaces de solucionar un problema que es de ellos ni siquiera respetan el tiempo de los clientes más de 15 llamadas para que me solucionen y nada😡😡 el peor servicio en banca lo tiene'],
#  ['felipeszarruk',
#   'Como puedo cancelar la cuenta sin ir al banco A través de la Web'],
#  ['MOISDI',
#   'Ya puse las quejas y ya me respondieron que no me podían responder que había sido víctima de un estafador pero quede muy triste Que garantías y seguridad le brindan a uno sus cuentas'],
#  ['AHxb', 'Son un chiste 😂'],
#  ['NoSoyJuanPa',
#   'tiene una publicidad que dice Esa app se convertiría en el empleado del mes 😑 Olvidaron que detrás de una App hay personas que programan piensan y trasnochan🚀 Si una App es buena las personas son los las empleados del mes ❤️'],
#  ['Osyegaoc', 'Hola ya el inconveniente fue solucionado'],
#  ['CamiloAlvarezB', 'le está poniendo el alma'],
#  ['JulianCatanoC',
#   'No se preocupe me tomé el trabajo de ir hasta una oficina y ni soluciones ni respuestas claras cuando les pregunté por qué nunca me explicaron desde el principio el escenario real de la situación ustedes son un karma para el usario'],
#  ['isislopez_1983',
#   'responda que uds le van quitando el dinero a la gente por cada movimiento con su propia plata'],
#  ['MrTangeles',
#   'Como asi que solo responden por el 50 de la plata si el error fue 100 de ustedes'],
#  ['super_chata',
#   'Hicieron cargo a mi cuenta por una compra en Amazon la cual no fue procesada pero Bancolombia me debitó el monto y no me lo ha devuelto en los teléfonos que dice debo llamar nadie se digna atender les agradezco procedan a devolver mi dinero de manera INMEDIATA'],
#  ['jabernalv',
#   '¿ya resolvieron esta situación La respuesta debe ser asumir ustedes'],
#  ['oqs216',
#   'son campeones con el dinero de sus usuarios algo parecido sucede cuando los cajeros automáticos no entregan el dinero el usuario debe de esperar un día hábil para devolver el dinero Pero cuando es el cliente que se demora un día ellos te cobran intereses'],
#  ['derianpt',
#   'llevo pidiendo días un extracto del mes de enero y siempre me envían el de febrero y marzo sean serios Lo necesito urgente'],
#  ['FitoHndz95',
#   'Cúcuta Norte de Santander y en el municipio de Bochalema el ubicado Parque Central Quedo atento a su respuesta'],
#  ['Camilo_S08', 'Me están pidiendo datos de mi sitio de trabajo'],
#  ['jumacoac', 'Les sobra una R en el correo'],
#  ['oliver_cepeda1',
#   'Yo tengo un préstamo con sofi y no tengo empleo y siempre que me llaman me ofrecen ciertos alivios que realmente lo que me ofrecen es extender las cuotas con doble interés vivasos por cierto ya me tienen aburrido cada 3 días llamando'],
#  ['NANITOSHKA',
#   'alivios Me hicieron préstamo 20mll en marzo comenzó la pandemia me dieron el alivio ahora ya van en 3 millones de intereses y me llaman xa financiar toda la deuda Disque no me cobran un mes y los intereses por las nubes Pido envíen estracto de intereses y nada'],
#  ['TrvlGrtAgn',
#   'bank in the world just like is the worst airline in the world How do these companies that provide shit service stay in business Well it wont be much longer for avianca and maybe will be soon after service'],
#  ['TrvlGrtAgn',
#   'operates the worst bank in the world Nothing ever changes with this crap bank Today in Victoria in Pereira we waited over 2 hrs in line with hundreds of people and even though they accepted us on the line for hours the bank closed and they said no more people Shit'],
#  ['FMejsal', 'Ratas'],
#  ['elkarmahallegad',
#   'Bancolombia roban por todos lados por tarjetas extranjeras cobran por transacción hasta 18 mil eso es un descaro ahora todas las arandelas que hacen para ir sacando dinero de cada cuenta Un robo totál'],
#  ['Ruvemcho',
#   'y Flypass cerrarán negociaciones con nuevos parqueaderos en Bogotá y Medellín 🚗🚙 que aceptarán este medio de pago sin contacto ⚡⚡ Actualmente los estacionamientos de Oviedo y el Aeropark 🌳🌳 tienen el servicio disponible'],
#  ['Ruvemcho',
#   'movilizará 140 000 millones de dólares en servicios financieros en los próximos 10 años El anuncio se dio en el encuentro de la Alianza Global de Inversores para el Desarrollo Sostenible de la ONU Lee aquí cómo se orientarán estos recursos 👇 …'],
#  ['fidelantoniomr',
#   'Muy alegres Ante la desgracia ajena que ustedes empeoran se les recomienda no ser tan festivos y más nuevos buscar soluciones en las que honren la confianza y la buena fe de quienes ponemos nuestro dinero en sus manos al menos para no lucir como cínicos'],
#  ['W4rr10rRo0t',
#   'Lo paso por un Sandbox y luego trato de notificarlo a pero como sus plataformas nunca sirven pues dejo así'],
#  ['camiloaafanador',
#   'RT Para qué le van a devolver la plata Díganlo enseguida o le va a repetir la misma información que ya le dieron y ya sabe'],
#  ['Bancolombia',
#   'Esto lo puedes realizar en la configuración de tu dispositivo móvil Saludos'],
#  ['MariaTeresaVaBa',
#   'No tienen en cuenta la posible reactivacion economica no todos son empleados del estado 😡😡😡😡'],
#  ['JohanQC777',
#   'Coloca la actividad económica 0090 de rentista de capital ya que no hay una que indique que es sostenida por sus padres Mentiras lee bien los ciiu previamente a tramitar el RUT sino quieres es mas fácil aperturar Nequi pero si te recomiendo luego migrar a un banco'],
#  ['pcerheguma',
#   'NUNCA fueron claros en las líneas telefónicas decían una cosa y por correo decían otra Ante tanta incoherencia e información tan poco clara lo mejor era si se podía cancelar cualquier deuda'],
#  ['ChicleBoyacense',
#   'RT Para qué le van a devolver la plata Díganlo enseguida o le va a repetir la misma información que ya le dieron y ya sabe'],
#  ['handrs9010',
#   'De esta dirección me llegan bastantes correos informacion@mailgrupobancolombia com co'],
#  ['landito1', 'Jajajajajajaja'],
#  ['billytontony',
#   'Ahhhh bueno fue solo un problema de falta de claridad de información La próxima vez sean mas claros a la hora de desplumar a la gente'],
#  ['roberlucena', 'Devuelvan el dinero'],
#  ['frankiko63',
#   'RT Para qué le van a devolver la plata Díganlo enseguida o le va a repetir la misma información que ya le dieron y ya sabe'],
#  ['AndresArboled_a',
#   'Eso es lo único que hace Bancolombia quitar el dinero cobrar mal dar mala información y ahora todos los usuarios están quedados menos mal están demostrando como son tendencia por mal Banco y como están llegando competencias fuertes para tumbarlos No mas Bancolombia'],
#  ['DanielSicAm',
#   'RT cuantos FAVS y condonan en su totalidad una deuda con ustedes'],
#  ['Mamertoid', 'Hijueputas'],
#  ['Jojuanna', 'Mil gracias'],
#  ['Dcaguirre97A',
#   'el sitio es de ustedes Si sí muy extraño que requiera un login por fuera del sitio de sucursal virtual personas Si no están enviando correos que tienen mala pinta'],
#  ['SergioLB12',
#   'Es tendencia solocitar a empresas o personas determinada cantidad de me gusta likes favs para obtener algo a cambio Dicho esto ¿cuantos me gusta likes favs para condonar una deuda que tengo con ustedes'],
#  ['JPABLORODRIL',
#   'RT Para qué le van a devolver la plata Díganlo enseguida o le va a repetir la misma información que ya le dieron y ya sabe'],
#  ['dozurpe',
#   'Yo tenia que abrir otra ventana de mi celular para ver la dinámica'],
#  ['TavoP_G', 'No sean ratas'],
#  ['DCaroCarambola',
#   'lo abro les mento la madre a los ladrones les pregunto por acá a ustedes cuál es el correo para informar lo del pishing ya luego lo reenvío y lo elimino'],
#  ['xmariana02', 'Pero yo no trabajo mis papás me mantienen todavía jajj'],
#  ['himmelklavier',
#   'RT Para qué le van a devolver la plata Díganlo enseguida o le va a repetir la misma información que ya le dieron y ya sabe'],
#  ['rolo_del',
#   'RT Para qué le van a devolver la plata Díganlo enseguida o le va a repetir la misma información que ya le dieron y ya sabe'],
#  ['PalmSolangel',
#   'Esa manía de ustedes de querer obligarlo a uno a inscribir las facturas para pagar a través de la sucursal virtual Ahora la famosa clave dinámica desde la app no sirve No sé por qué inventan tanto😞'],
#  ['ElHombreDeLasR',
#   'Depende si es un enlace porno le echo un ojito primero de rapidez y ahí sí lo borro 🤭🤭🤭'],
#  ['ATurmewhat', 'en pocas palabras RATAS 🐁'],
#  ['xmariana02',
#   'Les pregunté por acá si necesitaba el RUT para crear la cuenta y me dijeron que me tenía que acercar a una sucursal física para que allá me dijeran si era necesario o no'],
#  ['IsabelMTaborda', 'No me ha querido servir en todo el día 🙄🤦🏻\u200d♀️'],
#  ['fidelacorrea',
#   'que falta de honestidad del Banco y de la persona que recibió el dinero por error Que 😱😱😱😠😠😠'],
#  ['lajana9090',
#   'Pura mierda congelaron el cobro de los créditos Pero los intereses crecían como si el cliente hubiera dejado de pagar porque sí Troncos de rateros a mí me quitaron 500 mil y punta de interés'],
#  ['Bancolombia',
#   'La mejor forma de protegerte del phishing es identificar si es una estafa para hacerlo reenvíalo a corrreosospechoso@bancolombia com co Estos son 3 elementos que podrás encontrar en este tipo de correos ʘ˧'],
#  ['fidelacorrea', 'demasiado cínismo 😱😱😱'],
#  ['JAIRMETALS',
#   'Son unas ratas mejor busquen otro banco como Colpatria o otros estos hp cobran 12 000 de cuota de manejo y sin importar la pandemia ratas hp'],
#  ['maupovi75', 'RT RATAS HIJUEPUTAS ABUSANDO DE LA GENTE'],
#  ['maupovi75', 'RATAS HIJUEPUTAS ABUSANDO DE LA GENTE'],
#  ['nancho85',
#   'buenas tardes mi esposa y yo tenemos cuentas de ahorro de bancolombia y manejamos un solo celular yo ya tengo registrado la clave dinámica con mi cuenta se puede registrar también la cuenta de mi esposa con el mismo celular No tenemos más celular que hacemos'],
#  ['JJoseTrujillo',
#   'responde por eso tal vez el cajero y su gerente para no ponerse en evidencia ante Medellin tratan de resolverlo ellos pero la central del banco responde por todo seguro Obvio hay perjuicios pero el capital no se pierde duerma tranquila'],
#  ['SergioLB12',
#   'cuantos FAVS y condonan en su totalidad una deuda con ustedes'],
#  ['ginac0723',
#   'le ha bloqueado la cuenta 2 veces a mi mamá no la deja hacer transferencias pagos o lo que sea pero sí reciben la plata que le envían a ella y fue a solucionarlo le cambiaron la tarjeta y al otro día la misma mierda a qué juegan'],
#  ['MayoVGil',
#   'Les contacte primero por los canales internos y es muy molesta la respuesta de sus asesores toman decisiones unilaterales siempre sin pensar en las personas'],
#  ['ncojack_JP',
#   'Buen dia a mi me han llegado correos parecidos diciendo que digite mi documento para saber el extracto'],
#  ['romnyd', 'Seguro me invente la falla'],
#  ['jpradach1', 'No Carolina nada qué hacer'],
#  ['romnyd',
#   'otra vez su plataforma de pse fallando Como si no fuera importante tener el soporte de pago'],
#  ['QueMamera_',
#   'Daniel el inconveniente te lo estoy mostrando en la imagen Saludos'],
#  ['edyjo_',
#   'Ya me he comunicado con anterioridad y en múltiples ocasiones por DM por email por línea telefónica y no pasa nada Si de verdad quiere deme indicaciones de la queja y'],
#  ['frajobehi',
#   'Un iPhone 12 pro plus Max XT por favor con la cuota de 9 900 gracias'],
#  ['Bancolombia',
#   '1 Si el asunto es urgente el destinatario no concuerda y te piden descargar archivos elimínalo \u200b 2 Si parece ser del Banco y te pide clave usuario y número de la tarjeta reenvíalo a correosospechoso@bancolombia com\u200b ʘ˧'],
#  ['alexagat',
#   'Hola cada que marcó al 5109000 me aparece Davivienda y no tengo ese número guardado con nombre de Davivienda'],
#  ['MRCHIKIP',
#   'No Loren por privado lo vacilan a uno y se hace lo que uds quieran y como uds quieran es mi dinero y deberian sostener las garantias que me ofrecieron al momento de adquirir el producto Prefiero cancelar mis productos con uds y presionar la empresa para me pague con otro banco'],
#  ['fcoramna', 'Estaremos observando cualquier cosa gritas'],
#  ['MRCHIKIP',
#   'de repente y sin autorizacion cambian mi plan de cuenta como les da la gana cobrando extra y me lo tengo que tragar Si toca que la empresa me pague la nomina en cheque o en monedas pues lo acepto pero esa cuenta se cancela'],
#  ['sehuanes_felipe', 'Muchas gracias por la información'],
#  ['Camo__Oficial',
#   'Y me siguen llamando del 304 550 3348 no quedo claro ayer que no quiero recibir mas este tipo de llamadas no me interesa por que vendieron mis datos'],
#  ['faja9498',
#   'ni lo recomendaría a bancolombia ni lo recomiendo fue el banco que se aprovechó de la necesidad de sus clientes en la pandemia para hacer de la suya'],
#  ['TavoAcevedo', 'Ok ya escribí por interno'],
#  ['gorofox', 'Buenas tardes hay inconvenientes con la APP'],
#  ['Osyegaoc', 'ojalá lo implementarán'],
#  ['TavoAcevedo',
#   'A ver si por aquí responden ¿De cuánto es el descuento ¿Cómo se accede a él'],
#  ['ValeriaMendezC',
#   'qué está pasando con la seguridad de información de los usuarios Ya conozco 3 casos incluyendo el mío sobre el bloqueo de la cuenta porque alguien intentó meterse desde la sucursal virtual Por favor expliquen lo que está sucediendo'],
#  ['jonyleonp',
#   'Buenas tardes muchas gracias en la actualidad tengo dos crediagil y dos créditos tasa fija estoy sin trabajo desde el pasado mes de abril y quiero postularme al congelamiento de la deuda hasta dic es posible ante la incapacidad de pago'],
#  ['mariselacasalla', 'No he podido enviar el mensaje DM'],
#  ['mariselacasalla',
#   'el peor servicio de Bancolombia solo atienden por línea telefónica y dicen que espere su llamada y llevo 5 meses esperando que me llamen'],
#  ['luiskgomezc',
#   'Que servicio tan malo de sus cajeros electrónicos La mayoría de las veces que voy no sirven ¿Entonces para qué están Lo que hace le hace a uno perder el tiempo 😡'],
#  ['AndreaSndoValle', 'Hola ya respondí por Dm espero pronta solución gracias'],
#  ['OliverS66063224', 'Eso me llego hoy'],
#  ['RichiRojasL',
#   'Estoy esperando su respuesta por DM Nuevamente me acabaron de llamar a preguntar por alguien que no soy yo'],
#  ['LizPater17',
#   'Asuman su responsabilidad y dejen de robarle a la gente No sean descarados'],
#  ['Jojuanna', 'quisiera saber si esta información es verdadera gracias'],
#  ['jpradach1', 'Pues ya estoy en DM'],
#  ['Alejoeplugg',
#   'Hola muy buenas tardes Santi Me sale un error que me debo inscribirme a la clave dinámica pero lo raro fue que hace unas horas antes había hecho una transferencia y yo ya he llamado y he hecho el procedimiento para la clave dinámica me genera el problema muy seguido'],
#  ['jramirezc1984', 'esto es cierto O es algo anormal'],
#  ['MateoPaV', 'me llega este mensaje es verdad o es una estafa'],
#  ['FitoHndz95',
#   'El cajero del parque central del municipio de Bochalema también presenta problemas y es el único que hay'],
#  ['FitoHndz95',
#   'Es por el bien de todos que hago esa queja es muy molesto que siempre se vea la aglomeración de personas en los cajeros Bancolombia y además se presta para que los amigos de lo ajeno hagan de las suyas Faltan protocolos de bioseguridad por lo menos un antibacterial en los CC'],
#  ['Enero20b',
#   'Para qué le van a devolver la plata Díganlo enseguida o le va a repetir la misma información que ya le dieron y ya sabe'],
#  ['Lalupa33376573',
#   'El numero del celular que envío el mensaje es 316 334 66 30 para que tengan en cuenta y pongan en reporte esta modalidad de fraude gracias'],
#  ['FitoHndz95', 'Cúcuta Norte de Santander'],
#  ['Lalupa33376573',
#   'Hola buenos días en la mañana de hoy recibí un mensaje que dice así FELICITACIONES HOY MOVISTAR Y BANCOLOMBIA TE FELICITAN POR SER EL GANADOR DE 10 000 000 COMUNICATE YA PBX 301248090 CDG 750 AUT COLJUEGOS Y ESTE ES EL NUMERO DONDE ME ENVIARON EL MENSAJE A MI'],
#  ['Misslegsonfire', 'Ya pude solucionar gracias Los tkm'],
#  ['EvanyPonce', 'que servicio de porquería'],
#  ['claramejiacar',
#   'cómo sería para desbloquear mi IP y poder entrar a la sucursal desde mi wifi'],
#  ['DayanaJ86812013',
#   'Buenos días sucede que aparezco en bancolombia beneficiada de ingreso solidario y no me han cancelado ningún giro'],
#  ['jonyleonp',
#   'apreciados señores tengo varios créditos con ustedes libreinv y crediágil y desde el mes de abril estoy sin trabajo podrían indicarme que debo hacer en este caso para acogerme al periodo de gracia hasta diciembre de acuerdo a la última circular de la s financiera'],
#  ['FitoHndz95',
#   'Por la pandemia y mi labor no puedo estarme movilizando hasta allá a verificar esos códigos además tengo entendido que para eso tienen personal técnico Me parece el colmo del descaro Seriedad por favor'],
#  ['FitoHndz95',
#   'CC Unicentro sólo sirve 1 o 2 CC Jardín plaza 1 de 4 CC Ventura plaza solo sirve 1 barrio San Luis solo sirve 1 Av libertadores más abajo del CAI Niza 1 de 4 Av Cero al lado de Mkgusto solo sirven 2 y en el parque central de Bochalema el único que hay dañado'],
#  ['oscar_concha', '🙌🙌🙌👍👍🇨🇴🇨🇴🇨🇴'],
#  ['sarita_abad', 'Nos van asesorar sobre sus utilidades en la pandemia'],
#  ['oscar_concha',
#   'Acabo de hacer un pago a por un dispositivo nunca usado y la clave dinámica en el celular funcionó perfectamente Sencilla y Segura'],
#  ['alejand65379810',
#   'Estan respondiendo vainas locas que no concuerdan ni con la fecha de compra no saben donde estan parados 😡'],
#  ['Camiburgosp', 'LOS ODIO'],
#  ['alejand65379810',
#   'Privado para que Para que no se den cuenta lo ratas que son ustedes'],
#  ['PiliCorreaZ',
#   'llevo tres días intentando realizar una transferencia y me indican que me comunique a la línea luego llamo a la línea y me informan que hay un incidente pero no dan información de qué se trata ni para cuando hay una solución Para cuándo se soluciona el incidente'],
#  ['sabanerita1', 'Ya les escribo'],
#  ['alejand65379810',
#   'Señores tengo casi dos meses esperando un reembolso de dinero y aun nada Se piensan robar la plata'],
#  ['Klovn', 'phishing llegó a mi correo'],
#  ['juanfelipemc25',
#   'cómo así que debemos migrar la clave dinámica a la app personas desde el 20 de octubre Cómo hacen las personas que no tienen teléfonos inteligentes y todo lo haces es a través del PC Me toca comprarle un celular a mi abuela para eso o uds se lo regalaran'],
#  ['Luzmari03586318', '3125080487'],
#  ['Jennyg7',
#   'Entiendo esto pero no me importaría tener un rechazo y generar nuevamente el pago como en otras entidades bancarias es absurdo tener que esperar 3 días para hacer un pago urgente'],
#  ['Jennyg7',
#   'Gracias pero ayer llame al banco y ya me aclararon la información y me dijeron que se demora hasta tres días la inscripción de una cuenta a otro banco y pues nada me toca salir hoy a retirar y desplazarme hasta el otro banco para hacer la consignación que ayuda en la pandemia'],
#  ['Jennyg7',
#   'A mi me parece terrible que inscribir una cuenta de otro banco se demore hasta 3 días y más cuando uno la necesita hacer urgente este es único banco que me encuentro que hace esto y realmente es molesto'],
#  ['sarita_abad',
#   'Que van a revisar si ya descontaron el dinero 🤷🏻\u200d♀️ acaso lo piensan devolver 🤷🏻\u200d♀️'],
#  ['Jennyg7',
#   'Ayer al mediodía inscribí una cuenta para hacer un transferencia urgente y esta es la hora que la cuenta no ha quedado inscrita me parece el colmo que me digan que se puede demorar hasta tres días respeten que la necesito hacer urgente Soy nueva en bancolombia y no me gusta'],
#  ['Jennyg7',
#   'Ayer al mediodía inscribí una cuenta para hacer un transferencia urgente y esta es la hora que la cuenta no ha quedado inscrita me parece el colmo que me digan que se puede demorar hasta tres días respeten que la necesito hacer urgente Soy nueva en bancolombia y no me gusta'],
#  ['JaimeACastro5',
#   'Banco llamé el viernes a cancelar una tarjeta de credito virtual Me dijeron que la cancelación se vería reflejada en 1 día hábil Hoy miercoles sigo viendo activa esa tarjeta Necesito cancelarla antes de que me cobre manejo Colaborenme por favor'],
#  ['linajarabo',
#   '1 mes sin solucionar lo del pago total a mi crédito hipotecario quieren más Plata Quieren robar más'],
#  ['linajarabo',
#   'llevo más de 1 mes sin solucionar mi pago de crédito hipotecario que más quiere robar'],
#  ['nfrancovel',
#   'Quiere decir que van a dejar a lod adultos mayores sin posibilidad de que les ayudemos a hacer sus pagos Ya pensaron en ese segmento de clientes Son clientes que no usan la app ni la van a usar Uds los están obligando a salir a un banco y nos quitan la posibilidad de ayudarlos'],
#  ['edmartinezm',
#   'tu atención al cliente es horrible y tu app es lenta e inoperante como proceso burocrático'],
#  ['FitoHndz95',
#   'Espero que con ese mismo fervor y patriotismo se encarguen de arreglar los cajeros en Cúcuta en todos los CC y en general muy pocos sirven y se aglomera la gente por su culpa Sean serios y respeten los usuarios'],
#  ['wrusinque',
#   'Vamos Tigre gracias Bancolonbia por ser patrocinador de la selec'],
#  ['AidaDia34410791',
#   'Al consultarme me sale esto no entiendo porque dicen que ustedes no me pagan si mis primeros 4 giros los cobre con ustedes'],
#  ['Marivelezo1', 'Falcao te mereces otro hijo'],
#  ['mariale714',
#   'Esperanza la que yo tengo de que no empiecen a cobrar las transferencias a otros bancos para robar más plata'],
#  ['tefaniaa26',
#   'Vieron ese gol Jajaja eso merece que no le cobren tasa nominal en el mes de octubre 💯✌️🇨🇴'],
#  ['Marivelezo1', 'Grande Falcao Tigre de tigres'],
#  ['CataUribeLopez', '4'],
#  ['daniarenas', 'Me gané mi primera polla 💛💛💙❤️'],
#  ['EdwinGutierrezT',
#   'Ustedes procuren mejorar la aplicación que bien lenta si está'],
#  ['AlejitaLopezC', '6'],
#  ['saraduquelpz', '6 ☝🏼☝🏼'],
#  ['ClienteBanistmo', '5 💪🏻'],
#  ['dokhrates', 'Ladrones'],
#  ['MonsalveAcevedo', '2 👆🙏🏼❤️'],
#  ['laurajp7', '5 💪'],
#  ['CuervoMan_',
#   'Obviamente no están teniendo en cuenta a estos 10 millones de Hijueputas Que grandes'],
#  ['PadresEHijos9',
#   'Arreglen esa porquería de App en vez de estar twiteando maricadas'],
#  ['Marivelezo1', '5 Vamos por el empate'],
#  ['Richienator', '1'],
#  ['CuervoMan_',
#   'RT en su comercial dice que vuelven a latir 40 millones de corazones y los otros 10 millones 🥺'],
#  ['Cris_Quintero', '1 🙌'],
#  ['DanielaMacias01', '1 a echarle cabeza mijos🤔🤔'],
#  ['__sebastian_o_d', '1 Cabeza fría'],
#  ['phelipeRz', 'no es cierto'],
#  ['lopezsalexander', '7'],
#  ['cloiinunez', 'Y esto que es De nuevo app Bancolombia caida'],
#  ['cloiinunez', 'Otra vez caida la app de Bancolombia'],
#  ['AHxb', 'RT Ladrones'],
#  ['phelipeRz',
#   'hoy se anotó dos golazos en mí cuenta debitandome sin mí permiso 200 000'],
#  ['dokhrates', 'Ladrones'],
#  ['OscarTrejos9',
#   'Promocionando fútbol mientras las personas que tienen su dinero en tienen que hacer enormes filas en Cartago bajo el inclemente sol soportando por horas temperaturas superiores a los 30° Pésimo y nefasto servicio'],
#  ['dokhrates', 'Ladrones'],
#  ['phelipeRz',
#   'me acaba de debitar 200 000 sin justificación alguna y no me dan razón en la línea telefónica ¿ahora sus formas de ganar utilidades es literalmente robándole al ciudadano'],
#  ['nanita821117',
#   'Dudas No tengo pereza de usarla pero pues toca porque uds no escuchan a los usuarios Hay algo fundamental en el diseño de cualquier cosa y es la USABILIDAD Parece que los diseñadores de su app desconocen el término'],
#  ['paoz08', 'Solucionado gracias'],
#  ['lfsantanam', 'me están llegando estos mensajes al correo'],
#  ['Eyarce',
#   'y Flypass cerrarán negociaciones con nuevos parqueaderos en Bogotá y Medellín 🚗🚙 que aceptarán este medio de pago sin contacto ⚡⚡ Actualmente los estacionamientos de Oviedo y el Aeropark 🌳🌳 tienen el servicio disponible'],
#  ['OlaveLigia',
#   'porque no me dan la opción de descargar certificado de crédito hipotecario lo requiero para declarar renta ya que no lo reportan en la rete fuente que me enviaron solicite por teléfono el documento dijeron que tardaba 6 horas aún no llega'],
#  ['bermzzy', 'me ha quitado más plata de la que saco'],
#  ['PilarAmayaJ', 'otra vez falla en la app No me deja trasferir'],
#  ['Nata1992m',
#   'todas sus campañas de alivio son una mentira si de la sucursal telefónica nos envían al punto físico no saben dar explicaciones es mentira sus alivios y hacen que los productos entren en Mora para cobrar intereses'],
#  ['NestorTuran',
#   'Ah claro Me imagino que a él nunca se le ocurrió comunicarse con el banco'],
#  ['scastril',
#   'el banco que dice colocarle el alma a los colombianos más bien le está partiendo la madre a los colombianos'],
#  ['rubielagomez',
#   'O me solucionan la@situación o me encargaré de llevar esto hasta las últimas consecuencias mi hija viaja y la única tarjeta que tiene es con Bancolombia y es un deber de axa expedirme el certificado de asistencia'],
#  ['rubielagomez',
#   'Que el el DM otras 5 horas colgada al teléfono por qué sume que se que quiere decir ese término'],
#  ['rubielagomez',
#   'inaudito que una entidad tan prestigiosa como la de ustedes jueguen con el cliente de la forma como lo hacen llevo tres días solicitando certificado de viaje internacional y me ponen al teléfono 60 minutos y cuelgan la llamada es una obligación y lo exijo'],
#  ['Marcelalopezoc1',
#   'como es posible que he solicitado la cancelación de una tarjeta de crédito 3 veces con bancolombia y siempre me dan vueltas y me sacan peros y no finalizan el proceso esto es un atropello al consumidor'],
#  ['stvanss',
#   'cuanto hay que reclamar para que una persona le cancelen una tarjeta de crédito que ya no desea que tomadera de pelo es increíble'],
#  ['pmendez3',
#   'Debo expresar públicamente que ante el problema manifestado y a pesar de estar en el exterior el Equipo Bancolombia me a contactado y me ha brindado un servicio de atención rápido y excelente quedo muy agradecido Y espero muy pronto una resolución satisfactoria del caso'],
#  ['ArgenisJessSal1',
#   'Me realizaron un giro desde Canadá el día 01 del mes en curso A la fecha no se registra en mi cuenta Debo ir a una oficina para retirar o puedo hacerlo consignar en mi cuenta por medios electrónicos'],
#  ['RichiRojasL',
#   'Les dejé mis datos de contacto por DM Espero que esta vez sí pregunten por mí'],
#  ['paoz08',
#   'que pasa con la aplicación que no aparece la clave dinámica y uno con afán de pagar sus obligaciones'],
#  ['GigiMendozaN', 'Les envíe el DM hace 10 mins'],
#  ['GigiMendozaN', 'Sucursal Virtual WEB y Móvil Por ningún lado funciona'],
#  ['RichiRojasL',
#   'Daniel es tu compañero Yo soy Ricardo He hablado durante un mes con personal de las áreas de servicio al cliente y conciliación y no tienen una solución Quiero conocer los procedimientos de'],
#  ['malanarodriguez', 'porque no me deja ingresar con mi huella 🤯🤯🤯'],
#  ['GigiMendozaN', 'Enviado'],
#  ['MDCristian_mont',
#   'puedo saber por que me dejan esperando en linea mas de 1 hora esta es la segunda llamada q hago y me dejan en linea por q no puedo cancelar esa tarjeta de crédito del demonio ni tiempo también merece respeto'],
#  ['RichiRojasL',
#   'Daniel ya lo he hecho y no me dan solución Me dicen que esta persona debe actualizar sus datos Él ya lo hizo pero ustedes no retiran mi número del sistema Ya he hablado con el área de servicio al cliente y tampoco tienen una solución Por eso le escribí a'],
#  ['Junior16748139', 'Bobo aquel que caiga en sus trampas'],
#  ['amtribin',
#   'Pues aún estoy esperando que me atiendan llamo a la línea de atención al cliente escribo al dm y NADA absolutamente nada me han ayudado'],
#  ['Danielleml',
#   'me agenda citas para que sus agentes me llamen y me cuelguen 😂 a ver si me contestan'],
#  ['pmendez3',
#   'que sea por el correo por la app ha sido mi peor experiencia pense que iba a ser mas facil Y resulta que meto la clave que aparece y nunca es valida ya estoy estresado con esa situacion no puedo movilizar mi dinero'],
#  ['amtribin',
#   'Yo llevo todo el día tratando de que me informen porqué me están cobrando 500 mil pesos por el congelamiento de mi crédito hipotecario y nadie me sabe explicar absolutamente nada esa es la ayuda que le dan a los colombianos'],
#  ['midasmckalister', 'Cambien esas máquinas eso ya tecnología vieja'],
#  ['midasmckalister',
#   'Ustedes tienen esa información ahorita me desplazo los 10 kilometros desde donde vivo que desgracia perder el tiempo con ustedes'],
#  ['Camo__Oficial',
#   'Entonces porque me llaman a vender seguros de parte de una entidad relacionada con banclombia yo no les di permiso para eso'],
#  ['Hey__Carlitos',
#   'Mary ya escribí Espero pueda obtener una respuesta por este medio'],
#  ['Camo__Oficial',
#   'que hace con mis datos personales ¿Por qué los venden a empresas que venden seguros quien regula esto la Que inseguridad quien más tendrá mis datos'],
#  ['magils',
#   '¿Es legal que me pida más datos personales como mi número de cédula para dejar de llamarme cuando no tengo ni tendré NINGUN PRODUCTO con ellos'],
#  ['AbrahamDReyes', '¿Donde puedo llamar'],
#  ['AbrahamDReyes',
#   'Lo sentimos usted no está autorizado para marcar este número 🤷🏾'],
#  ['magils', 'Ya les envié la información Espero que no me llamen más Cc'],
#  ['PachoChaverra', 'Scar una tarjeta'],
#  ['magils',
#   'La única validación que tienen que hacer es eliminar mi número telefónico de su sistema'],
#  ['midasmckalister',
#   'Señores es hora de cambien los cajeros de La Calera por tecnología nueva las que están son maquinas obsoletas'],
#  ['Luzmari03586318',
#   'Quiero saber si me enviaran mensaje de texto para cobrar mis giros por nequi freddy lizarazo'],
#  ['albahgarcia',
#   'lo que uds hacen con los adultos mayores es irresponsable El viernes tuvieron a mi papá adulto mayor 2 horas Para abrir una cuenta de ahorros y desbloquear otra cuenta Hoy le volvieron a bloquear sus cuentas La solución ir nuevamente al banco'],
#  ['MariaVGonzalezM',
#   'Hasta cuando los abusos Incumplen promesas y acuerdos te hacen pagar corriendo a “su tiempo” y nunca cumplen lo que se supone me “otorgaron” desde julio'],
#  ['midasmckalister',
#   'Señores ustedes son lo peor como institución fuera la primera vez esto ocurre cada 8 dias'],
#  ['misspark8',
#   'La nueva aplicación es un problema no una ayuda para los clientes'],
#  ['agudelo_m',
#   'Son sus políticas institucionales y las entiendo pero no las comparto me parece una falta de empatía que en semejante contingencia uno tenga que ir a ponerse en riesgo a una sucursal porque ustedes no aceptan abonos a capital por ningún otro medio'],
#  ['Silvanadiaz98', 'Hola Tati ya se arregló jejeje besitos'],
#  ['OdioLasSopas',
#   'llamo desde su página me tienen 20 minutos como una estúpida cuando por fin me atiende el que se supone me resuelve dice cliente no responde y yo a el lo escucho perfecto LOS ODIO COMO LE VAN A BAJAR EL RENDIMIENTO A UNA INVERSION PORQUE SÍ'],
#  ['GabyEscalante5',
#   'el servicio de atención al cliente por teléfono es tan nefasto que marca una alguna de las opciones y lo que hacen es cancelar la llamada'],
#  ['lauragornzalez', 'Me pasa lo mismo'],
#  ['Andresc_h',
#   'Queremos que la app funcione bien y sin tanto error Ya viene la quincena'],
#  ['shaka38', 'Quieres saber de bugs en producción 🤣 🤣 🤣'],
#  ['DianaOr50911680',
#   'Seguridad Bancolombia no brinda eso más de 15 días para devolverme 150 mil pesos que descontaron abusivamente de mi cuenta'],
#  ['ricardo18226532',
#   'no obliguen a la gente a abrir una cuenta para reclamar giros sucursales Pereira si a alguien lo estan obligando ante quien puede poner la queja para q sancione el banco q gracias y a los lectores no usen giros bancolombia'],
#  ['alemon008',
#   'Quisieras conocer buen servicio al cliente Yo te puedo ayudar'],
#  ['Bancolombia',
#   'Recuerda que ya no tienes que llamar a la línea telefónica para resolver tus dudas sobre la nueva App Personas aquí te ayudamos a responder a todas tus preguntas ʘ˩'],
#  ['Bancolombia',
#   'Respuesta \u200b cualquier transacción que hagas desde App Personas se validará automáticamente ya no hace falta esperar a que te notifiquen para usarla ʘ˩'],
#  ['Bancolombia',
#   '¿Si haces un pago desde App Personas deberás esperar a recibirla por correo o mensaje de texto \u200b ʘ˩'],
#  ['Bancolombia',
#   'Respuesta ¡Es muy fácil Entra desde tu celular a App Personas y en el home podrás ver los 6 dígitos sin necesidad de ingresar tu usuario o clave ʘ˩'],
#  ['Bancolombia',
#   'Si estás realizando un pago desde otro canal y te pide la clave dinámica ¿cómo puedes consultarla ʘ˩'],
#  ['Santo90R',
#   'Qué hay una entrada específica y es por fuera del centro comercial'],
#  ['MarcoJara_7',
#   'Si señores también ando en el DM esperando a que me hablen pero tampoco'],
#  ['MarcoJara_7', 'Señores ya les hable por DM Pero no hay respuesta'],
#  ['Santo90R',
#   'Ya estoy realizando la transacción pero uds no pueden imponer más barreras especialmente para las personas de la tercera edad'],
#  ['MarcoJara_7',
#   'Señores dejen de burlarse de los usuarios Ya me he comunicado con su DM pero no resuelven nada Se quedan callados Pareciera que el interés de ustedes es desviar la discusión que pone en evidencia lo mala empresa que son'],
#  ['Santo90R',
#   'Centro Comercial Santa Fe en la ciudad de Bogotá El guarda también impide el ingreso a los acompañantes de las personas de la tercera edad Es el colmo'],
#  ['Check3891',
#   'He tenido muchos y no me interesa si cambian o no me da embarrada la gente que tiene cuenta en ese banco gracias Luis'],
#  ['mrugeles',
#   'Resolví mover mi cuenta de nómina a otro banco no tiene sentido tener una cuenta de ahorro en un banco y creditos en otro En Bancolombia siempre ha sido un problema el tema de solicitar créditos se demoran mucho o no responden'],
#  ['garrincha25', 'alguna falla en la app que no deja transferir dinero'],
#  ['Richardortegar1',
#   'Estamos llamando desde la semana pasada a la sucursal telefónica y ninguna opción es validad'],
#  ['Richardortegar1',
#   'Mi esposa está intentando ingresar a la app pero no recuerda la clave'],
#  ['Richardortegar1', 'Por favor se pueden comunicar con mi esposa 3046121174'],
#  ['Richardortegar1', 'Necesitamos cambiar la clave personal'],
#  ['Claudiagelvez16', 'buenos días cuando dice dm que página es'],
#  ['inruc', 'quién castiga a los que se dedican al'],
#  ['inruc', 'consejo número un NO ahorre en Bancolombia'],
#  ['Juanguis3', 'Bancolombia lavándose las manos como siempre'],
#  ['OdioLasSopas',
#   'su chat no sirve para nada Pido asesor y finalizan el chat'],
#  ['JohanOquendo3',
#   'Esta llegando este correo lo reporte en Correosospechoso@bancolombia com co Y es una estafa no lo abran no den ningún dato inmediatamente lo reportan y lo eliminan'],
#  ['Sergi0_Sanchez', 'correosospechoso@bancolombia Sin com co o loquesea'],
#  ['midasmckalister', 'Ahí están en las fotos'],
#  ['Bryangels',
#   'Hola Kevyn Pude llamar a la línea de fraudes antes de hacer cualquier otra cosa y ellos me indicaron el proceso a seguir Pude darme cuenta del fraude De igual forma te comparto el correo que me llegó'],
#  ['DIARIO_DJK',
# ...
#  ['VladimirDavilaT',
#   'Ya me comuniqué y dijeron que los intereses corrían si o si pero el documento firmado habla de congelar las cuotas y correr los créditos el tiempo no cobrado'],
#  ['nipeed',
#   'cerraron una sucursal en Yopal por que no se le estaba amontonando los clientes estamos en tiempo de distanciamiento social'],
#  ['jhonmartinez', 'Si'],
#  ['Catacorreagomez',
#   'como es posible que estoy haciendo un reclamo y el asesor me cuelgue cuando empiezo a nombrarle mis derechos'],
#  ['John_Rockdrgz',
#   'solo con un reclamo y le van a dar gerencia ah no así si me le quejo al que sea'],
#  ['angelaville03', 'se volvieron enemigos'],
#  ['lapopularmusic',
#   'Inconforme Decepción tristeza D ver una corporación de ladrones ladrones profesionales como el país lleno de corrupción'],
#  ['lapopularmusic', 'Cual proceso Uds no respetan ni a su madre'],
#  ['EriSawPer',
#   'andan mandando estos correos como si fueran ustedes Hay manera de denunciar esas cuentas'],
#  ['lapopularmusic', 'delincuentes'],
#  ['VladimirDavilaT',
#   'mentirosos dijeron que congelarian las cuotas 3 meses créditos personales y 6 micros hoy están cobrando intereses de esos meses dicen que son atrasados sin abono al capital para quedar bien'],
#  ['lapopularmusic',
#   'Sucedió que son unos putos ladrones 14 años manteniendo mis productos con ustedes 14 años y uds trabajan a sus clientes como ladrones Putos mentirosos Estafadores'],
#  ['lapopularmusic', 'putos mentirosos Explotadores Desgraciados'],
#  ['angelicacantor',
#   'No no tengo dudas Pero no entiendo por qué volver a cobrar si ya probamos que no es necesario Los bancos quieren ganar por todo lado Podrían dar ejemplo'],
#  ['Lamorasinsuegra', 'Mi café favorito ❤️✨'],
#  ['99jvbg',
#   'Hola para abrir una cuenta de ahorros necesito monto de apertura Soy Venezolano con PEP y pasaporte vigente'],
#  ['rativa_jhon', 'Que es el dm'],
#  ['rativa_jhon',
#   'buenas tardes me han generado un descuento de mi cuánta de ahorros de 105000 sin explicación alguna'],
#  ['karokagudelo',
#   'La solución de la persona de servicio al cliente fue que llamara a poner la queja después de 2 horas el sistema si estaba lento para las quejas'],
#  ['GuerreroArley15', ''],
#  ['karokagudelo',
#   'pésimo servicio 2 horas y no me solucionaron absolutamente nada Me van a generar cobros por errores de ustedes mismos y me hacen cobros de manejo de una tarjeta que no me han querido renovar'],
#  ['jonathan_avila_',
#   'buenas tardes Que debo hacer para cancelar una cuenta de ahorros'],
#  ['VivianaBuor', 'Ya les escribí'],
#  ['VivianaBuor',
#   'Llegó este mensaje de correo y al ingresar a la plataforma apareció error Fue en mi primer intento'],
#  ['VivianaBuor',
#   'siempre pasa lo mismo Voy a revisar una referencia bancaria y se bloquea el usuario se bloqueó al primer intento de registro Será que me pueden ayudar'],
#  ['pelaez2702',
#   'Buenos días consulta si una persona tuvo inconvenientes con la justicia y ya no No puede abrir una cuenta de ahorros con el Banco por estar en alguna lista Lo consulto por qué una persona que conozco le paso ayer fue y le dijeron que no por eso'],
#  ['YAZMIN_CRUZ',
#   'buen día me informan que sucede con la fiducuenta Intento consultarla y sale un error aparte que muestra saldo en 0'],
#  ['MaCamilaG',
#   'voy 42 min y contando en la línea de los cuales llevo 38 escuchando música de espera Que falta de respeto Y cómo cuelgo si puse que quería calificar la pésima atención'],
#  ['retadoresmtb',
#   'No me están dando solución Le repito no he autorizado ningún débito'],
#  ['anambarrerap', 'la app está caída'],
#  ['Diana_nietodz2',
#   'Ya lo hice Y de ustedes me respondieron que es los que deben solucionar'],
#  ['retadoresmtb',
#   'Para qué me citan al DM si me van a dejar en visto Le recuerdo que me están robando 5 millones necesito solución urgente'],
#  ['Ricardoonoro', 'Ya lo envíe Luis sería bueno notificar a banco farabella'],
#  ['sonomandj',
#   'de nada sirve tener muchos de estos PACS s pero todos haciendo lo mismo que mamera de verdad Buenos días para cliente No tengo cupo BANCOLOMBIA'],
#  ['Ricardoonoro',
#   'buenos días me llegó por correo este correo de ustedes falso por favor revisarlo y mirar si pueden hacer algo para que los incautos no le roben De mi parte bloqueo estás cuentas Ya no tengo cuenta con ustedes'],
#  ['juanpduke',
#   'llevo más de un mes tratando de que un papel salga con una dirección correcta ha sido imposible 8 horas perdidas al teléfono y en chats todos los asesores salen con excusas diferentes Eso es ponerle el alma para aburrirlo a uno'],
#  ['retadoresmtb',
#   'Ya fui a una oficina y me hicieron esperar 8 días para responder que no van a hacer nada'],
#  ['infractoresbga', 'les escribí por DM'],
#  ['LosBernal2', 'Jajajajaja si vió Habló el robot 😂😂😂😂😂'],
#  ['luedgor',
#   'hace 1 mes solicite tarjeta de crédito y está no ha llegado y lo peor es que a mi correo ya me llegó extracto He llamado 2 veces a la línea telefónica y no me solucionan'],
#  ['Umbrellatec',
#   'pagué el 2 de oct mi tarjeta directamente desde el dinero al siguiente dia se veia reflejado como pagado aunque uds no me dejaban hacer uso de los fondos hoy 8 de oct me dicen que la plata no ha entrado un mov negativo me van a robar de frente'],
#  ['muchilon',
#   'y es así como los delincuentes envían correos para engañar y robar a la gente por internet Me bloquearon la cuenta que no tengo con Bancolombia jajajajaja'],
#  ['JJPadillaG', 'Buena Aleja 🤣'],
#  ['LosBernal2',
#   'Lo mas charro es que estas cosas que responden uno no sabe si son un robot o qué Responden por acá cada pemdejada pero en la vida real no se hablan con el banco Igual no resuelven'],
#  ['NyXio',
#   'Súper déspotas las personas que trabajan en atención al cliente Y lo mínimo que deberían enseñarle a los empleados es a identificarse ya que si la persona está dando información lo ideal sería poder verificarla Definitivamente'],
#  ['NachoGreiffenst', 'Definitivamente les quedó grande la app No pudieron'],
#  ['MichaelMarimon',
#   'un asco que le quiten servicios es injusto que no se pueda hacer una compra de cartera con los servicios del banco la solución es hacer un avance en la tv para cobrar un interés más alto GMF y comisión de avance'],
#  ['NathyGomezz', 'Gracias'],
#  ['alexandrabejar5',
#   'Llevo ya 3 meses esperando una respuesta Esto no parece un banco sino el seguro social 😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😃😃'],
#  ['denizpm17',
#   'Y para que invirtieron tanto dinero en la biometria dactilar es que acaso el se va a robar los dedos de otros Que poco diligentes son en estas épocas y en todas deverdad que es el peor sistema de atención al cliente'],
#  ['Juanzonne',
#   'quisiera saber cuáles es el nombre de la asesora encargada de esta línea persona grosera y altanera no deja encuentra de satisfacción y le cuelga el teléfono a uno en mitad de la llamada Y cuál es la forma de poder hacer una queja a esta persona'],
#  ['jupaquingo',
#   'están llegando estos correos a mi cuenta personal Reviso mi app y no tengo ningún bloqueo Consideró que es correo fraudulento'],
#  ['farkantos_', 'que tan real es este correo'],
#  ['NathyGomezz', 'ustedes ofrecen servicios de salud y para mascotas'],
#  ['GIOVANNICAICE',
#   'Por favor cancelen quiero cancelar mi requerimiento tomaré el servicio con otro banco'],
#  ['Osvaldo51688807',
#   'app bancolombia a ala mano no funciona y ahora con plata y sin plata manda huevo y me dijeron q mejor sacaran la de daviplata apenasa saque el dinero de bancolombia me paso a daviviend'],
#  ['MicheloMarceles',
#   'son comunes este tipo de correos pishing Que puede uno hacer frente a esto Esa dirección no puede denunciarse'],
#  ['PnalLLANO', 'RT Ya'],
#  ['AngelicAzulita', 'Ya'],
#  ['jennp2603',
#   'proceso de activación de clave dinámica en la App bastante deficiente y doloroso para el usuario En ningún lado avisan q le bloquearán la clave por 2 horas después de activarla'],
#  ['yonatanruiz',
#   '3198287421 este número pertenece a su empresa me llaman y saben datos de mi tarjeta de crédito'],
#  ['Bancolombia',
#   'Si conoces algún proyecto del sector agro o turismo rural que genere valor en su cadena productiva invítalo a postularse en la convocatoria de En Campo para recibir mentorías financiación y otros beneficios para fortalecer su modelo de negocio ʘ⁞'],
#  ['Milo_dt', 'Tiempo después pude realizar la transferencia'],
#  ['PedroMirandaT',
#   'JAJAJAJAJAJAJAJAJAJA Dizque hola Mafaldo JAJAJAJAJAJAJAJAJA'],
#  ['sepinle',
#   'haciendo declaraciones de renta a 80 mil pesos Que piensa la No hay posturas para hacer respetar y valorar la profesión Ayuda'],
#  ['moises_tejada',
#   'Los llame a su línea telefónica y no me dan ninguna solución inmediata y la culpa es al parecer es de ustedes que reverso el@pago a y por eso me va a suspender el servicio porque tengo que pagar doble ahora'],
#  ['arroyo1987', 'hola este mensaje es real'],
#  ['MaryAlarcon8',
#   'Este es el mensaje que me sale voy a transferir a la fidecuenta'],
#  ['Elvenao_', 'tienen un DM'],
#  ['DJLUIS1892',
#   'Esto es lo que me sale cada vez que intento pagar una cuota de mi tarjeta de crédito Cómo esperan que uno cumpla si su app falla de esta manera Pero para llamar y cobrar sí son veloces'],
#  ['MaryAlarcon8', 'Traté de hacer una transferencia y no me dejó'],
#  ['JuanmRL3', 'El séptimo pago será en este mes de octubre'],
#  ['ErikaDuranOchoa', 'No estoy solicitando nada Saludos'],
#  ['Mirage_roJo',
#   'Ojo con este número que está llamando en su nombre proponiendo devoluciones de efectivo y cuantas fantasías más 👍👍'],
#  ['shoyos4',
#   'Espero que me alléguen el proceso disciplinario o las medidas tomadas respeto al caso'],
#  ['_DJBG',
#   'Quiero seguir manejando la Clave dinámica por correo electrónico no tengo en el teléfono y tampoco quiero instalar la aplicación Que pasos debo de seguir'],
#  ['jhocor', 'Menos mal no tengo productos con ustedes'],
#  ['DavidSa79633823',
#   'Ya hice todo eso ya hablé con 4 asesores en 2 días y nada la página no funciona que es lo que pasa'],
#  ['YerlisEstor',
#   'Todo el día pasa así entonces no creo que esté funcionando con “normalidad”'],
#  ['DavidSa79633823',
#   'Me reporta error TIGA001 al tratar de activar la tarjeta débito llevo 3 días intentando en la página'],
#  ['MaryAlarcon8', 'la app está caída'],
#  ['Vivicastillo91', 'Gracias ya reenvié el correo'],
#  ['__barataria',
#   '20 minutos esperando una clave dinámica ¿La están enviando por 4 72 o qué'],
#  ['Macdiaz13', 'Y que es DM'],
#  ['PaulaPuertaH',
#   'me gustaría saber si la app tiene una funcionalidad para buscar establecimientos cercanos que sean'],
#  ['Bancolombia',
#   'Reportando esta información que te llegó Recuerda adjuntar todos los soportes Te invitamos para que ingreses al siguiente enlace y conozcas más sobre seguridad Que tengas una linda tarde Jacke'],
#  ['Bancolombia',
#   'Que suplantan la imagen del banco Ten presente que nosotros nunca enviamos enlaces ni solicitamos datos personales a través de estos canales Te solicitamos que envíes un correo electrónico a la siguiente dirección Correosospechoso@bancolombia com co'],
#  ['Juancma29',
#   'veo con preocupación que me llega un correo de phishing pero en esta ocasión me llega directamente a mi correo no a un grupo en especifico Solicito que se investigue por qué mi correo personal está filtrado Lo raro es q el correo desde donde lo envían es falabella'],
#  ['fenixlouis',
#   'Que triste saber que no se puede confiar en este banco debitan el dinero de la cuenta sin autorización Un verdadero fraude solicito estudio de mi caso y devolución del dinero Ya'],
#  ['FabianC36203154',
#   'No puedo entrar a etrading en linea porque me figura una cuenta de invesbot en vez de mi cuenta original y no puedo cambiarla'],
#  ['Zuheydy2',
#   'me gustaría saber que pasa con el aporte del ingreso solidario se están tirando la pelotita entre prosperidad Social Bancolombia y Nequi lo único que quiero saber es cuál es el inconveniente'],
#  ['Juampiqbillos',
#   'ustedes que control tienen sobre sus bases de datos me llega un correo diciendo que han bloqueado mi tarjeta que entre a un link y resultó ser un sitio inseguro hace unos días recibí una llamada dónde pretendían que les diera la fecha de vto de la tarjeta OJO'],
#  ['MDGA50',
#   'Ahora me sale este error no me permite hacer ninguna transferencia ayuda'],
#  ['jhocor', 'pendientes clientes quieren robar datos con un correo falso'],
#  ['Bancolombia',
#   'com co com co Reenvía el correo que te llegó a nuestro email correosospechoso@bancolombia com co Te saluda Luis'],
#  ['gerardbermon',
#   'limpio Pero si visualmente está saturada de cosas Parece un neceser'],
#  ['alexcast5000',
#   'Que farsa de aplicación llevó varios días tratando de hacer un trámite y no sirve para nada Nadie responde'],
#  ['alexandrabejar5',
#   'RT Estoy escribiendo al DM allí pero no obtengo respuesta 🤔🤔🤔🤔🤔🤔🤔🤔🤔🤔🤔🤔🤔🤔🤔🤔🤔🤔🤔'],
#  ['alexandrabejar5',
#   'RT Que Moral 😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡'],
#  ['Jonalex_r',
#   'me están enviando información fraudulenta por favor indiquen un canal para denunciar'],
#  ['alexandrabejar5',
#   'Que Moral 😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡'],
#  ['danacarito', 'Ya les escribí Pero cómo raro sin soluciones'],
#  ['laverde1976',
#   'No me atrevo a enviar al whats app pero esto me llegó hoy No tengo productos con ese banco'],
#  ['danacarito',
#   'llamó aBancolombia a Cancelar una tarjeta de Crédito pues no la quiero más Primero un asesor dice que no tiene línea Llamó de nuevo y me dicen que sólo si verifican mi identidad la cancelan apenas me verifican dicen que no me escuchan y cuelgan'],
#  ['alexandrabejar5',
#   'Estoy escribiendo al DM allí pero no obtengo respuesta 🤔🤔🤔🤔🤔🤔🤔🤔🤔🤔🤔🤔🤔🤔🤔🤔🤔🤔🤔'],
#  ['danacarito',
#   'llamó aBancolombia a Cancelar una tarjeta de Crédito pues no la quiero más Primero un asesoró dice que no tiene línea Llamó de nuevo y me dicen que sólo si verifican mi identidad la cancelan apenas me verifican dicen que no me escuchan y cuelgan'],
#  ['paola_monroy87',
#   'para consignaren no se puede entrar al banco te obligan a salir a la fila de la peatonal por una ficha para entrar a la misma puerta del banco donde estaba al llegar Donde esta la seguridad'],
#  ['LuisVasquz92',
#   'Respetuosamente les reporto ataques cibernéticos con suplantación de la razón social de Bancolombia'],
#  ['alexandrabejar5',
#   'RT buen día Cuando será que me colaboran con la refinanciación de mi producto Ya llevo 3 meses rogándoles y NO han querido gestionarme unas cuotas que Yo pueda pagar 😡😡😡😡😡😡😡 Todas las veces que me llaman dicen que aún NO sale la respuesta'],
#  ['alexandrabejar5',
#   'buen día Cuando será que me colaboran con la refinanciación de mi producto Ya llevo 3 meses rogándoles y NO han querido gestionarme unas cuotas que Yo pueda pagar 😡😡😡😡😡😡😡 Todas las veces que me llaman dicen que aún NO sale la respuesta'],
#  ['agromerchant', ''],
#  ['agromerchant', ''],
#  ['ramiochoa', 'ya'],
#  ['mayitosama',
#   'Señores No es que no sepa cómo usarla Lo sé y la uso El problema es que ES UN ENREDO Demasiados pasos para una información Muy visual y poco útil Demasiada información inútil Demasiados pasos para una transacción sencilla La anterior era más sencilla'],
#  ['ramiochoa',
#   'bancolombia que sucede con las transferencias internacionales desde ayer estoy tratando y nada es urgente'],
#  ['AlcazarAlcides', 'Eso es lo q nose'],
#  ['icgoco',
#   'Acabo de llamar y me dicen que tienen incidencias en el sistema Que ni para poner la queja les sirve Este banco es inservible'],
#  ['Sierritafede8',
#   'Mientras los clientes que se defiendan como puedan increíble'],
#  ['tratra690',
#   'Estoy en Bogotá entonces no hay pico y cédula estoy en lo correcto'],
#  ['NAGOCORREA',
#   'Buen Día Sebastián ya mire en la página de ingreso y si soy beneficiario como pasó al DM gracias'],
#  ['NAGOCORREA',
#   'Como es eso q los giros los hicieron entre el 29 y 30 de sept yo estuve en pendiente y me decían q no habían autozado los pagos'],
#  ['JazLucia3',
#   'Buenos días El mismo día respondí las preguntas favor revisar'],
#  ['JazLucia3',
#   'Buenos días El mismo día respondí las preguntas favor revisar']]

# %% [markdown]
# - ## Function to convert tweets in lowercase

# %%
def lower_case(list_text): # Convert lowercase tweets for language processing
    list_lower_case = []
    for i in list_text:
        word = i.strip()
        new_word = word.lower()
        list_lower_case.append(new_word)
    return(list_lower_case)

# %%
tweets = lower_case([text[i][1] for i in range(len(text))])
text = [[users[i],tweets[i]] for i in range(len(users))]
text
# Out:
# [['Mimi_UVasquez',
#   'el ya radicó la queja lo que hago es avisar a mis amigos de redes que su app es super insegura'],
#  ['fredysend',
#   'ya no pudieron eso es de hace mucho tiempo toco llevarnos la cuenta empresa para otro banco muy regulares en todos los aspectos'],
#  ['LuchoCandanoza', ''],
#  ['Mimi_UVasquez',
#   'varios amigos me reportan que la actualización de la app es muy insegura ayer a un amigo le robaron un iphone y seguido de eso le robaron dinero de su cuenta bancaria por transferencia desde la app pilas con eso'],
#  ['betoacevedo',
#   'rt encontré con sorpresa la implementación de una dmp dentro del portal transaccional de personas quisiera conocer las políticas de manejo de datos digitales y que información nombrada con exactitud está guardando la dmp y para que la están utilizando'],
#  ['midasmckalister',
#   'señores llevan dañados los cajeros automáticos de la calera 8 días co de sus noches pésimo servicio cambien esas máquinas obsoletas'],
#  ['redactor24',
#   'paren ya su acoso ya les dije que no me interesa su cupo de crédito ¿cómo más hay que decirlo para que dejen de bombardearme con su publicidad telefónica y de mensajería'],
#  ['todoparati23', 'por que mi tarjeta débito no tiene cvv'],
#  ['Bancolombia',
#   'creemos más que nunca en su fortaleza y queremos acompañarlas a conseguir un mejor futuro por eso creamos la línea de crédito agro para todas una oportunidad para que puedan alcanzar sus sueños y tener un mayor bienestar'],
#  ['JehanAliC',
#   'y su mundo digital para facilitar su trámite imprima el documento llene a mano ponga su huella quien tiene huellero en su casa después escaneé les falta poner “por último radique en el banco” 🤣 súper digital 👏👍'],
#  ['caritoalegria91',
#   'la app de ustedes la mayoría del tiempo está fallando mala cosa'],
#  ['zerrrrrrep',
#   'malo el servicio en el banco físico y ni hablar del soporte por este medio ahí estoy esperando soporte hace horas …'],
#  ['midasmckalister',
#   'ustedes el mismo cuento de siempre escriba por dm lo concreto y lea todos los twittear es que los tres cajeros que hay en la calera llevan una semana sin funcionar'],
#  ['fredysend',
#   'es triste que cada quincena sea lo mismo con uds esa sucursal virtual caída estamos mamaos de eso'],
#  ['CAMT_1_4',
#   'encontré con sorpresa la implementación de una dmp dentro del portal transaccional de personas quisiera conocer las políticas de manejo de datos digitales y que información nombrada con exactitud está guardando la dmp y para que la están utilizando'],
#  ['mauriciorodas00',
#   'ya ajusto 20 llamadas en un solo día que fastidio de banco'],
#  ['jorgehestradag',
#   'pero entonces no es en este momento ha sido en varios momentos ya que el mismo error tanto desde sucursal personas o empresas lo he tenido en más de una oportunidad'],
#  ['cegatron89',
#   'le han estado cobrando el 4x1000 a mi madre desde que abrió la cuenta en diciembre y no se ha llegado a ese tope ¿lo hacen con todas las cuentas para pensión a padres de otros amigos le han realizado lo mismo'],
#  ['Daniieel1983', 'claro que si tatiana 😉'],
#  ['davidescobar73',
#   'precisamente día de pago de nómina y la sucursal virtual empresas caída'],
#  ['Briam_Gutierrez',
#   'yo le llamaria falsa publicidad porque no estan dando este tipo de credito'],
#  ['AndresZ85755720', 'a qué horas se cae la app de bancolombia'],
#  ['Fg535',
#   'pueden hacer una bendita aplicación que no se muera cada quincena'],
#  ['Solano', 'gracias angie ya respondí por dm'],
#  ['linajarabo',
#   'cómo es posible que pague el total de mi crédito hipotecario hace más de 1 mes y ahora resultan cobrando sin saber qué es y nadie responde'],
#  ['edyjo_',
#   'gracias estefa eres muy amable sin embargo el tiempo se ha extendido más de la cuenta cuando la solución debió ser más oportuna temo que el banco me informes que mi dinero se perdió y me toque emprender un proceso judicial'],
#  ['edyjo_',
#   'muchas gracias por comunicarte conmigo estefa pero tu respuesta no satisface mis pretensiones es posible que me informes las causas o motivos de la demora en resolver mi caso'],
#  ['MotoRatona_',
#   'gracias aunque ni siquiera tengo productos con ustedes y eso lo hace aún más gracioso 😂'],
#  ['Sebastian_G14',
#   'buenas tardes me podrían brindar asesoría realicé un pago de mi tarjeta de crédito mastercard que tengo con ustedes en el banco pero la pague desde la app de otro banco el pago salió y me confirmó pero la tarjeta en la app personas me aparece la deuda aún'],
#  ['MotoRatona_',
#   'claramente ya bloqueé la cuenta que envía esos mensajes me causa gracia que ni siquiera se esfuerzan en cambiar el dominio del remitente y dejan banco falabella 🤣🤣🤦\u200d♀️'],
#  ['davidmtnz27',
#   'ellos cajeros fallan y se quedan con la plata los aplicativos de consulta en el call center no funcionan de la personal cero actitud de servicio disculpen srs que les sirve'],
#  ['Eduardo34501436',
#   'buenas tardes bancolombia yo cobro por modalidad de giro con ustedes y hace 1 mes abrí una cuenta de ahorro a la mano en este pago que se aproxima ya me empezan a pagar x cuenta o me van a trasladar a supergiros gracias'],
#  ['Aliceresponde',
#   'por favor me confirma si el tiene el absurdo cobro por retirar de cajero en otras ciudades por favor explicar ese atropello cómo validar los topes de estas injustificadas y desmotivantes políticas de la banca en colombia'],
#  ['YAG_C', 'que ya la tengo inscrita'],
#  ['aldairvelasque1', 'yo te escribí por dm'],
#  ['dianymarr', 'no me solicitaron pago mínimo'],
#  ['aiztferonitro',
#   'deisyb si alguna vez te hace una marranada financiera recuerda muy bien este tw es un sentimiento de impotencia solo espero hacer lo posible para pagar y nunca mas volver a verlos la gente sabe que como banco no tienen nada que perder que nadie les pague'],
#  ['aldairvelasque1', 'reexpedición'],
#  ['rodolfo20961215',
#   'buenas tardes me gustaría saber el horario de atención de la sucursal en zipaquira gracias'],
#  ['MshadowsMCR',
#   'no amiguitos esas excusas ya no valen ustedes reflejaron las porquerias que son con los colombianos no les importo que muchos estuvieran endeudados otros pasando necesidades pero vaya uno no pague lo que ustedes dicen y verá asco de banco'],
#  ['TuConsonante', 'si lo lamentan pero no hacen nada para solucionar 🙄'],
#  ['YAG_C',
#   'ya estoy inscrito estoy tratando de hacer un pago pero la clave dinámica no llega o llega media hora después cuando ya no sirve'],
#  ['super_chata',
#   'buenas tardes ya les respondí por dm toda la información q solicitan para q de manera inmediata me devuelvan mi dinero información que ustedes deben tener pero por su ineficiencia y para ganar tiempo se les hace más fácil que el cliente se las suministre'],
#  ['Adriana88541440', 'ajaaaaaaaaaaaajaaaaa'],
#  ['AnnieLaBanani',
#   'me ayudan tengo que activar una cuenta que abrí por medios digitales y no he podido'],
#  ['dianymarr', 'respondí por dm'],
#  ['Luret_',
#   'un crédito de libre inversión interpuse un dp con uno de sus asesores telefónicos después de que alguien de redes sociales me llamará y no pueden encontrar el requerimiento sin el número de radicado en pleno siglo xxi que empresa no puedo encontrar un radicado con otros datos'],
#  ['Felipextilla',
#   'la gerente dice que es el protocolo de bioseguridad le pregunto donde esta exhibido y dice lo tengo en el computador'],
#  ['Felipextilla',
#   'bancolombia sucursal parway media hora para que la gerente salga brava a atender y decir que nonabre la puerta no dejan entrar al banco'],
#  ['Luret_',
#   'es el 4to mes en donde estoy pagando los intereses de un periodo de gracia de 3 meses que no pedí hasta cuándo voy a pagar esos intereses'],
#  ['dianymarr', 'ya le escribí por dm espero su pronta respuesta'],
#  ['ElcoyoteLpez', 'reyes del pésimo servicio cambian para empeorar'],
#  ['YAG_C', 'hay problemas con clave dinamica'],
#  ['GustavierPB',
#   'buenos días una pregunta ¿que es el débito sucursal bancolombia y ¿cuánto e el monto máximo a descontar gracias'],
#  ['johanagt88', 'no funciona esa clave dinámica'],
#  ['VGLARA2', 'que fea mala lenta en 15na bancolombia muere'],
#  ['mauriciorodas00',
#   'cuando me acerco a sus oficinas a buscar una alternativa y me dicen que ya no hay turnos que llame que llame a los que me dicen que lo único que tengo que hacer es pagar qué fastidio de banco'],
#  ['mauriciorodas00',
#   'cuando llaman y me piden una cantidad de datos que cada llamada les tengo que suministrar para que la única información que dan es que o pago o me reportan qué fastidio de banco'],
#  ['betobaena27',
#   'quincena o fin de mes la plataforma caída que raro no 😆😆😆😆😆'],
#  ['mauriciorodas00',
#   'cuando solo llaman y dice que si no pago me reportan como si en esta situación eso fuera realmente preocupante antes que otras prioridades qué fastidio de banco'],
#  ['Juli_abad89', 'alivio para ustedes será'],
#  ['ElBienhumorado',
#   'bla bla bla llevamos 5 veces hablando con el banco y no dan solución es un descaro'],
#  ['_danielmqz_', 'se llama camila'],
#  ['_danielmqz_',
#   'rt asuman su responsabilidad y dejen de robarle a la gente no sean descarados'],
#  ['YamitGarcia1', 'perdón que es dm'],
#  ['isa_garrido1', 'ya les escribí por dm'],
#  ['mauriciorodas00',
#   'con hasta 20 llamadas diarias de cobro y siempre se les dice lo mismo qué fastidio de banco'],
#  ['NestorLlanoSal1', 'vergüenza de banco ladrones con permiso para robar'],
#  ['isa_garrido1',
#   'necesito comunicarme vía telefónica con un asesor y no atienden las llamadas 😩😩 que rabia el caos de'],
#  ['TavoAcevedo',
#   'me dieron hoy una respuesta por cierto carente de información para un evento que terminó ayer mejor dicho de nada sirvieron los canales de comunicación con ustedes'],
#  ['froyuc', ''],
#  ['ilegi2',
#   'rt que van a revisar si ya descontaron el dinero 🤷🏻\u200d♀️ acaso lo piensan devolver 🤷🏻\u200d♀️'],
#  ['ilegi2',
#   'rt no se preocupe me tomé el trabajo de ir hasta una oficina y ni soluciones ni respuestas claras cuando les pregunté por qué nunca me explicaron desde el principio el escenario real de la situación ustedes son un karma para el usario'],
#  ['Tico92588258',
#   'mala mala mala esa app siempre arroja error hasta para hacer el pago de un producto'],
#  ['froyuc',
#   'que es lo que pasa com esa app no sirve para nada ¿como novedad hoy tambien esta caída'],
#  ['ManuelEsp30',
#   'lo he dicho el banco más ladrón de colombia junto a los del nadie los controla roban a pueblo multiplican el dinero que usaron para comprar la presidencia y mantener el poder de hacer lo que quieran sin control'],
#  ['fabianacuna1',
#   'escribí hace rato y ahí me quedé igual que en las llamadas que ineptitud la cacha del culo estos pingos'],
#  ['OSCARACALDEROND',
#   'esto lo he realizado por dm en varias ocasiones y ha todos les explico y luego me dejan disque esperando respuesta del area encargada y así ha pasado casi 3 meses quiero que me contacte un asesor por vía telefónica'],
#  ['mauriciorodas00',
#   'indolentes y alejados de la realidad mundial acosan y lastiman la salud mental de sus clientes que fastidio de banco'],
#  ['MariadelCCB',
#   'siempre me mandan al dm para no darme ninguna respuesta exacta y correcta me habían dicho una cosa y hoy que llamo a preguntar por el radicado me dicen otra no se quién es más ratero si o'],
#  ['mauriciorodas00',
#   'deberles a ustedes es peor que matar un cura que karma que fastidio'],
#  ['mauriciorodas00',
#   'que desespero tener una mora con ustedes 15 llamadas al día para decir que pague respeten'],
#  ['fabianacuna1',
#   'yo llevo 9 llamadas a ese dizque centro de ayuda para cancelar una puta tarjeta de crédito que ni la tengo porque me cancelaron el plástico y no lo mandaron pero igual cobran la cuota de manejo después preguntan porque uno apoya los vándalos'],
#  ['ZulyMoz', 'para qué si no hay respuesta'],
#  ['MOISDI',
#   'es que cualquiera puede estrar a mi cuenta un día cualquiera y cogerme lo que les de la gana quien me dice a mi que no fueron ustedes ustedes se lavan las manos que seguridad le están brindando a uno uno no es adivino para saber que era 7n fraude en la semana m'],
#  ['OSCARACALDEROND',
#   'pido la respuesta formal a mi reclamo de reintegro de hace 2 meses y me envía un email con una respuesta de otro reclamo de hace 3 meses negligencia o burla'],
#  ['OSCARACALDEROND',
#   'estoy intentando que me envíen un email con la respuesta adjunta de un reclamo de hace 2 meses y mandan el email vacío es una burla o es negligencia del asesor pero igual no logro tener solución a mi reclamo'],
#  ['OSCARACALDEROND',
#   '3 llamadas a la línea de atención al cliente pero el asesor me deja esperando hasta que se corta la llamada y se pierde todo lo adelantado y lo peor es que los asesores no tienen el mínimo detalle para devolver la llamada y dar solución al problema del cliente'],
#  ['FitoHndz95',
#   'en el barrio san luis también pasa lo mismo de los dos cajeros sólo está funcionando uno frente al supermercado la canasta campesina'],
#  ['JoaoelJugador',
#   'perdone gustavo la palabra pero mas pendejo usted que no siguió pagando normalmente el tal alívio nunca existió porque simplemente debía seguir acumulando intereses sobre toda el capital desde el inicio cuando lo escuché me pareció la estupidez mas grande'],
#  ['aiztferonitro',
#   'me van a devolver es una pendejada escribir al interno no solucionan nada solo les preocupa la mala publicidad no van a solucionar nada'],
#  ['_art_hur__', 'cómo sería'],
#  ['Galaxy_Waltz', 'necesito ayuda por favor dm'],
#  ['MarianaSolano3',
#   'increíble que presten un servicio tan malo no son capaces de solucionar un problema que es de ellos ni siquiera respetan el tiempo de los clientes más de 15 llamadas para que me solucionen y nada😡😡 el peor servicio en banca lo tiene'],
#  ['felipeszarruk',
#   'como puedo cancelar la cuenta sin ir al banco a través de la web'],
#  ['MOISDI',
#   'ya puse las quejas y ya me respondieron que no me podían responder que había sido víctima de un estafador pero quede muy triste que garantías y seguridad le brindan a uno sus cuentas'],
#  ['AHxb', 'son un chiste 😂'],
#  ['NoSoyJuanPa',
#   'tiene una publicidad que dice esa app se convertiría en el empleado del mes 😑 olvidaron que detrás de una app hay personas que programan piensan y trasnochan🚀 si una app es buena las personas son los las empleados del mes ❤️'],
#  ['Osyegaoc', 'hola ya el inconveniente fue solucionado'],
#  ['CamiloAlvarezB', 'le está poniendo el alma'],
#  ['JulianCatanoC',
#   'no se preocupe me tomé el trabajo de ir hasta una oficina y ni soluciones ni respuestas claras cuando les pregunté por qué nunca me explicaron desde el principio el escenario real de la situación ustedes son un karma para el usario'],
#  ['isislopez_1983',
#   'responda que uds le van quitando el dinero a la gente por cada movimiento con su propia plata'],
#  ['MrTangeles',
#   'como asi que solo responden por el 50 de la plata si el error fue 100 de ustedes'],
#  ['super_chata',
#   'hicieron cargo a mi cuenta por una compra en amazon la cual no fue procesada pero bancolombia me debitó el monto y no me lo ha devuelto en los teléfonos que dice debo llamar nadie se digna atender les agradezco procedan a devolver mi dinero de manera inmediata'],
#  ['jabernalv',
#   '¿ya resolvieron esta situación la respuesta debe ser asumir ustedes'],
#  ['oqs216',
#   'son campeones con el dinero de sus usuarios algo parecido sucede cuando los cajeros automáticos no entregan el dinero el usuario debe de esperar un día hábil para devolver el dinero pero cuando es el cliente que se demora un día ellos te cobran intereses'],
#  ['derianpt',
#   'llevo pidiendo días un extracto del mes de enero y siempre me envían el de febrero y marzo sean serios lo necesito urgente'],
#  ['FitoHndz95',
#   'cúcuta norte de santander y en el municipio de bochalema el ubicado parque central quedo atento a su respuesta'],
#  ['Camilo_S08', 'me están pidiendo datos de mi sitio de trabajo'],
#  ['jumacoac', 'les sobra una r en el correo'],
#  ['oliver_cepeda1',
#   'yo tengo un préstamo con sofi y no tengo empleo y siempre que me llaman me ofrecen ciertos alivios que realmente lo que me ofrecen es extender las cuotas con doble interés vivasos por cierto ya me tienen aburrido cada 3 días llamando'],
#  ['NANITOSHKA',
#   'alivios me hicieron préstamo 20mll en marzo comenzó la pandemia me dieron el alivio ahora ya van en 3 millones de intereses y me llaman xa financiar toda la deuda disque no me cobran un mes y los intereses por las nubes pido envíen estracto de intereses y nada'],
#  ['TrvlGrtAgn',
#   'bank in the world just like is the worst airline in the world how do these companies that provide shit service stay in business well it wont be much longer for avianca and maybe will be soon after service'],
#  ['TrvlGrtAgn',
#   'operates the worst bank in the world nothing ever changes with this crap bank today in victoria in pereira we waited over 2 hrs in line with hundreds of people and even though they accepted us on the line for hours the bank closed and they said no more people shit'],
#  ['FMejsal', 'ratas'],
#  ['elkarmahallegad',
#   'bancolombia roban por todos lados por tarjetas extranjeras cobran por transacción hasta 18 mil eso es un descaro ahora todas las arandelas que hacen para ir sacando dinero de cada cuenta un robo totál'],
#  ['Ruvemcho',
#   'y flypass cerrarán negociaciones con nuevos parqueaderos en bogotá y medellín 🚗🚙 que aceptarán este medio de pago sin contacto ⚡⚡ actualmente los estacionamientos de oviedo y el aeropark 🌳🌳 tienen el servicio disponible'],
#  ['Ruvemcho',
#   'movilizará 140 000 millones de dólares en servicios financieros en los próximos 10 años el anuncio se dio en el encuentro de la alianza global de inversores para el desarrollo sostenible de la onu lee aquí cómo se orientarán estos recursos 👇 …'],
#  ['fidelantoniomr',
#   'muy alegres ante la desgracia ajena que ustedes empeoran se les recomienda no ser tan festivos y más nuevos buscar soluciones en las que honren la confianza y la buena fe de quienes ponemos nuestro dinero en sus manos al menos para no lucir como cínicos'],
#  ['W4rr10rRo0t',
#   'lo paso por un sandbox y luego trato de notificarlo a pero como sus plataformas nunca sirven pues dejo así'],
#  ['camiloaafanador',
#   'rt para qué le van a devolver la plata díganlo enseguida o le va a repetir la misma información que ya le dieron y ya sabe'],
#  ['Bancolombia',
#   'esto lo puedes realizar en la configuración de tu dispositivo móvil saludos'],
#  ['MariaTeresaVaBa',
#   'no tienen en cuenta la posible reactivacion economica no todos son empleados del estado 😡😡😡😡'],
#  ['JohanQC777',
#   'coloca la actividad económica 0090 de rentista de capital ya que no hay una que indique que es sostenida por sus padres mentiras lee bien los ciiu previamente a tramitar el rut sino quieres es mas fácil aperturar nequi pero si te recomiendo luego migrar a un banco'],
#  ['pcerheguma',
#   'nunca fueron claros en las líneas telefónicas decían una cosa y por correo decían otra ante tanta incoherencia e información tan poco clara lo mejor era si se podía cancelar cualquier deuda'],
#  ['ChicleBoyacense',
#   'rt para qué le van a devolver la plata díganlo enseguida o le va a repetir la misma información que ya le dieron y ya sabe'],
#  ['handrs9010',
#   'de esta dirección me llegan bastantes correos informacion@mailgrupobancolombia com co'],
#  ['landito1', 'jajajajajajaja'],
#  ['billytontony',
#   'ahhhh bueno fue solo un problema de falta de claridad de información la próxima vez sean mas claros a la hora de desplumar a la gente'],
#  ['roberlucena', 'devuelvan el dinero'],
#  ['frankiko63',
#   'rt para qué le van a devolver la plata díganlo enseguida o le va a repetir la misma información que ya le dieron y ya sabe'],
#  ['AndresArboled_a',
#   'eso es lo único que hace bancolombia quitar el dinero cobrar mal dar mala información y ahora todos los usuarios están quedados menos mal están demostrando como son tendencia por mal banco y como están llegando competencias fuertes para tumbarlos no mas bancolombia'],
#  ['DanielSicAm',
#   'rt cuantos favs y condonan en su totalidad una deuda con ustedes'],
#  ['Mamertoid', 'hijueputas'],
#  ['Jojuanna', 'mil gracias'],
#  ['Dcaguirre97A',
#   'el sitio es de ustedes si sí muy extraño que requiera un login por fuera del sitio de sucursal virtual personas si no están enviando correos que tienen mala pinta'],
#  ['SergioLB12',
#   'es tendencia solocitar a empresas o personas determinada cantidad de me gusta likes favs para obtener algo a cambio dicho esto ¿cuantos me gusta likes favs para condonar una deuda que tengo con ustedes'],
#  ['JPABLORODRIL',
#   'rt para qué le van a devolver la plata díganlo enseguida o le va a repetir la misma información que ya le dieron y ya sabe'],
#  ['dozurpe',
#   'yo tenia que abrir otra ventana de mi celular para ver la dinámica'],
#  ['TavoP_G', 'no sean ratas'],
#  ['DCaroCarambola',
#   'lo abro les mento la madre a los ladrones les pregunto por acá a ustedes cuál es el correo para informar lo del pishing ya luego lo reenvío y lo elimino'],
#  ['xmariana02', 'pero yo no trabajo mis papás me mantienen todavía jajj'],
#  ['himmelklavier',
#   'rt para qué le van a devolver la plata díganlo enseguida o le va a repetir la misma información que ya le dieron y ya sabe'],
#  ['rolo_del',
#   'rt para qué le van a devolver la plata díganlo enseguida o le va a repetir la misma información que ya le dieron y ya sabe'],
#  ['PalmSolangel',
#   'esa manía de ustedes de querer obligarlo a uno a inscribir las facturas para pagar a través de la sucursal virtual ahora la famosa clave dinámica desde la app no sirve no sé por qué inventan tanto😞'],
#  ['ElHombreDeLasR',
#   'depende si es un enlace porno le echo un ojito primero de rapidez y ahí sí lo borro 🤭🤭🤭'],
#  ['ATurmewhat', 'en pocas palabras ratas 🐁'],
#  ['xmariana02',
#   'les pregunté por acá si necesitaba el rut para crear la cuenta y me dijeron que me tenía que acercar a una sucursal física para que allá me dijeran si era necesario o no'],
#  ['IsabelMTaborda', 'no me ha querido servir en todo el día 🙄🤦🏻\u200d♀️'],
#  ['fidelacorrea',
#   'que falta de honestidad del banco y de la persona que recibió el dinero por error que 😱😱😱😠😠😠'],
#  ['lajana9090',
#   'pura mierda congelaron el cobro de los créditos pero los intereses crecían como si el cliente hubiera dejado de pagar porque sí troncos de rateros a mí me quitaron 500 mil y punta de interés'],
#  ['Bancolombia',
#   'la mejor forma de protegerte del phishing es identificar si es una estafa para hacerlo reenvíalo a corrreosospechoso@bancolombia com co estos son 3 elementos que podrás encontrar en este tipo de correos ʘ˧'],
#  ['fidelacorrea', 'demasiado cínismo 😱😱😱'],
#  ['JAIRMETALS',
#   'son unas ratas mejor busquen otro banco como colpatria o otros estos hp cobran 12 000 de cuota de manejo y sin importar la pandemia ratas hp'],
#  ['maupovi75', 'rt ratas hijueputas abusando de la gente'],
#  ['maupovi75', 'ratas hijueputas abusando de la gente'],
#  ['nancho85',
#   'buenas tardes mi esposa y yo tenemos cuentas de ahorro de bancolombia y manejamos un solo celular yo ya tengo registrado la clave dinámica con mi cuenta se puede registrar también la cuenta de mi esposa con el mismo celular no tenemos más celular que hacemos'],
#  ['JJoseTrujillo',
#   'responde por eso tal vez el cajero y su gerente para no ponerse en evidencia ante medellin tratan de resolverlo ellos pero la central del banco responde por todo seguro obvio hay perjuicios pero el capital no se pierde duerma tranquila'],
#  ['SergioLB12',
#   'cuantos favs y condonan en su totalidad una deuda con ustedes'],
#  ['ginac0723',
#   'le ha bloqueado la cuenta 2 veces a mi mamá no la deja hacer transferencias pagos o lo que sea pero sí reciben la plata que le envían a ella y fue a solucionarlo le cambiaron la tarjeta y al otro día la misma mierda a qué juegan'],
#  ['MayoVGil',
#   'les contacte primero por los canales internos y es muy molesta la respuesta de sus asesores toman decisiones unilaterales siempre sin pensar en las personas'],
#  ['ncojack_JP',
#   'buen dia a mi me han llegado correos parecidos diciendo que digite mi documento para saber el extracto'],
#  ['romnyd', 'seguro me invente la falla'],
#  ['jpradach1', 'no carolina nada qué hacer'],
#  ['romnyd',
#   'otra vez su plataforma de pse fallando como si no fuera importante tener el soporte de pago'],
#  ['QueMamera_',
#   'daniel el inconveniente te lo estoy mostrando en la imagen saludos'],
#  ['edyjo_',
#   'ya me he comunicado con anterioridad y en múltiples ocasiones por dm por email por línea telefónica y no pasa nada si de verdad quiere deme indicaciones de la queja y'],
#  ['frajobehi',
#   'un iphone 12 pro plus max xt por favor con la cuota de 9 900 gracias'],
#  ['Bancolombia',
#   '1 si el asunto es urgente el destinatario no concuerda y te piden descargar archivos elimínalo \u200b 2 si parece ser del banco y te pide clave usuario y número de la tarjeta reenvíalo a correosospechoso@bancolombia com\u200b ʘ˧'],
#  ['alexagat',
#   'hola cada que marcó al 5109000 me aparece davivienda y no tengo ese número guardado con nombre de davivienda'],
#  ['MRCHIKIP',
#   'no loren por privado lo vacilan a uno y se hace lo que uds quieran y como uds quieran es mi dinero y deberian sostener las garantias que me ofrecieron al momento de adquirir el producto prefiero cancelar mis productos con uds y presionar la empresa para me pague con otro banco'],
#  ['fcoramna', 'estaremos observando cualquier cosa gritas'],
#  ['MRCHIKIP',
#   'de repente y sin autorizacion cambian mi plan de cuenta como les da la gana cobrando extra y me lo tengo que tragar si toca que la empresa me pague la nomina en cheque o en monedas pues lo acepto pero esa cuenta se cancela'],
#  ['sehuanes_felipe', 'muchas gracias por la información'],
#  ['Camo__Oficial',
#   'y me siguen llamando del 304 550 3348 no quedo claro ayer que no quiero recibir mas este tipo de llamadas no me interesa por que vendieron mis datos'],
#  ['faja9498',
#   'ni lo recomendaría a bancolombia ni lo recomiendo fue el banco que se aprovechó de la necesidad de sus clientes en la pandemia para hacer de la suya'],
#  ['TavoAcevedo', 'ok ya escribí por interno'],
#  ['gorofox', 'buenas tardes hay inconvenientes con la app'],
#  ['Osyegaoc', 'ojalá lo implementarán'],
#  ['TavoAcevedo',
#   'a ver si por aquí responden ¿de cuánto es el descuento ¿cómo se accede a él'],
#  ['ValeriaMendezC',
#   'qué está pasando con la seguridad de información de los usuarios ya conozco 3 casos incluyendo el mío sobre el bloqueo de la cuenta porque alguien intentó meterse desde la sucursal virtual por favor expliquen lo que está sucediendo'],
#  ['jonyleonp',
#   'buenas tardes muchas gracias en la actualidad tengo dos crediagil y dos créditos tasa fija estoy sin trabajo desde el pasado mes de abril y quiero postularme al congelamiento de la deuda hasta dic es posible ante la incapacidad de pago'],
#  ['mariselacasalla', 'no he podido enviar el mensaje dm'],
#  ['mariselacasalla',
#   'el peor servicio de bancolombia solo atienden por línea telefónica y dicen que espere su llamada y llevo 5 meses esperando que me llamen'],
#  ['luiskgomezc',
#   'que servicio tan malo de sus cajeros electrónicos la mayoría de las veces que voy no sirven ¿entonces para qué están lo que hace le hace a uno perder el tiempo 😡'],
#  ['AndreaSndoValle', 'hola ya respondí por dm espero pronta solución gracias'],
#  ['OliverS66063224', 'eso me llego hoy'],
#  ['RichiRojasL',
#   'estoy esperando su respuesta por dm nuevamente me acabaron de llamar a preguntar por alguien que no soy yo'],
#  ['LizPater17',
#   'asuman su responsabilidad y dejen de robarle a la gente no sean descarados'],
#  ['Jojuanna', 'quisiera saber si esta información es verdadera gracias'],
#  ['jpradach1', 'pues ya estoy en dm'],
#  ['Alejoeplugg',
#   'hola muy buenas tardes santi me sale un error que me debo inscribirme a la clave dinámica pero lo raro fue que hace unas horas antes había hecho una transferencia y yo ya he llamado y he hecho el procedimiento para la clave dinámica me genera el problema muy seguido'],
#  ['jramirezc1984', 'esto es cierto o es algo anormal'],
#  ['MateoPaV', 'me llega este mensaje es verdad o es una estafa'],
#  ['FitoHndz95',
#   'el cajero del parque central del municipio de bochalema también presenta problemas y es el único que hay'],
#  ['FitoHndz95',
#   'es por el bien de todos que hago esa queja es muy molesto que siempre se vea la aglomeración de personas en los cajeros bancolombia y además se presta para que los amigos de lo ajeno hagan de las suyas faltan protocolos de bioseguridad por lo menos un antibacterial en los cc'],
#  ['Enero20b',
#   'para qué le van a devolver la plata díganlo enseguida o le va a repetir la misma información que ya le dieron y ya sabe'],
#  ['Lalupa33376573',
#   'el numero del celular que envío el mensaje es 316 334 66 30 para que tengan en cuenta y pongan en reporte esta modalidad de fraude gracias'],
#  ['FitoHndz95', 'cúcuta norte de santander'],
#  ['Lalupa33376573',
#   'hola buenos días en la mañana de hoy recibí un mensaje que dice así felicitaciones hoy movistar y bancolombia te felicitan por ser el ganador de 10 000 000 comunicate ya pbx 301248090 cdg 750 aut coljuegos y este es el numero donde me enviaron el mensaje a mi'],
#  ['Misslegsonfire', 'ya pude solucionar gracias los tkm'],
#  ['EvanyPonce', 'que servicio de porquería'],
#  ['claramejiacar',
#   'cómo sería para desbloquear mi ip y poder entrar a la sucursal desde mi wifi'],
#  ['DayanaJ86812013',
#   'buenos días sucede que aparezco en bancolombia beneficiada de ingreso solidario y no me han cancelado ningún giro'],
#  ['jonyleonp',
#   'apreciados señores tengo varios créditos con ustedes libreinv y crediágil y desde el mes de abril estoy sin trabajo podrían indicarme que debo hacer en este caso para acogerme al periodo de gracia hasta diciembre de acuerdo a la última circular de la s financiera'],
#  ['FitoHndz95',
#   'por la pandemia y mi labor no puedo estarme movilizando hasta allá a verificar esos códigos además tengo entendido que para eso tienen personal técnico me parece el colmo del descaro seriedad por favor'],
#  ['FitoHndz95',
#   'cc unicentro sólo sirve 1 o 2 cc jardín plaza 1 de 4 cc ventura plaza solo sirve 1 barrio san luis solo sirve 1 av libertadores más abajo del cai niza 1 de 4 av cero al lado de mkgusto solo sirven 2 y en el parque central de bochalema el único que hay dañado'],
#  ['oscar_concha', '🙌🙌🙌👍👍🇨🇴🇨🇴🇨🇴'],
#  ['sarita_abad', 'nos van asesorar sobre sus utilidades en la pandemia'],
#  ['oscar_concha',
#   'acabo de hacer un pago a por un dispositivo nunca usado y la clave dinámica en el celular funcionó perfectamente sencilla y segura'],
#  ['alejand65379810',
#   'estan respondiendo vainas locas que no concuerdan ni con la fecha de compra no saben donde estan parados 😡'],
#  ['Camiburgosp', 'los odio'],
#  ['alejand65379810',
#   'privado para que para que no se den cuenta lo ratas que son ustedes'],
#  ['PiliCorreaZ',
#   'llevo tres días intentando realizar una transferencia y me indican que me comunique a la línea luego llamo a la línea y me informan que hay un incidente pero no dan información de qué se trata ni para cuando hay una solución para cuándo se soluciona el incidente'],
#  ['sabanerita1', 'ya les escribo'],
#  ['alejand65379810',
#   'señores tengo casi dos meses esperando un reembolso de dinero y aun nada se piensan robar la plata'],
#  ['Klovn', 'phishing llegó a mi correo'],
#  ['juanfelipemc25',
#   'cómo así que debemos migrar la clave dinámica a la app personas desde el 20 de octubre cómo hacen las personas que no tienen teléfonos inteligentes y todo lo haces es a través del pc me toca comprarle un celular a mi abuela para eso o uds se lo regalaran'],
#  ['Luzmari03586318', '3125080487'],
#  ['Jennyg7',
#   'entiendo esto pero no me importaría tener un rechazo y generar nuevamente el pago como en otras entidades bancarias es absurdo tener que esperar 3 días para hacer un pago urgente'],
#  ['Jennyg7',
#   'gracias pero ayer llame al banco y ya me aclararon la información y me dijeron que se demora hasta tres días la inscripción de una cuenta a otro banco y pues nada me toca salir hoy a retirar y desplazarme hasta el otro banco para hacer la consignación que ayuda en la pandemia'],
#  ['Jennyg7',
#   'a mi me parece terrible que inscribir una cuenta de otro banco se demore hasta 3 días y más cuando uno la necesita hacer urgente este es único banco que me encuentro que hace esto y realmente es molesto'],
#  ['sarita_abad',
#   'que van a revisar si ya descontaron el dinero 🤷🏻\u200d♀️ acaso lo piensan devolver 🤷🏻\u200d♀️'],
#  ['Jennyg7',
#   'ayer al mediodía inscribí una cuenta para hacer un transferencia urgente y esta es la hora que la cuenta no ha quedado inscrita me parece el colmo que me digan que se puede demorar hasta tres días respeten que la necesito hacer urgente soy nueva en bancolombia y no me gusta'],
#  ['Jennyg7',
#   'ayer al mediodía inscribí una cuenta para hacer un transferencia urgente y esta es la hora que la cuenta no ha quedado inscrita me parece el colmo que me digan que se puede demorar hasta tres días respeten que la necesito hacer urgente soy nueva en bancolombia y no me gusta'],
#  ['JaimeACastro5',
#   'banco llamé el viernes a cancelar una tarjeta de credito virtual me dijeron que la cancelación se vería reflejada en 1 día hábil hoy miercoles sigo viendo activa esa tarjeta necesito cancelarla antes de que me cobre manejo colaborenme por favor'],
#  ['linajarabo',
#   '1 mes sin solucionar lo del pago total a mi crédito hipotecario quieren más plata quieren robar más'],
#  ['linajarabo',
#   'llevo más de 1 mes sin solucionar mi pago de crédito hipotecario que más quiere robar'],
#  ['nfrancovel',
#   'quiere decir que van a dejar a lod adultos mayores sin posibilidad de que les ayudemos a hacer sus pagos ya pensaron en ese segmento de clientes son clientes que no usan la app ni la van a usar uds los están obligando a salir a un banco y nos quitan la posibilidad de ayudarlos'],
#  ['edmartinezm',
#   'tu atención al cliente es horrible y tu app es lenta e inoperante como proceso burocrático'],
#  ['FitoHndz95',
#   'espero que con ese mismo fervor y patriotismo se encarguen de arreglar los cajeros en cúcuta en todos los cc y en general muy pocos sirven y se aglomera la gente por su culpa sean serios y respeten los usuarios'],
#  ['wrusinque',
#   'vamos tigre gracias bancolonbia por ser patrocinador de la selec'],
#  ['AidaDia34410791',
#   'al consultarme me sale esto no entiendo porque dicen que ustedes no me pagan si mis primeros 4 giros los cobre con ustedes'],
#  ['Marivelezo1', 'falcao te mereces otro hijo'],
#  ['mariale714',
#   'esperanza la que yo tengo de que no empiecen a cobrar las transferencias a otros bancos para robar más plata'],
#  ['tefaniaa26',
#   'vieron ese gol jajaja eso merece que no le cobren tasa nominal en el mes de octubre 💯✌️🇨🇴'],
#  ['Marivelezo1', 'grande falcao tigre de tigres'],
#  ['CataUribeLopez', '4'],
#  ['daniarenas', 'me gané mi primera polla 💛💛💙❤️'],
#  ['EdwinGutierrezT',
#   'ustedes procuren mejorar la aplicación que bien lenta si está'],
#  ['AlejitaLopezC', '6'],
#  ['saraduquelpz', '6 ☝🏼☝🏼'],
#  ['ClienteBanistmo', '5 💪🏻'],
#  ['dokhrates', 'ladrones'],
#  ['MonsalveAcevedo', '2 👆🙏🏼❤️'],
#  ['laurajp7', '5 💪'],
#  ['CuervoMan_',
#   'obviamente no están teniendo en cuenta a estos 10 millones de hijueputas que grandes'],
#  ['PadresEHijos9',
#   'arreglen esa porquería de app en vez de estar twiteando maricadas'],
#  ['Marivelezo1', '5 vamos por el empate'],
#  ['Richienator', '1'],
#  ['CuervoMan_',
#   'rt en su comercial dice que vuelven a latir 40 millones de corazones y los otros 10 millones 🥺'],
#  ['Cris_Quintero', '1 🙌'],
#  ['DanielaMacias01', '1 a echarle cabeza mijos🤔🤔'],
#  ['__sebastian_o_d', '1 cabeza fría'],
#  ['phelipeRz', 'no es cierto'],
#  ['lopezsalexander', '7'],
#  ['cloiinunez', 'y esto que es de nuevo app bancolombia caida'],
#  ['cloiinunez', 'otra vez caida la app de bancolombia'],
#  ['AHxb', 'rt ladrones'],
#  ['phelipeRz',
#   'hoy se anotó dos golazos en mí cuenta debitandome sin mí permiso 200 000'],
#  ['dokhrates', 'ladrones'],
#  ['OscarTrejos9',
#   'promocionando fútbol mientras las personas que tienen su dinero en tienen que hacer enormes filas en cartago bajo el inclemente sol soportando por horas temperaturas superiores a los 30° pésimo y nefasto servicio'],
#  ['dokhrates', 'ladrones'],
#  ['phelipeRz',
#   'me acaba de debitar 200 000 sin justificación alguna y no me dan razón en la línea telefónica ¿ahora sus formas de ganar utilidades es literalmente robándole al ciudadano'],
#  ['nanita821117',
#   'dudas no tengo pereza de usarla pero pues toca porque uds no escuchan a los usuarios hay algo fundamental en el diseño de cualquier cosa y es la usabilidad parece que los diseñadores de su app desconocen el término'],
#  ['paoz08', 'solucionado gracias'],
#  ['lfsantanam', 'me están llegando estos mensajes al correo'],
#  ['Eyarce',
#   'y flypass cerrarán negociaciones con nuevos parqueaderos en bogotá y medellín 🚗🚙 que aceptarán este medio de pago sin contacto ⚡⚡ actualmente los estacionamientos de oviedo y el aeropark 🌳🌳 tienen el servicio disponible'],
#  ['OlaveLigia',
#   'porque no me dan la opción de descargar certificado de crédito hipotecario lo requiero para declarar renta ya que no lo reportan en la rete fuente que me enviaron solicite por teléfono el documento dijeron que tardaba 6 horas aún no llega'],
#  ['bermzzy', 'me ha quitado más plata de la que saco'],
#  ['PilarAmayaJ', 'otra vez falla en la app no me deja trasferir'],
#  ['Nata1992m',
#   'todas sus campañas de alivio son una mentira si de la sucursal telefónica nos envían al punto físico no saben dar explicaciones es mentira sus alivios y hacen que los productos entren en mora para cobrar intereses'],
#  ['NestorTuran',
#   'ah claro me imagino que a él nunca se le ocurrió comunicarse con el banco'],
#  ['scastril',
#   'el banco que dice colocarle el alma a los colombianos más bien le está partiendo la madre a los colombianos'],
#  ['rubielagomez',
#   'o me solucionan la@situación o me encargaré de llevar esto hasta las últimas consecuencias mi hija viaja y la única tarjeta que tiene es con bancolombia y es un deber de axa expedirme el certificado de asistencia'],
#  ['rubielagomez',
#   'que el el dm otras 5 horas colgada al teléfono por qué sume que se que quiere decir ese término'],
#  ['rubielagomez',
#   'inaudito que una entidad tan prestigiosa como la de ustedes jueguen con el cliente de la forma como lo hacen llevo tres días solicitando certificado de viaje internacional y me ponen al teléfono 60 minutos y cuelgan la llamada es una obligación y lo exijo'],
#  ['Marcelalopezoc1',
#   'como es posible que he solicitado la cancelación de una tarjeta de crédito 3 veces con bancolombia y siempre me dan vueltas y me sacan peros y no finalizan el proceso esto es un atropello al consumidor'],
#  ['stvanss',
#   'cuanto hay que reclamar para que una persona le cancelen una tarjeta de crédito que ya no desea que tomadera de pelo es increíble'],
#  ['pmendez3',
#   'debo expresar públicamente que ante el problema manifestado y a pesar de estar en el exterior el equipo bancolombia me a contactado y me ha brindado un servicio de atención rápido y excelente quedo muy agradecido y espero muy pronto una resolución satisfactoria del caso'],
#  ['ArgenisJessSal1',
#   'me realizaron un giro desde canadá el día 01 del mes en curso a la fecha no se registra en mi cuenta debo ir a una oficina para retirar o puedo hacerlo consignar en mi cuenta por medios electrónicos'],
#  ['RichiRojasL',
#   'les dejé mis datos de contacto por dm espero que esta vez sí pregunten por mí'],
#  ['paoz08',
#   'que pasa con la aplicación que no aparece la clave dinámica y uno con afán de pagar sus obligaciones'],
#  ['GigiMendozaN', 'les envíe el dm hace 10 mins'],
#  ['GigiMendozaN', 'sucursal virtual web y móvil por ningún lado funciona'],
#  ['RichiRojasL',
#   'daniel es tu compañero yo soy ricardo he hablado durante un mes con personal de las áreas de servicio al cliente y conciliación y no tienen una solución quiero conocer los procedimientos de'],
#  ['malanarodriguez', 'porque no me deja ingresar con mi huella 🤯🤯🤯'],
#  ['GigiMendozaN', 'enviado'],
#  ['MDCristian_mont',
#   'puedo saber por que me dejan esperando en linea mas de 1 hora esta es la segunda llamada q hago y me dejan en linea por q no puedo cancelar esa tarjeta de crédito del demonio ni tiempo también merece respeto'],
#  ['RichiRojasL',
#   'daniel ya lo he hecho y no me dan solución me dicen que esta persona debe actualizar sus datos él ya lo hizo pero ustedes no retiran mi número del sistema ya he hablado con el área de servicio al cliente y tampoco tienen una solución por eso le escribí a'],
#  ['Junior16748139', 'bobo aquel que caiga en sus trampas'],
#  ['amtribin',
#   'pues aún estoy esperando que me atiendan llamo a la línea de atención al cliente escribo al dm y nada absolutamente nada me han ayudado'],
#  ['Danielleml',
#   'me agenda citas para que sus agentes me llamen y me cuelguen 😂 a ver si me contestan'],
#  ['pmendez3',
#   'que sea por el correo por la app ha sido mi peor experiencia pense que iba a ser mas facil y resulta que meto la clave que aparece y nunca es valida ya estoy estresado con esa situacion no puedo movilizar mi dinero'],
#  ['amtribin',
#   'yo llevo todo el día tratando de que me informen porqué me están cobrando 500 mil pesos por el congelamiento de mi crédito hipotecario y nadie me sabe explicar absolutamente nada esa es la ayuda que le dan a los colombianos'],
#  ['midasmckalister', 'cambien esas máquinas eso ya tecnología vieja'],
#  ['midasmckalister',
#   'ustedes tienen esa información ahorita me desplazo los 10 kilometros desde donde vivo que desgracia perder el tiempo con ustedes'],
#  ['Camo__Oficial',
#   'entonces porque me llaman a vender seguros de parte de una entidad relacionada con banclombia yo no les di permiso para eso'],
#  ['Hey__Carlitos',
#   'mary ya escribí espero pueda obtener una respuesta por este medio'],
#  ['Camo__Oficial',
#   'que hace con mis datos personales ¿por qué los venden a empresas que venden seguros quien regula esto la que inseguridad quien más tendrá mis datos'],
#  ['magils',
#   '¿es legal que me pida más datos personales como mi número de cédula para dejar de llamarme cuando no tengo ni tendré ningun producto con ellos'],
#  ['AbrahamDReyes', '¿donde puedo llamar'],
#  ['AbrahamDReyes',
#   'lo sentimos usted no está autorizado para marcar este número 🤷🏾'],
#  ['magils', 'ya les envié la información espero que no me llamen más cc'],
#  ['PachoChaverra', 'scar una tarjeta'],
#  ['magils',
#   'la única validación que tienen que hacer es eliminar mi número telefónico de su sistema'],
#  ['midasmckalister',
#   'señores es hora de cambien los cajeros de la calera por tecnología nueva las que están son maquinas obsoletas'],
#  ['Luzmari03586318',
#   'quiero saber si me enviaran mensaje de texto para cobrar mis giros por nequi freddy lizarazo'],
#  ['albahgarcia',
#   'lo que uds hacen con los adultos mayores es irresponsable el viernes tuvieron a mi papá adulto mayor 2 horas para abrir una cuenta de ahorros y desbloquear otra cuenta hoy le volvieron a bloquear sus cuentas la solución ir nuevamente al banco'],
#  ['MariaVGonzalezM',
#   'hasta cuando los abusos incumplen promesas y acuerdos te hacen pagar corriendo a “su tiempo” y nunca cumplen lo que se supone me “otorgaron” desde julio'],
#  ['midasmckalister',
#   'señores ustedes son lo peor como institución fuera la primera vez esto ocurre cada 8 dias'],
#  ['misspark8',
#   'la nueva aplicación es un problema no una ayuda para los clientes'],
#  ['agudelo_m',
#   'son sus políticas institucionales y las entiendo pero no las comparto me parece una falta de empatía que en semejante contingencia uno tenga que ir a ponerse en riesgo a una sucursal porque ustedes no aceptan abonos a capital por ningún otro medio'],
#  ['Silvanadiaz98', 'hola tati ya se arregló jejeje besitos'],
#  ['OdioLasSopas',
#   'llamo desde su página me tienen 20 minutos como una estúpida cuando por fin me atiende el que se supone me resuelve dice cliente no responde y yo a el lo escucho perfecto los odio como le van a bajar el rendimiento a una inversion porque sí'],
#  ['GabyEscalante5',
#   'el servicio de atención al cliente por teléfono es tan nefasto que marca una alguna de las opciones y lo que hacen es cancelar la llamada'],
#  ['lauragornzalez', 'me pasa lo mismo'],
#  ['Andresc_h',
#   'queremos que la app funcione bien y sin tanto error ya viene la quincena'],
#  ['shaka38', 'quieres saber de bugs en producción 🤣 🤣 🤣'],
#  ['DianaOr50911680',
#   'seguridad bancolombia no brinda eso más de 15 días para devolverme 150 mil pesos que descontaron abusivamente de mi cuenta'],
#  ['ricardo18226532',
#   'no obliguen a la gente a abrir una cuenta para reclamar giros sucursales pereira si a alguien lo estan obligando ante quien puede poner la queja para q sancione el banco q gracias y a los lectores no usen giros bancolombia'],
#  ['alemon008',
#   'quisieras conocer buen servicio al cliente yo te puedo ayudar'],
#  ['Bancolombia',
#   'recuerda que ya no tienes que llamar a la línea telefónica para resolver tus dudas sobre la nueva app personas aquí te ayudamos a responder a todas tus preguntas ʘ˩'],
#  ['Bancolombia',
#   'respuesta \u200b cualquier transacción que hagas desde app personas se validará automáticamente ya no hace falta esperar a que te notifiquen para usarla ʘ˩'],
#  ['Bancolombia',
#   '¿si haces un pago desde app personas deberás esperar a recibirla por correo o mensaje de texto \u200b ʘ˩'],
#  ['Bancolombia',
#   'respuesta ¡es muy fácil entra desde tu celular a app personas y en el home podrás ver los 6 dígitos sin necesidad de ingresar tu usuario o clave ʘ˩'],
#  ['Bancolombia',
#   'si estás realizando un pago desde otro canal y te pide la clave dinámica ¿cómo puedes consultarla ʘ˩'],
#  ['Santo90R',
#   'qué hay una entrada específica y es por fuera del centro comercial'],
#  ['MarcoJara_7',
#   'si señores también ando en el dm esperando a que me hablen pero tampoco'],
#  ['MarcoJara_7', 'señores ya les hable por dm pero no hay respuesta'],
#  ['Santo90R',
#   'ya estoy realizando la transacción pero uds no pueden imponer más barreras especialmente para las personas de la tercera edad'],
#  ['MarcoJara_7',
#   'señores dejen de burlarse de los usuarios ya me he comunicado con su dm pero no resuelven nada se quedan callados pareciera que el interés de ustedes es desviar la discusión que pone en evidencia lo mala empresa que son'],
#  ['Santo90R',
#   'centro comercial santa fe en la ciudad de bogotá el guarda también impide el ingreso a los acompañantes de las personas de la tercera edad es el colmo'],
#  ['Check3891',
#   'he tenido muchos y no me interesa si cambian o no me da embarrada la gente que tiene cuenta en ese banco gracias luis'],
#  ['mrugeles',
#   'resolví mover mi cuenta de nómina a otro banco no tiene sentido tener una cuenta de ahorro en un banco y creditos en otro en bancolombia siempre ha sido un problema el tema de solicitar créditos se demoran mucho o no responden'],
#  ['garrincha25', 'alguna falla en la app que no deja transferir dinero'],
#  ['Richardortegar1',
#   'estamos llamando desde la semana pasada a la sucursal telefónica y ninguna opción es validad'],
#  ['Richardortegar1',
#   'mi esposa está intentando ingresar a la app pero no recuerda la clave'],
#  ['Richardortegar1', 'por favor se pueden comunicar con mi esposa 3046121174'],
#  ['Richardortegar1', 'necesitamos cambiar la clave personal'],
#  ['Claudiagelvez16', 'buenos días cuando dice dm que página es'],
#  ['inruc', 'quién castiga a los que se dedican al'],
#  ['inruc', 'consejo número un no ahorre en bancolombia'],
#  ['Juanguis3', 'bancolombia lavándose las manos como siempre'],
#  ['OdioLasSopas',
#   'su chat no sirve para nada pido asesor y finalizan el chat'],
#  ['JohanOquendo3',
#   'esta llegando este correo lo reporte en correosospechoso@bancolombia com co y es una estafa no lo abran no den ningún dato inmediatamente lo reportan y lo eliminan'],
#  ['Sergi0_Sanchez', 'correosospechoso@bancolombia sin com co o loquesea'],
#  ['midasmckalister', 'ahí están en las fotos'],
#  ['Bryangels',
#   'hola kevyn pude llamar a la línea de fraudes antes de hacer cualquier otra cosa y ellos me indicaron el proceso a seguir pude darme cuenta del fraude de igual forma te comparto el correo que me llegó'],
#  ['DIARIO_DJK',
# ...
#  ['VladimirDavilaT',
#   'ya me comuniqué y dijeron que los intereses corrían si o si pero el documento firmado habla de congelar las cuotas y correr los créditos el tiempo no cobrado'],
#  ['nipeed',
#   'cerraron una sucursal en yopal por que no se le estaba amontonando los clientes estamos en tiempo de distanciamiento social'],
#  ['jhonmartinez', 'si'],
#  ['Catacorreagomez',
#   'como es posible que estoy haciendo un reclamo y el asesor me cuelgue cuando empiezo a nombrarle mis derechos'],
#  ['John_Rockdrgz',
#   'solo con un reclamo y le van a dar gerencia ah no así si me le quejo al que sea'],
#  ['angelaville03', 'se volvieron enemigos'],
#  ['lapopularmusic',
#   'inconforme decepción tristeza d ver una corporación de ladrones ladrones profesionales como el país lleno de corrupción'],
#  ['lapopularmusic', 'cual proceso uds no respetan ni a su madre'],
#  ['EriSawPer',
#   'andan mandando estos correos como si fueran ustedes hay manera de denunciar esas cuentas'],
#  ['lapopularmusic', 'delincuentes'],
#  ['VladimirDavilaT',
#   'mentirosos dijeron que congelarian las cuotas 3 meses créditos personales y 6 micros hoy están cobrando intereses de esos meses dicen que son atrasados sin abono al capital para quedar bien'],
#  ['lapopularmusic',
#   'sucedió que son unos putos ladrones 14 años manteniendo mis productos con ustedes 14 años y uds trabajan a sus clientes como ladrones putos mentirosos estafadores'],
#  ['lapopularmusic', 'putos mentirosos explotadores desgraciados'],
#  ['angelicacantor',
#   'no no tengo dudas pero no entiendo por qué volver a cobrar si ya probamos que no es necesario los bancos quieren ganar por todo lado podrían dar ejemplo'],
#  ['Lamorasinsuegra', 'mi café favorito ❤️✨'],
#  ['99jvbg',
#   'hola para abrir una cuenta de ahorros necesito monto de apertura soy venezolano con pep y pasaporte vigente'],
#  ['rativa_jhon', 'que es el dm'],
#  ['rativa_jhon',
#   'buenas tardes me han generado un descuento de mi cuánta de ahorros de 105000 sin explicación alguna'],
#  ['karokagudelo',
#   'la solución de la persona de servicio al cliente fue que llamara a poner la queja después de 2 horas el sistema si estaba lento para las quejas'],
#  ['GuerreroArley15', ''],
#  ['karokagudelo',
#   'pésimo servicio 2 horas y no me solucionaron absolutamente nada me van a generar cobros por errores de ustedes mismos y me hacen cobros de manejo de una tarjeta que no me han querido renovar'],
#  ['jonathan_avila_',
#   'buenas tardes que debo hacer para cancelar una cuenta de ahorros'],
#  ['VivianaBuor', 'ya les escribí'],
#  ['VivianaBuor',
#   'llegó este mensaje de correo y al ingresar a la plataforma apareció error fue en mi primer intento'],
#  ['VivianaBuor',
#   'siempre pasa lo mismo voy a revisar una referencia bancaria y se bloquea el usuario se bloqueó al primer intento de registro será que me pueden ayudar'],
#  ['pelaez2702',
#   'buenos días consulta si una persona tuvo inconvenientes con la justicia y ya no no puede abrir una cuenta de ahorros con el banco por estar en alguna lista lo consulto por qué una persona que conozco le paso ayer fue y le dijeron que no por eso'],
#  ['YAZMIN_CRUZ',
#   'buen día me informan que sucede con la fiducuenta intento consultarla y sale un error aparte que muestra saldo en 0'],
#  ['MaCamilaG',
#   'voy 42 min y contando en la línea de los cuales llevo 38 escuchando música de espera que falta de respeto y cómo cuelgo si puse que quería calificar la pésima atención'],
#  ['retadoresmtb',
#   'no me están dando solución le repito no he autorizado ningún débito'],
#  ['anambarrerap', 'la app está caída'],
#  ['Diana_nietodz2',
#   'ya lo hice y de ustedes me respondieron que es los que deben solucionar'],
#  ['retadoresmtb',
#   'para qué me citan al dm si me van a dejar en visto le recuerdo que me están robando 5 millones necesito solución urgente'],
#  ['Ricardoonoro', 'ya lo envíe luis sería bueno notificar a banco farabella'],
#  ['sonomandj',
#   'de nada sirve tener muchos de estos pacs s pero todos haciendo lo mismo que mamera de verdad buenos días para cliente no tengo cupo bancolombia'],
#  ['Ricardoonoro',
#   'buenos días me llegó por correo este correo de ustedes falso por favor revisarlo y mirar si pueden hacer algo para que los incautos no le roben de mi parte bloqueo estás cuentas ya no tengo cuenta con ustedes'],
#  ['juanpduke',
#   'llevo más de un mes tratando de que un papel salga con una dirección correcta ha sido imposible 8 horas perdidas al teléfono y en chats todos los asesores salen con excusas diferentes eso es ponerle el alma para aburrirlo a uno'],
#  ['retadoresmtb',
#   'ya fui a una oficina y me hicieron esperar 8 días para responder que no van a hacer nada'],
#  ['infractoresbga', 'les escribí por dm'],
#  ['LosBernal2', 'jajajajaja si vió habló el robot 😂😂😂😂😂'],
#  ['luedgor',
#   'hace 1 mes solicite tarjeta de crédito y está no ha llegado y lo peor es que a mi correo ya me llegó extracto he llamado 2 veces a la línea telefónica y no me solucionan'],
#  ['Umbrellatec',
#   'pagué el 2 de oct mi tarjeta directamente desde el dinero al siguiente dia se veia reflejado como pagado aunque uds no me dejaban hacer uso de los fondos hoy 8 de oct me dicen que la plata no ha entrado un mov negativo me van a robar de frente'],
#  ['muchilon',
#   'y es así como los delincuentes envían correos para engañar y robar a la gente por internet me bloquearon la cuenta que no tengo con bancolombia jajajajaja'],
#  ['JJPadillaG', 'buena aleja 🤣'],
#  ['LosBernal2',
#   'lo mas charro es que estas cosas que responden uno no sabe si son un robot o qué responden por acá cada pemdejada pero en la vida real no se hablan con el banco igual no resuelven'],
#  ['NyXio',
#   'súper déspotas las personas que trabajan en atención al cliente y lo mínimo que deberían enseñarle a los empleados es a identificarse ya que si la persona está dando información lo ideal sería poder verificarla definitivamente'],
#  ['NachoGreiffenst', 'definitivamente les quedó grande la app no pudieron'],
#  ['MichaelMarimon',
#   'un asco que le quiten servicios es injusto que no se pueda hacer una compra de cartera con los servicios del banco la solución es hacer un avance en la tv para cobrar un interés más alto gmf y comisión de avance'],
#  ['NathyGomezz', 'gracias'],
#  ['alexandrabejar5',
#   'llevo ya 3 meses esperando una respuesta esto no parece un banco sino el seguro social 😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😃😃'],
#  ['denizpm17',
#   'y para que invirtieron tanto dinero en la biometria dactilar es que acaso el se va a robar los dedos de otros que poco diligentes son en estas épocas y en todas deverdad que es el peor sistema de atención al cliente'],
#  ['Juanzonne',
#   'quisiera saber cuáles es el nombre de la asesora encargada de esta línea persona grosera y altanera no deja encuentra de satisfacción y le cuelga el teléfono a uno en mitad de la llamada y cuál es la forma de poder hacer una queja a esta persona'],
#  ['jupaquingo',
#   'están llegando estos correos a mi cuenta personal reviso mi app y no tengo ningún bloqueo consideró que es correo fraudulento'],
#  ['farkantos_', 'que tan real es este correo'],
#  ['NathyGomezz', 'ustedes ofrecen servicios de salud y para mascotas'],
#  ['GIOVANNICAICE',
#   'por favor cancelen quiero cancelar mi requerimiento tomaré el servicio con otro banco'],
#  ['Osvaldo51688807',
#   'app bancolombia a ala mano no funciona y ahora con plata y sin plata manda huevo y me dijeron q mejor sacaran la de daviplata apenasa saque el dinero de bancolombia me paso a daviviend'],
#  ['MicheloMarceles',
#   'son comunes este tipo de correos pishing que puede uno hacer frente a esto esa dirección no puede denunciarse'],
#  ['PnalLLANO', 'rt ya'],
#  ['AngelicAzulita', 'ya'],
#  ['jennp2603',
#   'proceso de activación de clave dinámica en la app bastante deficiente y doloroso para el usuario en ningún lado avisan q le bloquearán la clave por 2 horas después de activarla'],
#  ['yonatanruiz',
#   '3198287421 este número pertenece a su empresa me llaman y saben datos de mi tarjeta de crédito'],
#  ['Bancolombia',
#   'si conoces algún proyecto del sector agro o turismo rural que genere valor en su cadena productiva invítalo a postularse en la convocatoria de en campo para recibir mentorías financiación y otros beneficios para fortalecer su modelo de negocio ʘ⁞'],
#  ['Milo_dt', 'tiempo después pude realizar la transferencia'],
#  ['PedroMirandaT',
#   'jajajajajajajajajaja dizque hola mafaldo jajajajajajajajaja'],
#  ['sepinle',
#   'haciendo declaraciones de renta a 80 mil pesos que piensa la no hay posturas para hacer respetar y valorar la profesión ayuda'],
#  ['moises_tejada',
#   'los llame a su línea telefónica y no me dan ninguna solución inmediata y la culpa es al parecer es de ustedes que reverso el@pago a y por eso me va a suspender el servicio porque tengo que pagar doble ahora'],
#  ['arroyo1987', 'hola este mensaje es real'],
#  ['MaryAlarcon8',
#   'este es el mensaje que me sale voy a transferir a la fidecuenta'],
#  ['Elvenao_', 'tienen un dm'],
#  ['DJLUIS1892',
#   'esto es lo que me sale cada vez que intento pagar una cuota de mi tarjeta de crédito cómo esperan que uno cumpla si su app falla de esta manera pero para llamar y cobrar sí son veloces'],
#  ['MaryAlarcon8', 'traté de hacer una transferencia y no me dejó'],
#  ['JuanmRL3', 'el séptimo pago será en este mes de octubre'],
#  ['ErikaDuranOchoa', 'no estoy solicitando nada saludos'],
#  ['Mirage_roJo',
#   'ojo con este número que está llamando en su nombre proponiendo devoluciones de efectivo y cuantas fantasías más 👍👍'],
#  ['shoyos4',
#   'espero que me alléguen el proceso disciplinario o las medidas tomadas respeto al caso'],
#  ['_DJBG',
#   'quiero seguir manejando la clave dinámica por correo electrónico no tengo en el teléfono y tampoco quiero instalar la aplicación que pasos debo de seguir'],
#  ['jhocor', 'menos mal no tengo productos con ustedes'],
#  ['DavidSa79633823',
#   'ya hice todo eso ya hablé con 4 asesores en 2 días y nada la página no funciona que es lo que pasa'],
#  ['YerlisEstor',
#   'todo el día pasa así entonces no creo que esté funcionando con “normalidad”'],
#  ['DavidSa79633823',
#   'me reporta error tiga001 al tratar de activar la tarjeta débito llevo 3 días intentando en la página'],
#  ['MaryAlarcon8', 'la app está caída'],
#  ['Vivicastillo91', 'gracias ya reenvié el correo'],
#  ['__barataria',
#   '20 minutos esperando una clave dinámica ¿la están enviando por 4 72 o qué'],
#  ['Macdiaz13', 'y que es dm'],
#  ['PaulaPuertaH',
#   'me gustaría saber si la app tiene una funcionalidad para buscar establecimientos cercanos que sean'],
#  ['Bancolombia',
#   'reportando esta información que te llegó recuerda adjuntar todos los soportes te invitamos para que ingreses al siguiente enlace y conozcas más sobre seguridad que tengas una linda tarde jacke'],
#  ['Bancolombia',
#   'que suplantan la imagen del banco ten presente que nosotros nunca enviamos enlaces ni solicitamos datos personales a través de estos canales te solicitamos que envíes un correo electrónico a la siguiente dirección correosospechoso@bancolombia com co'],
#  ['Juancma29',
#   'veo con preocupación que me llega un correo de phishing pero en esta ocasión me llega directamente a mi correo no a un grupo en especifico solicito que se investigue por qué mi correo personal está filtrado lo raro es q el correo desde donde lo envían es falabella'],
#  ['fenixlouis',
#   'que triste saber que no se puede confiar en este banco debitan el dinero de la cuenta sin autorización un verdadero fraude solicito estudio de mi caso y devolución del dinero ya'],
#  ['FabianC36203154',
#   'no puedo entrar a etrading en linea porque me figura una cuenta de invesbot en vez de mi cuenta original y no puedo cambiarla'],
#  ['Zuheydy2',
#   'me gustaría saber que pasa con el aporte del ingreso solidario se están tirando la pelotita entre prosperidad social bancolombia y nequi lo único que quiero saber es cuál es el inconveniente'],
#  ['Juampiqbillos',
#   'ustedes que control tienen sobre sus bases de datos me llega un correo diciendo que han bloqueado mi tarjeta que entre a un link y resultó ser un sitio inseguro hace unos días recibí una llamada dónde pretendían que les diera la fecha de vto de la tarjeta ojo'],
#  ['MDGA50',
#   'ahora me sale este error no me permite hacer ninguna transferencia ayuda'],
#  ['jhocor', 'pendientes clientes quieren robar datos con un correo falso'],
#  ['Bancolombia',
#   'com co com co reenvía el correo que te llegó a nuestro email correosospechoso@bancolombia com co te saluda luis'],
#  ['gerardbermon',
#   'limpio pero si visualmente está saturada de cosas parece un neceser'],
#  ['alexcast5000',
#   'que farsa de aplicación llevó varios días tratando de hacer un trámite y no sirve para nada nadie responde'],
#  ['alexandrabejar5',
#   'rt estoy escribiendo al dm allí pero no obtengo respuesta 🤔🤔🤔🤔🤔🤔🤔🤔🤔🤔🤔🤔🤔🤔🤔🤔🤔🤔🤔'],
#  ['alexandrabejar5',
#   'rt que moral 😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡'],
#  ['Jonalex_r',
#   'me están enviando información fraudulenta por favor indiquen un canal para denunciar'],
#  ['alexandrabejar5',
#   'que moral 😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡'],
#  ['danacarito', 'ya les escribí pero cómo raro sin soluciones'],
#  ['laverde1976',
#   'no me atrevo a enviar al whats app pero esto me llegó hoy no tengo productos con ese banco'],
#  ['danacarito',
#   'llamó abancolombia a cancelar una tarjeta de crédito pues no la quiero más primero un asesor dice que no tiene línea llamó de nuevo y me dicen que sólo si verifican mi identidad la cancelan apenas me verifican dicen que no me escuchan y cuelgan'],
#  ['alexandrabejar5',
#   'estoy escribiendo al dm allí pero no obtengo respuesta 🤔🤔🤔🤔🤔🤔🤔🤔🤔🤔🤔🤔🤔🤔🤔🤔🤔🤔🤔'],
#  ['danacarito',
#   'llamó abancolombia a cancelar una tarjeta de crédito pues no la quiero más primero un asesoró dice que no tiene línea llamó de nuevo y me dicen que sólo si verifican mi identidad la cancelan apenas me verifican dicen que no me escuchan y cuelgan'],
#  ['paola_monroy87',
#   'para consignaren no se puede entrar al banco te obligan a salir a la fila de la peatonal por una ficha para entrar a la misma puerta del banco donde estaba al llegar donde esta la seguridad'],
#  ['LuisVasquz92',
#   'respetuosamente les reporto ataques cibernéticos con suplantación de la razón social de bancolombia'],
#  ['alexandrabejar5',
#   'rt buen día cuando será que me colaboran con la refinanciación de mi producto ya llevo 3 meses rogándoles y no han querido gestionarme unas cuotas que yo pueda pagar 😡😡😡😡😡😡😡 todas las veces que me llaman dicen que aún no sale la respuesta'],
#  ['alexandrabejar5',
#   'buen día cuando será que me colaboran con la refinanciación de mi producto ya llevo 3 meses rogándoles y no han querido gestionarme unas cuotas que yo pueda pagar 😡😡😡😡😡😡😡 todas las veces que me llaman dicen que aún no sale la respuesta'],
#  ['agromerchant', ''],
#  ['agromerchant', ''],
#  ['ramiochoa', 'ya'],
#  ['mayitosama',
#   'señores no es que no sepa cómo usarla lo sé y la uso el problema es que es un enredo demasiados pasos para una información muy visual y poco útil demasiada información inútil demasiados pasos para una transacción sencilla la anterior era más sencilla'],
#  ['ramiochoa',
#   'bancolombia que sucede con las transferencias internacionales desde ayer estoy tratando y nada es urgente'],
#  ['AlcazarAlcides', 'eso es lo q nose'],
#  ['icgoco',
#   'acabo de llamar y me dicen que tienen incidencias en el sistema que ni para poner la queja les sirve este banco es inservible'],
#  ['Sierritafede8',
#   'mientras los clientes que se defiendan como puedan increíble'],
#  ['tratra690',
#   'estoy en bogotá entonces no hay pico y cédula estoy en lo correcto'],
#  ['NAGOCORREA',
#   'buen día sebastián ya mire en la página de ingreso y si soy beneficiario como pasó al dm gracias'],
#  ['NAGOCORREA',
#   'como es eso q los giros los hicieron entre el 29 y 30 de sept yo estuve en pendiente y me decían q no habían autozado los pagos'],
#  ['JazLucia3',
#   'buenos días el mismo día respondí las preguntas favor revisar'],
#  ['JazLucia3',
#   'buenos días el mismo día respondí las preguntas favor revisar']]

# %% [markdown]
# - ## Replace the emojis for their names

# %%
import emoji # Emoji codes

# %%
def replace_name_emoji(list_text): # function that replaces emoticons by their names
    list_name_emoji = []
    for l in list_text:
        name_emoji = emoji.demojize(l, delimiters=(' ', ' '))
        list_name_emoji.append(name_emoji) 
    return(list_name_emoji)

# %%
tweets = replace_name_emoji([text[i][1] for i in range(len(text))])
tweets = [tweets[i].replace("_"," ") for i in range(len(tweets))]
text = [[users[i],tweets[i]] for i in range(len(users))]
text
# Out:
# [['Mimi_UVasquez',
#   'el ya radicó la queja lo que hago es avisar a mis amigos de redes que su app es super insegura'],
#  ['fredysend',
#   'ya no pudieron eso es de hace mucho tiempo toco llevarnos la cuenta empresa para otro banco muy regulares en todos los aspectos'],
#  ['LuchoCandanoza', ''],
#  ['Mimi_UVasquez',
#   'varios amigos me reportan que la actualización de la app es muy insegura ayer a un amigo le robaron un iphone y seguido de eso le robaron dinero de su cuenta bancaria por transferencia desde la app pilas con eso'],
#  ['betoacevedo',
#   'rt encontré con sorpresa la implementación de una dmp dentro del portal transaccional de personas quisiera conocer las políticas de manejo de datos digitales y que información nombrada con exactitud está guardando la dmp y para que la están utilizando'],
#  ['midasmckalister',
#   'señores llevan dañados los cajeros automáticos de la calera 8 días co de sus noches pésimo servicio cambien esas máquinas obsoletas'],
#  ['redactor24',
#   'paren ya su acoso ya les dije que no me interesa su cupo de crédito ¿cómo más hay que decirlo para que dejen de bombardearme con su publicidad telefónica y de mensajería'],
#  ['todoparati23', 'por que mi tarjeta débito no tiene cvv'],
#  ['Bancolombia',
#   'creemos más que nunca en su fortaleza y queremos acompañarlas a conseguir un mejor futuro por eso creamos la línea de crédito agro para todas una oportunidad para que puedan alcanzar sus sueños y tener un mayor bienestar'],
#  ['JehanAliC',
#   'y su mundo digital para facilitar su trámite imprima el documento llene a mano ponga su huella quien tiene huellero en su casa después escaneé les falta poner “por último radique en el banco”  rolling on the floor laughing  súper digital  clapping hands  thumbs up '],
#  ['caritoalegria91',
#   'la app de ustedes la mayoría del tiempo está fallando mala cosa'],
#  ['zerrrrrrep',
#   'malo el servicio en el banco físico y ni hablar del soporte por este medio ahí estoy esperando soporte hace horas …'],
#  ['midasmckalister',
#   'ustedes el mismo cuento de siempre escriba por dm lo concreto y lea todos los twittear es que los tres cajeros que hay en la calera llevan una semana sin funcionar'],
#  ['fredysend',
#   'es triste que cada quincena sea lo mismo con uds esa sucursal virtual caída estamos mamaos de eso'],
#  ['CAMT_1_4',
#   'encontré con sorpresa la implementación de una dmp dentro del portal transaccional de personas quisiera conocer las políticas de manejo de datos digitales y que información nombrada con exactitud está guardando la dmp y para que la están utilizando'],
#  ['mauriciorodas00',
#   'ya ajusto 20 llamadas en un solo día que fastidio de banco'],
#  ['jorgehestradag',
#   'pero entonces no es en este momento ha sido en varios momentos ya que el mismo error tanto desde sucursal personas o empresas lo he tenido en más de una oportunidad'],
#  ['cegatron89',
#   'le han estado cobrando el 4x1000 a mi madre desde que abrió la cuenta en diciembre y no se ha llegado a ese tope ¿lo hacen con todas las cuentas para pensión a padres de otros amigos le han realizado lo mismo'],
#  ['Daniieel1983', 'claro que si tatiana  winking face '],
#  ['davidescobar73',
#   'precisamente día de pago de nómina y la sucursal virtual empresas caída'],
#  ['Briam_Gutierrez',
#   'yo le llamaria falsa publicidad porque no estan dando este tipo de credito'],
#  ['AndresZ85755720', 'a qué horas se cae la app de bancolombia'],
#  ['Fg535',
#   'pueden hacer una bendita aplicación que no se muera cada quincena'],
#  ['Solano', 'gracias angie ya respondí por dm'],
#  ['linajarabo',
#   'cómo es posible que pague el total de mi crédito hipotecario hace más de 1 mes y ahora resultan cobrando sin saber qué es y nadie responde'],
#  ['edyjo_',
#   'gracias estefa eres muy amable sin embargo el tiempo se ha extendido más de la cuenta cuando la solución debió ser más oportuna temo que el banco me informes que mi dinero se perdió y me toque emprender un proceso judicial'],
#  ['edyjo_',
#   'muchas gracias por comunicarte conmigo estefa pero tu respuesta no satisface mis pretensiones es posible que me informes las causas o motivos de la demora en resolver mi caso'],
#  ['MotoRatona_',
#   'gracias aunque ni siquiera tengo productos con ustedes y eso lo hace aún más gracioso  face with tears of joy '],
#  ['Sebastian_G14',
#   'buenas tardes me podrían brindar asesoría realicé un pago de mi tarjeta de crédito mastercard que tengo con ustedes en el banco pero la pague desde la app de otro banco el pago salió y me confirmó pero la tarjeta en la app personas me aparece la deuda aún'],
#  ['MotoRatona_',
#   'claramente ya bloqueé la cuenta que envía esos mensajes me causa gracia que ni siquiera se esfuerzan en cambiar el dominio del remitente y dejan banco falabella  rolling on the floor laughing  rolling on the floor laughing  woman facepalming '],
#  ['davidmtnz27',
#   'ellos cajeros fallan y se quedan con la plata los aplicativos de consulta en el call center no funcionan de la personal cero actitud de servicio disculpen srs que les sirve'],
#  ['Eduardo34501436',
#   'buenas tardes bancolombia yo cobro por modalidad de giro con ustedes y hace 1 mes abrí una cuenta de ahorro a la mano en este pago que se aproxima ya me empezan a pagar x cuenta o me van a trasladar a supergiros gracias'],
#  ['Aliceresponde',
#   'por favor me confirma si el tiene el absurdo cobro por retirar de cajero en otras ciudades por favor explicar ese atropello cómo validar los topes de estas injustificadas y desmotivantes políticas de la banca en colombia'],
#  ['YAG_C', 'que ya la tengo inscrita'],
#  ['aldairvelasque1', 'yo te escribí por dm'],
#  ['dianymarr', 'no me solicitaron pago mínimo'],
#  ['aiztferonitro',
#   'deisyb si alguna vez te hace una marranada financiera recuerda muy bien este tw es un sentimiento de impotencia solo espero hacer lo posible para pagar y nunca mas volver a verlos la gente sabe que como banco no tienen nada que perder que nadie les pague'],
#  ['aldairvelasque1', 'reexpedición'],
#  ['rodolfo20961215',
#   'buenas tardes me gustaría saber el horario de atención de la sucursal en zipaquira gracias'],
#  ['MshadowsMCR',
#   'no amiguitos esas excusas ya no valen ustedes reflejaron las porquerias que son con los colombianos no les importo que muchos estuvieran endeudados otros pasando necesidades pero vaya uno no pague lo que ustedes dicen y verá asco de banco'],
#  ['TuConsonante',
#   'si lo lamentan pero no hacen nada para solucionar  face with rolling eyes '],
#  ['YAG_C',
#   'ya estoy inscrito estoy tratando de hacer un pago pero la clave dinámica no llega o llega media hora después cuando ya no sirve'],
#  ['super_chata',
#   'buenas tardes ya les respondí por dm toda la información q solicitan para q de manera inmediata me devuelvan mi dinero información que ustedes deben tener pero por su ineficiencia y para ganar tiempo se les hace más fácil que el cliente se las suministre'],
#  ['Adriana88541440', 'ajaaaaaaaaaaaajaaaaa'],
#  ['AnnieLaBanani',
#   'me ayudan tengo que activar una cuenta que abrí por medios digitales y no he podido'],
#  ['dianymarr', 'respondí por dm'],
#  ['Luret_',
#   'un crédito de libre inversión interpuse un dp con uno de sus asesores telefónicos después de que alguien de redes sociales me llamará y no pueden encontrar el requerimiento sin el número de radicado en pleno siglo xxi que empresa no puedo encontrar un radicado con otros datos'],
#  ['Felipextilla',
#   'la gerente dice que es el protocolo de bioseguridad le pregunto donde esta exhibido y dice lo tengo en el computador'],
#  ['Felipextilla',
#   'bancolombia sucursal parway media hora para que la gerente salga brava a atender y decir que nonabre la puerta no dejan entrar al banco'],
#  ['Luret_',
#   'es el 4to mes en donde estoy pagando los intereses de un periodo de gracia de 3 meses que no pedí hasta cuándo voy a pagar esos intereses'],
#  ['dianymarr', 'ya le escribí por dm espero su pronta respuesta'],
#  ['ElcoyoteLpez', 'reyes del pésimo servicio cambian para empeorar'],
#  ['YAG_C', 'hay problemas con clave dinamica'],
#  ['GustavierPB',
#   'buenos días una pregunta ¿que es el débito sucursal bancolombia y ¿cuánto e el monto máximo a descontar gracias'],
#  ['johanagt88', 'no funciona esa clave dinámica'],
#  ['VGLARA2', 'que fea mala lenta en 15na bancolombia muere'],
#  ['mauriciorodas00',
#   'cuando me acerco a sus oficinas a buscar una alternativa y me dicen que ya no hay turnos que llame que llame a los que me dicen que lo único que tengo que hacer es pagar qué fastidio de banco'],
#  ['mauriciorodas00',
#   'cuando llaman y me piden una cantidad de datos que cada llamada les tengo que suministrar para que la única información que dan es que o pago o me reportan qué fastidio de banco'],
#  ['betobaena27',
#   'quincena o fin de mes la plataforma caída que raro no  grinning squinting face  grinning squinting face  grinning squinting face  grinning squinting face  grinning squinting face '],
#  ['mauriciorodas00',
#   'cuando solo llaman y dice que si no pago me reportan como si en esta situación eso fuera realmente preocupante antes que otras prioridades qué fastidio de banco'],
#  ['Juli_abad89', 'alivio para ustedes será'],
#  ['ElBienhumorado',
#   'bla bla bla llevamos 5 veces hablando con el banco y no dan solución es un descaro'],
#  ['_danielmqz_', 'se llama camila'],
#  ['_danielmqz_',
#   'rt asuman su responsabilidad y dejen de robarle a la gente no sean descarados'],
#  ['YamitGarcia1', 'perdón que es dm'],
#  ['isa_garrido1', 'ya les escribí por dm'],
#  ['mauriciorodas00',
#   'con hasta 20 llamadas diarias de cobro y siempre se les dice lo mismo qué fastidio de banco'],
#  ['NestorLlanoSal1', 'vergüenza de banco ladrones con permiso para robar'],
#  ['isa_garrido1',
#   'necesito comunicarme vía telefónica con un asesor y no atienden las llamadas  weary face  weary face  que rabia el caos de'],
#  ['TavoAcevedo',
#   'me dieron hoy una respuesta por cierto carente de información para un evento que terminó ayer mejor dicho de nada sirvieron los canales de comunicación con ustedes'],
#  ['froyuc', ''],
#  ['ilegi2',
#   'rt que van a revisar si ya descontaron el dinero  woman shrugging light skin tone  acaso lo piensan devolver  woman shrugging light skin tone '],
#  ['ilegi2',
#   'rt no se preocupe me tomé el trabajo de ir hasta una oficina y ni soluciones ni respuestas claras cuando les pregunté por qué nunca me explicaron desde el principio el escenario real de la situación ustedes son un karma para el usario'],
#  ['Tico92588258',
#   'mala mala mala esa app siempre arroja error hasta para hacer el pago de un producto'],
#  ['froyuc',
#   'que es lo que pasa com esa app no sirve para nada ¿como novedad hoy tambien esta caída'],
#  ['ManuelEsp30',
#   'lo he dicho el banco más ladrón de colombia junto a los del nadie los controla roban a pueblo multiplican el dinero que usaron para comprar la presidencia y mantener el poder de hacer lo que quieran sin control'],
#  ['fabianacuna1',
#   'escribí hace rato y ahí me quedé igual que en las llamadas que ineptitud la cacha del culo estos pingos'],
#  ['OSCARACALDEROND',
#   'esto lo he realizado por dm en varias ocasiones y ha todos les explico y luego me dejan disque esperando respuesta del area encargada y así ha pasado casi 3 meses quiero que me contacte un asesor por vía telefónica'],
#  ['mauriciorodas00',
#   'indolentes y alejados de la realidad mundial acosan y lastiman la salud mental de sus clientes que fastidio de banco'],
#  ['MariadelCCB',
#   'siempre me mandan al dm para no darme ninguna respuesta exacta y correcta me habían dicho una cosa y hoy que llamo a preguntar por el radicado me dicen otra no se quién es más ratero si o'],
#  ['mauriciorodas00',
#   'deberles a ustedes es peor que matar un cura que karma que fastidio'],
#  ['mauriciorodas00',
#   'que desespero tener una mora con ustedes 15 llamadas al día para decir que pague respeten'],
#  ['fabianacuna1',
#   'yo llevo 9 llamadas a ese dizque centro de ayuda para cancelar una puta tarjeta de crédito que ni la tengo porque me cancelaron el plástico y no lo mandaron pero igual cobran la cuota de manejo después preguntan porque uno apoya los vándalos'],
#  ['ZulyMoz', 'para qué si no hay respuesta'],
#  ['MOISDI',
#   'es que cualquiera puede estrar a mi cuenta un día cualquiera y cogerme lo que les de la gana quien me dice a mi que no fueron ustedes ustedes se lavan las manos que seguridad le están brindando a uno uno no es adivino para saber que era 7n fraude en la semana m'],
#  ['OSCARACALDEROND',
#   'pido la respuesta formal a mi reclamo de reintegro de hace 2 meses y me envía un email con una respuesta de otro reclamo de hace 3 meses negligencia o burla'],
#  ['OSCARACALDEROND',
#   'estoy intentando que me envíen un email con la respuesta adjunta de un reclamo de hace 2 meses y mandan el email vacío es una burla o es negligencia del asesor pero igual no logro tener solución a mi reclamo'],
#  ['OSCARACALDEROND',
#   '3 llamadas a la línea de atención al cliente pero el asesor me deja esperando hasta que se corta la llamada y se pierde todo lo adelantado y lo peor es que los asesores no tienen el mínimo detalle para devolver la llamada y dar solución al problema del cliente'],
#  ['FitoHndz95',
#   'en el barrio san luis también pasa lo mismo de los dos cajeros sólo está funcionando uno frente al supermercado la canasta campesina'],
#  ['JoaoelJugador',
#   'perdone gustavo la palabra pero mas pendejo usted que no siguió pagando normalmente el tal alívio nunca existió porque simplemente debía seguir acumulando intereses sobre toda el capital desde el inicio cuando lo escuché me pareció la estupidez mas grande'],
#  ['aiztferonitro',
#   'me van a devolver es una pendejada escribir al interno no solucionan nada solo les preocupa la mala publicidad no van a solucionar nada'],
#  ['_art_hur__', 'cómo sería'],
#  ['Galaxy_Waltz', 'necesito ayuda por favor dm'],
#  ['MarianaSolano3',
#   'increíble que presten un servicio tan malo no son capaces de solucionar un problema que es de ellos ni siquiera respetan el tiempo de los clientes más de 15 llamadas para que me solucionen y nada pouting face  pouting face  el peor servicio en banca lo tiene'],
#  ['felipeszarruk',
#   'como puedo cancelar la cuenta sin ir al banco a través de la web'],
#  ['MOISDI',
#   'ya puse las quejas y ya me respondieron que no me podían responder que había sido víctima de un estafador pero quede muy triste que garantías y seguridad le brindan a uno sus cuentas'],
#  ['AHxb', 'son un chiste  face with tears of joy '],
#  ['NoSoyJuanPa',
#   'tiene una publicidad que dice esa app se convertiría en el empleado del mes  expressionless face  olvidaron que detrás de una app hay personas que programan piensan y trasnochan rocket  si una app es buena las personas son los las empleados del mes  red heart '],
#  ['Osyegaoc', 'hola ya el inconveniente fue solucionado'],
#  ['CamiloAlvarezB', 'le está poniendo el alma'],
#  ['JulianCatanoC',
#   'no se preocupe me tomé el trabajo de ir hasta una oficina y ni soluciones ni respuestas claras cuando les pregunté por qué nunca me explicaron desde el principio el escenario real de la situación ustedes son un karma para el usario'],
#  ['isislopez_1983',
#   'responda que uds le van quitando el dinero a la gente por cada movimiento con su propia plata'],
#  ['MrTangeles',
#   'como asi que solo responden por el 50 de la plata si el error fue 100 de ustedes'],
#  ['super_chata',
#   'hicieron cargo a mi cuenta por una compra en amazon la cual no fue procesada pero bancolombia me debitó el monto y no me lo ha devuelto en los teléfonos que dice debo llamar nadie se digna atender les agradezco procedan a devolver mi dinero de manera inmediata'],
#  ['jabernalv',
#   '¿ya resolvieron esta situación la respuesta debe ser asumir ustedes'],
#  ['oqs216',
#   'son campeones con el dinero de sus usuarios algo parecido sucede cuando los cajeros automáticos no entregan el dinero el usuario debe de esperar un día hábil para devolver el dinero pero cuando es el cliente que se demora un día ellos te cobran intereses'],
#  ['derianpt',
#   'llevo pidiendo días un extracto del mes de enero y siempre me envían el de febrero y marzo sean serios lo necesito urgente'],
#  ['FitoHndz95',
#   'cúcuta norte de santander y en el municipio de bochalema el ubicado parque central quedo atento a su respuesta'],
#  ['Camilo_S08', 'me están pidiendo datos de mi sitio de trabajo'],
#  ['jumacoac', 'les sobra una r en el correo'],
#  ['oliver_cepeda1',
#   'yo tengo un préstamo con sofi y no tengo empleo y siempre que me llaman me ofrecen ciertos alivios que realmente lo que me ofrecen es extender las cuotas con doble interés vivasos por cierto ya me tienen aburrido cada 3 días llamando'],
#  ['NANITOSHKA',
#   'alivios me hicieron préstamo 20mll en marzo comenzó la pandemia me dieron el alivio ahora ya van en 3 millones de intereses y me llaman xa financiar toda la deuda disque no me cobran un mes y los intereses por las nubes pido envíen estracto de intereses y nada'],
#  ['TrvlGrtAgn',
#   'bank in the world just like is the worst airline in the world how do these companies that provide shit service stay in business well it wont be much longer for avianca and maybe will be soon after service'],
#  ['TrvlGrtAgn',
#   'operates the worst bank in the world nothing ever changes with this crap bank today in victoria in pereira we waited over 2 hrs in line with hundreds of people and even though they accepted us on the line for hours the bank closed and they said no more people shit'],
#  ['FMejsal', 'ratas'],
#  ['elkarmahallegad',
#   'bancolombia roban por todos lados por tarjetas extranjeras cobran por transacción hasta 18 mil eso es un descaro ahora todas las arandelas que hacen para ir sacando dinero de cada cuenta un robo totál'],
#  ['Ruvemcho',
#   'y flypass cerrarán negociaciones con nuevos parqueaderos en bogotá y medellín  automobile  sport utility vehicle  que aceptarán este medio de pago sin contacto  high voltage  high voltage  actualmente los estacionamientos de oviedo y el aeropark  deciduous tree  deciduous tree  tienen el servicio disponible'],
#  ['Ruvemcho',
#   'movilizará 140 000 millones de dólares en servicios financieros en los próximos 10 años el anuncio se dio en el encuentro de la alianza global de inversores para el desarrollo sostenible de la onu lee aquí cómo se orientarán estos recursos  backhand index pointing down  …'],
#  ['fidelantoniomr',
#   'muy alegres ante la desgracia ajena que ustedes empeoran se les recomienda no ser tan festivos y más nuevos buscar soluciones en las que honren la confianza y la buena fe de quienes ponemos nuestro dinero en sus manos al menos para no lucir como cínicos'],
#  ['W4rr10rRo0t',
#   'lo paso por un sandbox y luego trato de notificarlo a pero como sus plataformas nunca sirven pues dejo así'],
#  ['camiloaafanador',
#   'rt para qué le van a devolver la plata díganlo enseguida o le va a repetir la misma información que ya le dieron y ya sabe'],
#  ['Bancolombia',
#   'esto lo puedes realizar en la configuración de tu dispositivo móvil saludos'],
#  ['MariaTeresaVaBa',
#   'no tienen en cuenta la posible reactivacion economica no todos son empleados del estado  pouting face  pouting face  pouting face  pouting face '],
#  ['JohanQC777',
#   'coloca la actividad económica 0090 de rentista de capital ya que no hay una que indique que es sostenida por sus padres mentiras lee bien los ciiu previamente a tramitar el rut sino quieres es mas fácil aperturar nequi pero si te recomiendo luego migrar a un banco'],
#  ['pcerheguma',
#   'nunca fueron claros en las líneas telefónicas decían una cosa y por correo decían otra ante tanta incoherencia e información tan poco clara lo mejor era si se podía cancelar cualquier deuda'],
#  ['ChicleBoyacense',
#   'rt para qué le van a devolver la plata díganlo enseguida o le va a repetir la misma información que ya le dieron y ya sabe'],
#  ['handrs9010',
#   'de esta dirección me llegan bastantes correos informacion@mailgrupobancolombia com co'],
#  ['landito1', 'jajajajajajaja'],
#  ['billytontony',
#   'ahhhh bueno fue solo un problema de falta de claridad de información la próxima vez sean mas claros a la hora de desplumar a la gente'],
#  ['roberlucena', 'devuelvan el dinero'],
#  ['frankiko63',
#   'rt para qué le van a devolver la plata díganlo enseguida o le va a repetir la misma información que ya le dieron y ya sabe'],
#  ['AndresArboled_a',
#   'eso es lo único que hace bancolombia quitar el dinero cobrar mal dar mala información y ahora todos los usuarios están quedados menos mal están demostrando como son tendencia por mal banco y como están llegando competencias fuertes para tumbarlos no mas bancolombia'],
#  ['DanielSicAm',
#   'rt cuantos favs y condonan en su totalidad una deuda con ustedes'],
#  ['Mamertoid', 'hijueputas'],
#  ['Jojuanna', 'mil gracias'],
#  ['Dcaguirre97A',
#   'el sitio es de ustedes si sí muy extraño que requiera un login por fuera del sitio de sucursal virtual personas si no están enviando correos que tienen mala pinta'],
#  ['SergioLB12',
#   'es tendencia solocitar a empresas o personas determinada cantidad de me gusta likes favs para obtener algo a cambio dicho esto ¿cuantos me gusta likes favs para condonar una deuda que tengo con ustedes'],
#  ['JPABLORODRIL',
#   'rt para qué le van a devolver la plata díganlo enseguida o le va a repetir la misma información que ya le dieron y ya sabe'],
#  ['dozurpe',
#   'yo tenia que abrir otra ventana de mi celular para ver la dinámica'],
#  ['TavoP_G', 'no sean ratas'],
#  ['DCaroCarambola',
#   'lo abro les mento la madre a los ladrones les pregunto por acá a ustedes cuál es el correo para informar lo del pishing ya luego lo reenvío y lo elimino'],
#  ['xmariana02', 'pero yo no trabajo mis papás me mantienen todavía jajj'],
#  ['himmelklavier',
#   'rt para qué le van a devolver la plata díganlo enseguida o le va a repetir la misma información que ya le dieron y ya sabe'],
#  ['rolo_del',
#   'rt para qué le van a devolver la plata díganlo enseguida o le va a repetir la misma información que ya le dieron y ya sabe'],
#  ['PalmSolangel',
#   'esa manía de ustedes de querer obligarlo a uno a inscribir las facturas para pagar a través de la sucursal virtual ahora la famosa clave dinámica desde la app no sirve no sé por qué inventan tanto disappointed face '],
#  ['ElHombreDeLasR',
#   'depende si es un enlace porno le echo un ojito primero de rapidez y ahí sí lo borro  face with hand over mouth  face with hand over mouth  face with hand over mouth '],
#  ['ATurmewhat', 'en pocas palabras ratas  mouse '],
#  ['xmariana02',
#   'les pregunté por acá si necesitaba el rut para crear la cuenta y me dijeron que me tenía que acercar a una sucursal física para que allá me dijeran si era necesario o no'],
#  ['IsabelMTaborda',
#   'no me ha querido servir en todo el día  face with rolling eyes  woman facepalming light skin tone '],
#  ['fidelacorrea',
#   'que falta de honestidad del banco y de la persona que recibió el dinero por error que  face screaming in fear  face screaming in fear  face screaming in fear  angry face  angry face  angry face '],
#  ['lajana9090',
#   'pura mierda congelaron el cobro de los créditos pero los intereses crecían como si el cliente hubiera dejado de pagar porque sí troncos de rateros a mí me quitaron 500 mil y punta de interés'],
#  ['Bancolombia',
#   'la mejor forma de protegerte del phishing es identificar si es una estafa para hacerlo reenvíalo a corrreosospechoso@bancolombia com co estos son 3 elementos que podrás encontrar en este tipo de correos ʘ˧'],
#  ['fidelacorrea',
#   'demasiado cínismo  face screaming in fear  face screaming in fear  face screaming in fear '],
#  ['JAIRMETALS',
#   'son unas ratas mejor busquen otro banco como colpatria o otros estos hp cobran 12 000 de cuota de manejo y sin importar la pandemia ratas hp'],
#  ['maupovi75', 'rt ratas hijueputas abusando de la gente'],
#  ['maupovi75', 'ratas hijueputas abusando de la gente'],
#  ['nancho85',
#   'buenas tardes mi esposa y yo tenemos cuentas de ahorro de bancolombia y manejamos un solo celular yo ya tengo registrado la clave dinámica con mi cuenta se puede registrar también la cuenta de mi esposa con el mismo celular no tenemos más celular que hacemos'],
#  ['JJoseTrujillo',
#   'responde por eso tal vez el cajero y su gerente para no ponerse en evidencia ante medellin tratan de resolverlo ellos pero la central del banco responde por todo seguro obvio hay perjuicios pero el capital no se pierde duerma tranquila'],
#  ['SergioLB12',
#   'cuantos favs y condonan en su totalidad una deuda con ustedes'],
#  ['ginac0723',
#   'le ha bloqueado la cuenta 2 veces a mi mamá no la deja hacer transferencias pagos o lo que sea pero sí reciben la plata que le envían a ella y fue a solucionarlo le cambiaron la tarjeta y al otro día la misma mierda a qué juegan'],
#  ['MayoVGil',
#   'les contacte primero por los canales internos y es muy molesta la respuesta de sus asesores toman decisiones unilaterales siempre sin pensar en las personas'],
#  ['ncojack_JP',
#   'buen dia a mi me han llegado correos parecidos diciendo que digite mi documento para saber el extracto'],
#  ['romnyd', 'seguro me invente la falla'],
#  ['jpradach1', 'no carolina nada qué hacer'],
#  ['romnyd',
#   'otra vez su plataforma de pse fallando como si no fuera importante tener el soporte de pago'],
#  ['QueMamera_',
#   'daniel el inconveniente te lo estoy mostrando en la imagen saludos'],
#  ['edyjo_',
#   'ya me he comunicado con anterioridad y en múltiples ocasiones por dm por email por línea telefónica y no pasa nada si de verdad quiere deme indicaciones de la queja y'],
#  ['frajobehi',
#   'un iphone 12 pro plus max xt por favor con la cuota de 9 900 gracias'],
#  ['Bancolombia',
#   '1 si el asunto es urgente el destinatario no concuerda y te piden descargar archivos elimínalo \u200b 2 si parece ser del banco y te pide clave usuario y número de la tarjeta reenvíalo a correosospechoso@bancolombia com\u200b ʘ˧'],
#  ['alexagat',
#   'hola cada que marcó al 5109000 me aparece davivienda y no tengo ese número guardado con nombre de davivienda'],
#  ['MRCHIKIP',
#   'no loren por privado lo vacilan a uno y se hace lo que uds quieran y como uds quieran es mi dinero y deberian sostener las garantias que me ofrecieron al momento de adquirir el producto prefiero cancelar mis productos con uds y presionar la empresa para me pague con otro banco'],
#  ['fcoramna', 'estaremos observando cualquier cosa gritas'],
#  ['MRCHIKIP',
#   'de repente y sin autorizacion cambian mi plan de cuenta como les da la gana cobrando extra y me lo tengo que tragar si toca que la empresa me pague la nomina en cheque o en monedas pues lo acepto pero esa cuenta se cancela'],
#  ['sehuanes_felipe', 'muchas gracias por la información'],
#  ['Camo__Oficial',
#   'y me siguen llamando del 304 550 3348 no quedo claro ayer que no quiero recibir mas este tipo de llamadas no me interesa por que vendieron mis datos'],
#  ['faja9498',
#   'ni lo recomendaría a bancolombia ni lo recomiendo fue el banco que se aprovechó de la necesidad de sus clientes en la pandemia para hacer de la suya'],
#  ['TavoAcevedo', 'ok ya escribí por interno'],
#  ['gorofox', 'buenas tardes hay inconvenientes con la app'],
#  ['Osyegaoc', 'ojalá lo implementarán'],
#  ['TavoAcevedo',
#   'a ver si por aquí responden ¿de cuánto es el descuento ¿cómo se accede a él'],
#  ['ValeriaMendezC',
#   'qué está pasando con la seguridad de información de los usuarios ya conozco 3 casos incluyendo el mío sobre el bloqueo de la cuenta porque alguien intentó meterse desde la sucursal virtual por favor expliquen lo que está sucediendo'],
#  ['jonyleonp',
#   'buenas tardes muchas gracias en la actualidad tengo dos crediagil y dos créditos tasa fija estoy sin trabajo desde el pasado mes de abril y quiero postularme al congelamiento de la deuda hasta dic es posible ante la incapacidad de pago'],
#  ['mariselacasalla', 'no he podido enviar el mensaje dm'],
#  ['mariselacasalla',
#   'el peor servicio de bancolombia solo atienden por línea telefónica y dicen que espere su llamada y llevo 5 meses esperando que me llamen'],
#  ['luiskgomezc',
#   'que servicio tan malo de sus cajeros electrónicos la mayoría de las veces que voy no sirven ¿entonces para qué están lo que hace le hace a uno perder el tiempo  pouting face '],
#  ['AndreaSndoValle', 'hola ya respondí por dm espero pronta solución gracias'],
#  ['OliverS66063224', 'eso me llego hoy'],
#  ['RichiRojasL',
#   'estoy esperando su respuesta por dm nuevamente me acabaron de llamar a preguntar por alguien que no soy yo'],
#  ['LizPater17',
#   'asuman su responsabilidad y dejen de robarle a la gente no sean descarados'],
#  ['Jojuanna', 'quisiera saber si esta información es verdadera gracias'],
#  ['jpradach1', 'pues ya estoy en dm'],
#  ['Alejoeplugg',
#   'hola muy buenas tardes santi me sale un error que me debo inscribirme a la clave dinámica pero lo raro fue que hace unas horas antes había hecho una transferencia y yo ya he llamado y he hecho el procedimiento para la clave dinámica me genera el problema muy seguido'],
#  ['jramirezc1984', 'esto es cierto o es algo anormal'],
#  ['MateoPaV', 'me llega este mensaje es verdad o es una estafa'],
#  ['FitoHndz95',
#   'el cajero del parque central del municipio de bochalema también presenta problemas y es el único que hay'],
#  ['FitoHndz95',
#   'es por el bien de todos que hago esa queja es muy molesto que siempre se vea la aglomeración de personas en los cajeros bancolombia y además se presta para que los amigos de lo ajeno hagan de las suyas faltan protocolos de bioseguridad por lo menos un antibacterial en los cc'],
#  ['Enero20b',
#   'para qué le van a devolver la plata díganlo enseguida o le va a repetir la misma información que ya le dieron y ya sabe'],
#  ['Lalupa33376573',
#   'el numero del celular que envío el mensaje es 316 334 66 30 para que tengan en cuenta y pongan en reporte esta modalidad de fraude gracias'],
#  ['FitoHndz95', 'cúcuta norte de santander'],
#  ['Lalupa33376573',
#   'hola buenos días en la mañana de hoy recibí un mensaje que dice así felicitaciones hoy movistar y bancolombia te felicitan por ser el ganador de 10 000 000 comunicate ya pbx 301248090 cdg 750 aut coljuegos y este es el numero donde me enviaron el mensaje a mi'],
#  ['Misslegsonfire', 'ya pude solucionar gracias los tkm'],
#  ['EvanyPonce', 'que servicio de porquería'],
#  ['claramejiacar',
#   'cómo sería para desbloquear mi ip y poder entrar a la sucursal desde mi wifi'],
#  ['DayanaJ86812013',
#   'buenos días sucede que aparezco en bancolombia beneficiada de ingreso solidario y no me han cancelado ningún giro'],
#  ['jonyleonp',
#   'apreciados señores tengo varios créditos con ustedes libreinv y crediágil y desde el mes de abril estoy sin trabajo podrían indicarme que debo hacer en este caso para acogerme al periodo de gracia hasta diciembre de acuerdo a la última circular de la s financiera'],
#  ['FitoHndz95',
#   'por la pandemia y mi labor no puedo estarme movilizando hasta allá a verificar esos códigos además tengo entendido que para eso tienen personal técnico me parece el colmo del descaro seriedad por favor'],
#  ['FitoHndz95',
#   'cc unicentro sólo sirve 1 o 2 cc jardín plaza 1 de 4 cc ventura plaza solo sirve 1 barrio san luis solo sirve 1 av libertadores más abajo del cai niza 1 de 4 av cero al lado de mkgusto solo sirven 2 y en el parque central de bochalema el único que hay dañado'],
#  ['oscar_concha',
#   ' raising hands  raising hands  raising hands  thumbs up  thumbs up  Colombia  Colombia  Colombia '],
#  ['sarita_abad', 'nos van asesorar sobre sus utilidades en la pandemia'],
#  ['oscar_concha',
#   'acabo de hacer un pago a por un dispositivo nunca usado y la clave dinámica en el celular funcionó perfectamente sencilla y segura'],
#  ['alejand65379810',
#   'estan respondiendo vainas locas que no concuerdan ni con la fecha de compra no saben donde estan parados  pouting face '],
#  ['Camiburgosp', 'los odio'],
#  ['alejand65379810',
#   'privado para que para que no se den cuenta lo ratas que son ustedes'],
#  ['PiliCorreaZ',
#   'llevo tres días intentando realizar una transferencia y me indican que me comunique a la línea luego llamo a la línea y me informan que hay un incidente pero no dan información de qué se trata ni para cuando hay una solución para cuándo se soluciona el incidente'],
#  ['sabanerita1', 'ya les escribo'],
#  ['alejand65379810',
#   'señores tengo casi dos meses esperando un reembolso de dinero y aun nada se piensan robar la plata'],
#  ['Klovn', 'phishing llegó a mi correo'],
#  ['juanfelipemc25',
#   'cómo así que debemos migrar la clave dinámica a la app personas desde el 20 de octubre cómo hacen las personas que no tienen teléfonos inteligentes y todo lo haces es a través del pc me toca comprarle un celular a mi abuela para eso o uds se lo regalaran'],
#  ['Luzmari03586318', '3125080487'],
#  ['Jennyg7',
#   'entiendo esto pero no me importaría tener un rechazo y generar nuevamente el pago como en otras entidades bancarias es absurdo tener que esperar 3 días para hacer un pago urgente'],
#  ['Jennyg7',
#   'gracias pero ayer llame al banco y ya me aclararon la información y me dijeron que se demora hasta tres días la inscripción de una cuenta a otro banco y pues nada me toca salir hoy a retirar y desplazarme hasta el otro banco para hacer la consignación que ayuda en la pandemia'],
#  ['Jennyg7',
#   'a mi me parece terrible que inscribir una cuenta de otro banco se demore hasta 3 días y más cuando uno la necesita hacer urgente este es único banco que me encuentro que hace esto y realmente es molesto'],
#  ['sarita_abad',
#   'que van a revisar si ya descontaron el dinero  woman shrugging light skin tone  acaso lo piensan devolver  woman shrugging light skin tone '],
#  ['Jennyg7',
#   'ayer al mediodía inscribí una cuenta para hacer un transferencia urgente y esta es la hora que la cuenta no ha quedado inscrita me parece el colmo que me digan que se puede demorar hasta tres días respeten que la necesito hacer urgente soy nueva en bancolombia y no me gusta'],
#  ['Jennyg7',
#   'ayer al mediodía inscribí una cuenta para hacer un transferencia urgente y esta es la hora que la cuenta no ha quedado inscrita me parece el colmo que me digan que se puede demorar hasta tres días respeten que la necesito hacer urgente soy nueva en bancolombia y no me gusta'],
#  ['JaimeACastro5',
#   'banco llamé el viernes a cancelar una tarjeta de credito virtual me dijeron que la cancelación se vería reflejada en 1 día hábil hoy miercoles sigo viendo activa esa tarjeta necesito cancelarla antes de que me cobre manejo colaborenme por favor'],
#  ['linajarabo',
#   '1 mes sin solucionar lo del pago total a mi crédito hipotecario quieren más plata quieren robar más'],
#  ['linajarabo',
#   'llevo más de 1 mes sin solucionar mi pago de crédito hipotecario que más quiere robar'],
#  ['nfrancovel',
#   'quiere decir que van a dejar a lod adultos mayores sin posibilidad de que les ayudemos a hacer sus pagos ya pensaron en ese segmento de clientes son clientes que no usan la app ni la van a usar uds los están obligando a salir a un banco y nos quitan la posibilidad de ayudarlos'],
#  ['edmartinezm',
#   'tu atención al cliente es horrible y tu app es lenta e inoperante como proceso burocrático'],
#  ['FitoHndz95',
#   'espero que con ese mismo fervor y patriotismo se encarguen de arreglar los cajeros en cúcuta en todos los cc y en general muy pocos sirven y se aglomera la gente por su culpa sean serios y respeten los usuarios'],
#  ['wrusinque',
#   'vamos tigre gracias bancolonbia por ser patrocinador de la selec'],
#  ['AidaDia34410791',
#   'al consultarme me sale esto no entiendo porque dicen que ustedes no me pagan si mis primeros 4 giros los cobre con ustedes'],
#  ['Marivelezo1', 'falcao te mereces otro hijo'],
#  ['mariale714',
#   'esperanza la que yo tengo de que no empiecen a cobrar las transferencias a otros bancos para robar más plata'],
#  ['tefaniaa26',
#   'vieron ese gol jajaja eso merece que no le cobren tasa nominal en el mes de octubre  hundred points  victory hand  Colombia '],
#  ['Marivelezo1', 'grande falcao tigre de tigres'],
#  ['CataUribeLopez', '4'],
#  ['daniarenas',
#   'me gané mi primera polla  yellow heart  yellow heart  blue heart  red heart '],
#  ['EdwinGutierrezT',
#   'ustedes procuren mejorar la aplicación que bien lenta si está'],
#  ['AlejitaLopezC', '6'],
#  ['saraduquelpz',
#   '6  index pointing up medium-light skin tone  index pointing up medium-light skin tone '],
#  ['ClienteBanistmo', '5  flexed biceps light skin tone '],
#  ['dokhrates', 'ladrones'],
#  ['MonsalveAcevedo',
#   '2  backhand index pointing up  folded hands medium-light skin tone  red heart '],
#  ['laurajp7', '5  flexed biceps '],
#  ['CuervoMan_',
#   'obviamente no están teniendo en cuenta a estos 10 millones de hijueputas que grandes'],
#  ['PadresEHijos9',
#   'arreglen esa porquería de app en vez de estar twiteando maricadas'],
#  ['Marivelezo1', '5 vamos por el empate'],
#  ['Richienator', '1'],
#  ['CuervoMan_',
#   'rt en su comercial dice que vuelven a latir 40 millones de corazones y los otros 10 millones  pleading face '],
#  ['Cris_Quintero', '1  raising hands '],
#  ['DanielaMacias01', '1 a echarle cabeza mijos thinking face  thinking face '],
#  ['__sebastian_o_d', '1 cabeza fría'],
#  ['phelipeRz', 'no es cierto'],
#  ['lopezsalexander', '7'],
#  ['cloiinunez', 'y esto que es de nuevo app bancolombia caida'],
#  ['cloiinunez', 'otra vez caida la app de bancolombia'],
#  ['AHxb', 'rt ladrones'],
#  ['phelipeRz',
#   'hoy se anotó dos golazos en mí cuenta debitandome sin mí permiso 200 000'],
#  ['dokhrates', 'ladrones'],
#  ['OscarTrejos9',
#   'promocionando fútbol mientras las personas que tienen su dinero en tienen que hacer enormes filas en cartago bajo el inclemente sol soportando por horas temperaturas superiores a los 30° pésimo y nefasto servicio'],
#  ['dokhrates', 'ladrones'],
#  ['phelipeRz',
#   'me acaba de debitar 200 000 sin justificación alguna y no me dan razón en la línea telefónica ¿ahora sus formas de ganar utilidades es literalmente robándole al ciudadano'],
#  ['nanita821117',
#   'dudas no tengo pereza de usarla pero pues toca porque uds no escuchan a los usuarios hay algo fundamental en el diseño de cualquier cosa y es la usabilidad parece que los diseñadores de su app desconocen el término'],
#  ['paoz08', 'solucionado gracias'],
#  ['lfsantanam', 'me están llegando estos mensajes al correo'],
#  ['Eyarce',
#   'y flypass cerrarán negociaciones con nuevos parqueaderos en bogotá y medellín  automobile  sport utility vehicle  que aceptarán este medio de pago sin contacto  high voltage  high voltage  actualmente los estacionamientos de oviedo y el aeropark  deciduous tree  deciduous tree  tienen el servicio disponible'],
#  ['OlaveLigia',
#   'porque no me dan la opción de descargar certificado de crédito hipotecario lo requiero para declarar renta ya que no lo reportan en la rete fuente que me enviaron solicite por teléfono el documento dijeron que tardaba 6 horas aún no llega'],
#  ['bermzzy', 'me ha quitado más plata de la que saco'],
#  ['PilarAmayaJ', 'otra vez falla en la app no me deja trasferir'],
#  ['Nata1992m',
#   'todas sus campañas de alivio son una mentira si de la sucursal telefónica nos envían al punto físico no saben dar explicaciones es mentira sus alivios y hacen que los productos entren en mora para cobrar intereses'],
#  ['NestorTuran',
#   'ah claro me imagino que a él nunca se le ocurrió comunicarse con el banco'],
#  ['scastril',
#   'el banco que dice colocarle el alma a los colombianos más bien le está partiendo la madre a los colombianos'],
#  ['rubielagomez',
#   'o me solucionan la@situación o me encargaré de llevar esto hasta las últimas consecuencias mi hija viaja y la única tarjeta que tiene es con bancolombia y es un deber de axa expedirme el certificado de asistencia'],
#  ['rubielagomez',
#   'que el el dm otras 5 horas colgada al teléfono por qué sume que se que quiere decir ese término'],
#  ['rubielagomez',
#   'inaudito que una entidad tan prestigiosa como la de ustedes jueguen con el cliente de la forma como lo hacen llevo tres días solicitando certificado de viaje internacional y me ponen al teléfono 60 minutos y cuelgan la llamada es una obligación y lo exijo'],
#  ['Marcelalopezoc1',
#   'como es posible que he solicitado la cancelación de una tarjeta de crédito 3 veces con bancolombia y siempre me dan vueltas y me sacan peros y no finalizan el proceso esto es un atropello al consumidor'],
#  ['stvanss',
#   'cuanto hay que reclamar para que una persona le cancelen una tarjeta de crédito que ya no desea que tomadera de pelo es increíble'],
#  ['pmendez3',
#   'debo expresar públicamente que ante el problema manifestado y a pesar de estar en el exterior el equipo bancolombia me a contactado y me ha brindado un servicio de atención rápido y excelente quedo muy agradecido y espero muy pronto una resolución satisfactoria del caso'],
#  ['ArgenisJessSal1',
#   'me realizaron un giro desde canadá el día 01 del mes en curso a la fecha no se registra en mi cuenta debo ir a una oficina para retirar o puedo hacerlo consignar en mi cuenta por medios electrónicos'],
#  ['RichiRojasL',
#   'les dejé mis datos de contacto por dm espero que esta vez sí pregunten por mí'],
#  ['paoz08',
#   'que pasa con la aplicación que no aparece la clave dinámica y uno con afán de pagar sus obligaciones'],
#  ['GigiMendozaN', 'les envíe el dm hace 10 mins'],
#  ['GigiMendozaN', 'sucursal virtual web y móvil por ningún lado funciona'],
#  ['RichiRojasL',
#   'daniel es tu compañero yo soy ricardo he hablado durante un mes con personal de las áreas de servicio al cliente y conciliación y no tienen una solución quiero conocer los procedimientos de'],
#  ['malanarodriguez',
#   'porque no me deja ingresar con mi huella  exploding head  exploding head  exploding head '],
#  ['GigiMendozaN', 'enviado'],
#  ['MDCristian_mont',
#   'puedo saber por que me dejan esperando en linea mas de 1 hora esta es la segunda llamada q hago y me dejan en linea por q no puedo cancelar esa tarjeta de crédito del demonio ni tiempo también merece respeto'],
#  ['RichiRojasL',
#   'daniel ya lo he hecho y no me dan solución me dicen que esta persona debe actualizar sus datos él ya lo hizo pero ustedes no retiran mi número del sistema ya he hablado con el área de servicio al cliente y tampoco tienen una solución por eso le escribí a'],
#  ['Junior16748139', 'bobo aquel que caiga en sus trampas'],
#  ['amtribin',
#   'pues aún estoy esperando que me atiendan llamo a la línea de atención al cliente escribo al dm y nada absolutamente nada me han ayudado'],
#  ['Danielleml',
#   'me agenda citas para que sus agentes me llamen y me cuelguen  face with tears of joy  a ver si me contestan'],
#  ['pmendez3',
#   'que sea por el correo por la app ha sido mi peor experiencia pense que iba a ser mas facil y resulta que meto la clave que aparece y nunca es valida ya estoy estresado con esa situacion no puedo movilizar mi dinero'],
#  ['amtribin',
#   'yo llevo todo el día tratando de que me informen porqué me están cobrando 500 mil pesos por el congelamiento de mi crédito hipotecario y nadie me sabe explicar absolutamente nada esa es la ayuda que le dan a los colombianos'],
#  ['midasmckalister', 'cambien esas máquinas eso ya tecnología vieja'],
#  ['midasmckalister',
#   'ustedes tienen esa información ahorita me desplazo los 10 kilometros desde donde vivo que desgracia perder el tiempo con ustedes'],
#  ['Camo__Oficial',
#   'entonces porque me llaman a vender seguros de parte de una entidad relacionada con banclombia yo no les di permiso para eso'],
#  ['Hey__Carlitos',
#   'mary ya escribí espero pueda obtener una respuesta por este medio'],
#  ['Camo__Oficial',
#   'que hace con mis datos personales ¿por qué los venden a empresas que venden seguros quien regula esto la que inseguridad quien más tendrá mis datos'],
#  ['magils',
#   '¿es legal que me pida más datos personales como mi número de cédula para dejar de llamarme cuando no tengo ni tendré ningun producto con ellos'],
#  ['AbrahamDReyes', '¿donde puedo llamar'],
#  ['AbrahamDReyes',
#   'lo sentimos usted no está autorizado para marcar este número  person shrugging medium-dark skin tone '],
#  ['magils', 'ya les envié la información espero que no me llamen más cc'],
#  ['PachoChaverra', 'scar una tarjeta'],
#  ['magils',
#   'la única validación que tienen que hacer es eliminar mi número telefónico de su sistema'],
#  ['midasmckalister',
#   'señores es hora de cambien los cajeros de la calera por tecnología nueva las que están son maquinas obsoletas'],
#  ['Luzmari03586318',
#   'quiero saber si me enviaran mensaje de texto para cobrar mis giros por nequi freddy lizarazo'],
#  ['albahgarcia',
#   'lo que uds hacen con los adultos mayores es irresponsable el viernes tuvieron a mi papá adulto mayor 2 horas para abrir una cuenta de ahorros y desbloquear otra cuenta hoy le volvieron a bloquear sus cuentas la solución ir nuevamente al banco'],
#  ['MariaVGonzalezM',
#   'hasta cuando los abusos incumplen promesas y acuerdos te hacen pagar corriendo a “su tiempo” y nunca cumplen lo que se supone me “otorgaron” desde julio'],
#  ['midasmckalister',
#   'señores ustedes son lo peor como institución fuera la primera vez esto ocurre cada 8 dias'],
#  ['misspark8',
#   'la nueva aplicación es un problema no una ayuda para los clientes'],
#  ['agudelo_m',
#   'son sus políticas institucionales y las entiendo pero no las comparto me parece una falta de empatía que en semejante contingencia uno tenga que ir a ponerse en riesgo a una sucursal porque ustedes no aceptan abonos a capital por ningún otro medio'],
#  ['Silvanadiaz98', 'hola tati ya se arregló jejeje besitos'],
#  ['OdioLasSopas',
#   'llamo desde su página me tienen 20 minutos como una estúpida cuando por fin me atiende el que se supone me resuelve dice cliente no responde y yo a el lo escucho perfecto los odio como le van a bajar el rendimiento a una inversion porque sí'],
#  ['GabyEscalante5',
#   'el servicio de atención al cliente por teléfono es tan nefasto que marca una alguna de las opciones y lo que hacen es cancelar la llamada'],
#  ['lauragornzalez', 'me pasa lo mismo'],
#  ['Andresc_h',
#   'queremos que la app funcione bien y sin tanto error ya viene la quincena'],
#  ['shaka38',
#   'quieres saber de bugs en producción  rolling on the floor laughing   rolling on the floor laughing   rolling on the floor laughing '],
#  ['DianaOr50911680',
#   'seguridad bancolombia no brinda eso más de 15 días para devolverme 150 mil pesos que descontaron abusivamente de mi cuenta'],
#  ['ricardo18226532',
#   'no obliguen a la gente a abrir una cuenta para reclamar giros sucursales pereira si a alguien lo estan obligando ante quien puede poner la queja para q sancione el banco q gracias y a los lectores no usen giros bancolombia'],
#  ['alemon008',
#   'quisieras conocer buen servicio al cliente yo te puedo ayudar'],
#  ['Bancolombia',
#   'recuerda que ya no tienes que llamar a la línea telefónica para resolver tus dudas sobre la nueva app personas aquí te ayudamos a responder a todas tus preguntas ʘ˩'],
#  ['Bancolombia',
#   'respuesta \u200b cualquier transacción que hagas desde app personas se validará automáticamente ya no hace falta esperar a que te notifiquen para usarla ʘ˩'],
#  ['Bancolombia',
#   '¿si haces un pago desde app personas deberás esperar a recibirla por correo o mensaje de texto \u200b ʘ˩'],
#  ['Bancolombia',
#   'respuesta ¡es muy fácil entra desde tu celular a app personas y en el home podrás ver los 6 dígitos sin necesidad de ingresar tu usuario o clave ʘ˩'],
#  ['Bancolombia',
#   'si estás realizando un pago desde otro canal y te pide la clave dinámica ¿cómo puedes consultarla ʘ˩'],
#  ['Santo90R',
#   'qué hay una entrada específica y es por fuera del centro comercial'],
#  ['MarcoJara_7',
#   'si señores también ando en el dm esperando a que me hablen pero tampoco'],
#  ['MarcoJara_7', 'señores ya les hable por dm pero no hay respuesta'],
#  ['Santo90R',
#   'ya estoy realizando la transacción pero uds no pueden imponer más barreras especialmente para las personas de la tercera edad'],
#  ['MarcoJara_7',
#   'señores dejen de burlarse de los usuarios ya me he comunicado con su dm pero no resuelven nada se quedan callados pareciera que el interés de ustedes es desviar la discusión que pone en evidencia lo mala empresa que son'],
#  ['Santo90R',
#   'centro comercial santa fe en la ciudad de bogotá el guarda también impide el ingreso a los acompañantes de las personas de la tercera edad es el colmo'],
#  ['Check3891',
# ...
#  ['jonathan_avila_',
#   'buenas tardes que debo hacer para cancelar una cuenta de ahorros'],
#  ['VivianaBuor', 'ya les escribí'],
#  ['VivianaBuor',
#   'llegó este mensaje de correo y al ingresar a la plataforma apareció error fue en mi primer intento'],
#  ['VivianaBuor',
#   'siempre pasa lo mismo voy a revisar una referencia bancaria y se bloquea el usuario se bloqueó al primer intento de registro será que me pueden ayudar'],
#  ['pelaez2702',
#   'buenos días consulta si una persona tuvo inconvenientes con la justicia y ya no no puede abrir una cuenta de ahorros con el banco por estar en alguna lista lo consulto por qué una persona que conozco le paso ayer fue y le dijeron que no por eso'],
#  ['YAZMIN_CRUZ',
#   'buen día me informan que sucede con la fiducuenta intento consultarla y sale un error aparte que muestra saldo en 0'],
#  ['MaCamilaG',
#   'voy 42 min y contando en la línea de los cuales llevo 38 escuchando música de espera que falta de respeto y cómo cuelgo si puse que quería calificar la pésima atención'],
#  ['retadoresmtb',
#   'no me están dando solución le repito no he autorizado ningún débito'],
#  ['anambarrerap', 'la app está caída'],
#  ['Diana_nietodz2',
#   'ya lo hice y de ustedes me respondieron que es los que deben solucionar'],
#  ['retadoresmtb',
#   'para qué me citan al dm si me van a dejar en visto le recuerdo que me están robando 5 millones necesito solución urgente'],
#  ['Ricardoonoro', 'ya lo envíe luis sería bueno notificar a banco farabella'],
#  ['sonomandj',
#   'de nada sirve tener muchos de estos pacs s pero todos haciendo lo mismo que mamera de verdad buenos días para cliente no tengo cupo bancolombia'],
#  ['Ricardoonoro',
#   'buenos días me llegó por correo este correo de ustedes falso por favor revisarlo y mirar si pueden hacer algo para que los incautos no le roben de mi parte bloqueo estás cuentas ya no tengo cuenta con ustedes'],
#  ['juanpduke',
#   'llevo más de un mes tratando de que un papel salga con una dirección correcta ha sido imposible 8 horas perdidas al teléfono y en chats todos los asesores salen con excusas diferentes eso es ponerle el alma para aburrirlo a uno'],
#  ['retadoresmtb',
#   'ya fui a una oficina y me hicieron esperar 8 días para responder que no van a hacer nada'],
#  ['infractoresbga', 'les escribí por dm'],
#  ['LosBernal2',
#   'jajajajaja si vió habló el robot  face with tears of joy  face with tears of joy  face with tears of joy  face with tears of joy  face with tears of joy '],
#  ['luedgor',
#   'hace 1 mes solicite tarjeta de crédito y está no ha llegado y lo peor es que a mi correo ya me llegó extracto he llamado 2 veces a la línea telefónica y no me solucionan'],
#  ['Umbrellatec',
#   'pagué el 2 de oct mi tarjeta directamente desde el dinero al siguiente dia se veia reflejado como pagado aunque uds no me dejaban hacer uso de los fondos hoy 8 de oct me dicen que la plata no ha entrado un mov negativo me van a robar de frente'],
#  ['muchilon',
#   'y es así como los delincuentes envían correos para engañar y robar a la gente por internet me bloquearon la cuenta que no tengo con bancolombia jajajajaja'],
#  ['JJPadillaG', 'buena aleja  rolling on the floor laughing '],
#  ['LosBernal2',
#   'lo mas charro es que estas cosas que responden uno no sabe si son un robot o qué responden por acá cada pemdejada pero en la vida real no se hablan con el banco igual no resuelven'],
#  ['NyXio',
#   'súper déspotas las personas que trabajan en atención al cliente y lo mínimo que deberían enseñarle a los empleados es a identificarse ya que si la persona está dando información lo ideal sería poder verificarla definitivamente'],
#  ['NachoGreiffenst', 'definitivamente les quedó grande la app no pudieron'],
#  ['MichaelMarimon',
#   'un asco que le quiten servicios es injusto que no se pueda hacer una compra de cartera con los servicios del banco la solución es hacer un avance en la tv para cobrar un interés más alto gmf y comisión de avance'],
#  ['NathyGomezz', 'gracias'],
#  ['alexandrabejar5',
#   'llevo ya 3 meses esperando una respuesta esto no parece un banco sino el seguro social  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  grinning face with big eyes  grinning face with big eyes '],
#  ['denizpm17',
#   'y para que invirtieron tanto dinero en la biometria dactilar es que acaso el se va a robar los dedos de otros que poco diligentes son en estas épocas y en todas deverdad que es el peor sistema de atención al cliente'],
#  ['Juanzonne',
#   'quisiera saber cuáles es el nombre de la asesora encargada de esta línea persona grosera y altanera no deja encuentra de satisfacción y le cuelga el teléfono a uno en mitad de la llamada y cuál es la forma de poder hacer una queja a esta persona'],
#  ['jupaquingo',
#   'están llegando estos correos a mi cuenta personal reviso mi app y no tengo ningún bloqueo consideró que es correo fraudulento'],
#  ['farkantos_', 'que tan real es este correo'],
#  ['NathyGomezz', 'ustedes ofrecen servicios de salud y para mascotas'],
#  ['GIOVANNICAICE',
#   'por favor cancelen quiero cancelar mi requerimiento tomaré el servicio con otro banco'],
#  ['Osvaldo51688807',
#   'app bancolombia a ala mano no funciona y ahora con plata y sin plata manda huevo y me dijeron q mejor sacaran la de daviplata apenasa saque el dinero de bancolombia me paso a daviviend'],
#  ['MicheloMarceles',
#   'son comunes este tipo de correos pishing que puede uno hacer frente a esto esa dirección no puede denunciarse'],
#  ['PnalLLANO', 'rt ya'],
#  ['AngelicAzulita', 'ya'],
#  ['jennp2603',
#   'proceso de activación de clave dinámica en la app bastante deficiente y doloroso para el usuario en ningún lado avisan q le bloquearán la clave por 2 horas después de activarla'],
#  ['yonatanruiz',
#   '3198287421 este número pertenece a su empresa me llaman y saben datos de mi tarjeta de crédito'],
#  ['Bancolombia',
#   'si conoces algún proyecto del sector agro o turismo rural que genere valor en su cadena productiva invítalo a postularse en la convocatoria de en campo para recibir mentorías financiación y otros beneficios para fortalecer su modelo de negocio ʘ⁞'],
#  ['Milo_dt', 'tiempo después pude realizar la transferencia'],
#  ['PedroMirandaT',
#   'jajajajajajajajajaja dizque hola mafaldo jajajajajajajajaja'],
#  ['sepinle',
#   'haciendo declaraciones de renta a 80 mil pesos que piensa la no hay posturas para hacer respetar y valorar la profesión ayuda'],
#  ['moises_tejada',
#   'los llame a su línea telefónica y no me dan ninguna solución inmediata y la culpa es al parecer es de ustedes que reverso el@pago a y por eso me va a suspender el servicio porque tengo que pagar doble ahora'],
#  ['arroyo1987', 'hola este mensaje es real'],
#  ['MaryAlarcon8',
#   'este es el mensaje que me sale voy a transferir a la fidecuenta'],
#  ['Elvenao_', 'tienen un dm'],
#  ['DJLUIS1892',
#   'esto es lo que me sale cada vez que intento pagar una cuota de mi tarjeta de crédito cómo esperan que uno cumpla si su app falla de esta manera pero para llamar y cobrar sí son veloces'],
#  ['MaryAlarcon8', 'traté de hacer una transferencia y no me dejó'],
#  ['JuanmRL3', 'el séptimo pago será en este mes de octubre'],
#  ['ErikaDuranOchoa', 'no estoy solicitando nada saludos'],
#  ['Mirage_roJo',
#   'ojo con este número que está llamando en su nombre proponiendo devoluciones de efectivo y cuantas fantasías más  thumbs up  thumbs up '],
#  ['shoyos4',
#   'espero que me alléguen el proceso disciplinario o las medidas tomadas respeto al caso'],
#  ['_DJBG',
#   'quiero seguir manejando la clave dinámica por correo electrónico no tengo en el teléfono y tampoco quiero instalar la aplicación que pasos debo de seguir'],
#  ['jhocor', 'menos mal no tengo productos con ustedes'],
#  ['DavidSa79633823',
#   'ya hice todo eso ya hablé con 4 asesores en 2 días y nada la página no funciona que es lo que pasa'],
#  ['YerlisEstor',
#   'todo el día pasa así entonces no creo que esté funcionando con “normalidad”'],
#  ['DavidSa79633823',
#   'me reporta error tiga001 al tratar de activar la tarjeta débito llevo 3 días intentando en la página'],
#  ['MaryAlarcon8', 'la app está caída'],
#  ['Vivicastillo91', 'gracias ya reenvié el correo'],
#  ['__barataria',
#   '20 minutos esperando una clave dinámica ¿la están enviando por 4 72 o qué'],
#  ['Macdiaz13', 'y que es dm'],
#  ['PaulaPuertaH',
#   'me gustaría saber si la app tiene una funcionalidad para buscar establecimientos cercanos que sean'],
#  ['Bancolombia',
#   'reportando esta información que te llegó recuerda adjuntar todos los soportes te invitamos para que ingreses al siguiente enlace y conozcas más sobre seguridad que tengas una linda tarde jacke'],
#  ['Bancolombia',
#   'que suplantan la imagen del banco ten presente que nosotros nunca enviamos enlaces ni solicitamos datos personales a través de estos canales te solicitamos que envíes un correo electrónico a la siguiente dirección correosospechoso@bancolombia com co'],
#  ['Juancma29',
#   'veo con preocupación que me llega un correo de phishing pero en esta ocasión me llega directamente a mi correo no a un grupo en especifico solicito que se investigue por qué mi correo personal está filtrado lo raro es q el correo desde donde lo envían es falabella'],
#  ['fenixlouis',
#   'que triste saber que no se puede confiar en este banco debitan el dinero de la cuenta sin autorización un verdadero fraude solicito estudio de mi caso y devolución del dinero ya'],
#  ['FabianC36203154',
#   'no puedo entrar a etrading en linea porque me figura una cuenta de invesbot en vez de mi cuenta original y no puedo cambiarla'],
#  ['Zuheydy2',
#   'me gustaría saber que pasa con el aporte del ingreso solidario se están tirando la pelotita entre prosperidad social bancolombia y nequi lo único que quiero saber es cuál es el inconveniente'],
#  ['Juampiqbillos',
#   'ustedes que control tienen sobre sus bases de datos me llega un correo diciendo que han bloqueado mi tarjeta que entre a un link y resultó ser un sitio inseguro hace unos días recibí una llamada dónde pretendían que les diera la fecha de vto de la tarjeta ojo'],
#  ['MDGA50',
#   'ahora me sale este error no me permite hacer ninguna transferencia ayuda'],
#  ['jhocor', 'pendientes clientes quieren robar datos con un correo falso'],
#  ['Bancolombia',
#   'com co com co reenvía el correo que te llegó a nuestro email correosospechoso@bancolombia com co te saluda luis'],
#  ['gerardbermon',
#   'limpio pero si visualmente está saturada de cosas parece un neceser'],
#  ['alexcast5000',
#   'que farsa de aplicación llevó varios días tratando de hacer un trámite y no sirve para nada nadie responde'],
#  ['alexandrabejar5',
#   'rt estoy escribiendo al dm allí pero no obtengo respuesta  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face '],
#  ['alexandrabejar5',
#   'rt que moral  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face '],
#  ['Jonalex_r',
#   'me están enviando información fraudulenta por favor indiquen un canal para denunciar'],
#  ['alexandrabejar5',
#   'que moral  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face '],
#  ['danacarito', 'ya les escribí pero cómo raro sin soluciones'],
#  ['laverde1976',
#   'no me atrevo a enviar al whats app pero esto me llegó hoy no tengo productos con ese banco'],
#  ['danacarito',
#   'llamó abancolombia a cancelar una tarjeta de crédito pues no la quiero más primero un asesor dice que no tiene línea llamó de nuevo y me dicen que sólo si verifican mi identidad la cancelan apenas me verifican dicen que no me escuchan y cuelgan'],
#  ['alexandrabejar5',
#   'estoy escribiendo al dm allí pero no obtengo respuesta  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face '],
#  ['danacarito',
#   'llamó abancolombia a cancelar una tarjeta de crédito pues no la quiero más primero un asesoró dice que no tiene línea llamó de nuevo y me dicen que sólo si verifican mi identidad la cancelan apenas me verifican dicen que no me escuchan y cuelgan'],
#  ['paola_monroy87',
#   'para consignaren no se puede entrar al banco te obligan a salir a la fila de la peatonal por una ficha para entrar a la misma puerta del banco donde estaba al llegar donde esta la seguridad'],
#  ['LuisVasquz92',
#   'respetuosamente les reporto ataques cibernéticos con suplantación de la razón social de bancolombia'],
#  ['alexandrabejar5',
#   'rt buen día cuando será que me colaboran con la refinanciación de mi producto ya llevo 3 meses rogándoles y no han querido gestionarme unas cuotas que yo pueda pagar  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  todas las veces que me llaman dicen que aún no sale la respuesta'],
#  ['alexandrabejar5',
#   'buen día cuando será que me colaboran con la refinanciación de mi producto ya llevo 3 meses rogándoles y no han querido gestionarme unas cuotas que yo pueda pagar  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  todas las veces que me llaman dicen que aún no sale la respuesta'],
#  ['agromerchant', ''],
#  ['agromerchant', ''],
#  ['ramiochoa', 'ya'],
#  ['mayitosama',
#   'señores no es que no sepa cómo usarla lo sé y la uso el problema es que es un enredo demasiados pasos para una información muy visual y poco útil demasiada información inútil demasiados pasos para una transacción sencilla la anterior era más sencilla'],
#  ['ramiochoa',
#   'bancolombia que sucede con las transferencias internacionales desde ayer estoy tratando y nada es urgente'],
#  ['AlcazarAlcides', 'eso es lo q nose'],
#  ['icgoco',
#   'acabo de llamar y me dicen que tienen incidencias en el sistema que ni para poner la queja les sirve este banco es inservible'],
#  ['Sierritafede8',
#   'mientras los clientes que se defiendan como puedan increíble'],
#  ['tratra690',
#   'estoy en bogotá entonces no hay pico y cédula estoy en lo correcto'],
#  ['NAGOCORREA',
#   'buen día sebastián ya mire en la página de ingreso y si soy beneficiario como pasó al dm gracias'],
#  ['NAGOCORREA',
#   'como es eso q los giros los hicieron entre el 29 y 30 de sept yo estuve en pendiente y me decían q no habían autozado los pagos'],
#  ['JazLucia3',
#   'buenos días el mismo día respondí las preguntas favor revisar'],
#  ['JazLucia3',
#   'buenos días el mismo día respondí las preguntas favor revisar']]

# %% [markdown]
# ## Delete repeating tweets

# %%
tweets = [text[i][1] for i in range(len(text))]
tweets
# Out:
# ['el ya radicó la queja lo que hago es avisar a mis amigos de redes que su app es super insegura',
#  'ya no pudieron eso es de hace mucho tiempo toco llevarnos la cuenta empresa para otro banco muy regulares en todos los aspectos',
#  '',
#  'varios amigos me reportan que la actualización de la app es muy insegura ayer a un amigo le robaron un iphone y seguido de eso le robaron dinero de su cuenta bancaria por transferencia desde la app pilas con eso',
#  'rt encontré con sorpresa la implementación de una dmp dentro del portal transaccional de personas quisiera conocer las políticas de manejo de datos digitales y que información nombrada con exactitud está guardando la dmp y para que la están utilizando',
#  'señores llevan dañados los cajeros automáticos de la calera 8 días co de sus noches pésimo servicio cambien esas máquinas obsoletas',
#  'paren ya su acoso ya les dije que no me interesa su cupo de crédito ¿cómo más hay que decirlo para que dejen de bombardearme con su publicidad telefónica y de mensajería',
#  'por que mi tarjeta débito no tiene cvv',
#  'creemos más que nunca en su fortaleza y queremos acompañarlas a conseguir un mejor futuro por eso creamos la línea de crédito agro para todas una oportunidad para que puedan alcanzar sus sueños y tener un mayor bienestar',
#  'y su mundo digital para facilitar su trámite imprima el documento llene a mano ponga su huella quien tiene huellero en su casa después escaneé les falta poner “por último radique en el banco”  rolling on the floor laughing  súper digital  clapping hands  thumbs up ',
#  'la app de ustedes la mayoría del tiempo está fallando mala cosa',
#  'malo el servicio en el banco físico y ni hablar del soporte por este medio ahí estoy esperando soporte hace horas …',
#  'ustedes el mismo cuento de siempre escriba por dm lo concreto y lea todos los twittear es que los tres cajeros que hay en la calera llevan una semana sin funcionar',
#  'es triste que cada quincena sea lo mismo con uds esa sucursal virtual caída estamos mamaos de eso',
#  'encontré con sorpresa la implementación de una dmp dentro del portal transaccional de personas quisiera conocer las políticas de manejo de datos digitales y que información nombrada con exactitud está guardando la dmp y para que la están utilizando',
#  'ya ajusto 20 llamadas en un solo día que fastidio de banco',
#  'pero entonces no es en este momento ha sido en varios momentos ya que el mismo error tanto desde sucursal personas o empresas lo he tenido en más de una oportunidad',
#  'le han estado cobrando el 4x1000 a mi madre desde que abrió la cuenta en diciembre y no se ha llegado a ese tope ¿lo hacen con todas las cuentas para pensión a padres de otros amigos le han realizado lo mismo',
#  'claro que si tatiana  winking face ',
#  'precisamente día de pago de nómina y la sucursal virtual empresas caída',
#  'yo le llamaria falsa publicidad porque no estan dando este tipo de credito',
#  'a qué horas se cae la app de bancolombia',
#  'pueden hacer una bendita aplicación que no se muera cada quincena',
#  'gracias angie ya respondí por dm',
#  'cómo es posible que pague el total de mi crédito hipotecario hace más de 1 mes y ahora resultan cobrando sin saber qué es y nadie responde',
#  'gracias estefa eres muy amable sin embargo el tiempo se ha extendido más de la cuenta cuando la solución debió ser más oportuna temo que el banco me informes que mi dinero se perdió y me toque emprender un proceso judicial',
#  'muchas gracias por comunicarte conmigo estefa pero tu respuesta no satisface mis pretensiones es posible que me informes las causas o motivos de la demora en resolver mi caso',
#  'gracias aunque ni siquiera tengo productos con ustedes y eso lo hace aún más gracioso  face with tears of joy ',
#  'buenas tardes me podrían brindar asesoría realicé un pago de mi tarjeta de crédito mastercard que tengo con ustedes en el banco pero la pague desde la app de otro banco el pago salió y me confirmó pero la tarjeta en la app personas me aparece la deuda aún',
#  'claramente ya bloqueé la cuenta que envía esos mensajes me causa gracia que ni siquiera se esfuerzan en cambiar el dominio del remitente y dejan banco falabella  rolling on the floor laughing  rolling on the floor laughing  woman facepalming ',
#  'ellos cajeros fallan y se quedan con la plata los aplicativos de consulta en el call center no funcionan de la personal cero actitud de servicio disculpen srs que les sirve',
#  'buenas tardes bancolombia yo cobro por modalidad de giro con ustedes y hace 1 mes abrí una cuenta de ahorro a la mano en este pago que se aproxima ya me empezan a pagar x cuenta o me van a trasladar a supergiros gracias',
#  'por favor me confirma si el tiene el absurdo cobro por retirar de cajero en otras ciudades por favor explicar ese atropello cómo validar los topes de estas injustificadas y desmotivantes políticas de la banca en colombia',
#  'que ya la tengo inscrita',
#  'yo te escribí por dm',
#  'no me solicitaron pago mínimo',
#  'deisyb si alguna vez te hace una marranada financiera recuerda muy bien este tw es un sentimiento de impotencia solo espero hacer lo posible para pagar y nunca mas volver a verlos la gente sabe que como banco no tienen nada que perder que nadie les pague',
#  'reexpedición',
#  'buenas tardes me gustaría saber el horario de atención de la sucursal en zipaquira gracias',
#  'no amiguitos esas excusas ya no valen ustedes reflejaron las porquerias que son con los colombianos no les importo que muchos estuvieran endeudados otros pasando necesidades pero vaya uno no pague lo que ustedes dicen y verá asco de banco',
#  'si lo lamentan pero no hacen nada para solucionar  face with rolling eyes ',
#  'ya estoy inscrito estoy tratando de hacer un pago pero la clave dinámica no llega o llega media hora después cuando ya no sirve',
#  'buenas tardes ya les respondí por dm toda la información q solicitan para q de manera inmediata me devuelvan mi dinero información que ustedes deben tener pero por su ineficiencia y para ganar tiempo se les hace más fácil que el cliente se las suministre',
#  'ajaaaaaaaaaaaajaaaaa',
#  'me ayudan tengo que activar una cuenta que abrí por medios digitales y no he podido',
#  'respondí por dm',
#  'un crédito de libre inversión interpuse un dp con uno de sus asesores telefónicos después de que alguien de redes sociales me llamará y no pueden encontrar el requerimiento sin el número de radicado en pleno siglo xxi que empresa no puedo encontrar un radicado con otros datos',
#  'la gerente dice que es el protocolo de bioseguridad le pregunto donde esta exhibido y dice lo tengo en el computador',
#  'bancolombia sucursal parway media hora para que la gerente salga brava a atender y decir que nonabre la puerta no dejan entrar al banco',
#  'es el 4to mes en donde estoy pagando los intereses de un periodo de gracia de 3 meses que no pedí hasta cuándo voy a pagar esos intereses',
#  'ya le escribí por dm espero su pronta respuesta',
#  'reyes del pésimo servicio cambian para empeorar',
#  'hay problemas con clave dinamica',
#  'buenos días una pregunta ¿que es el débito sucursal bancolombia y ¿cuánto e el monto máximo a descontar gracias',
#  'no funciona esa clave dinámica',
#  'que fea mala lenta en 15na bancolombia muere',
#  'cuando me acerco a sus oficinas a buscar una alternativa y me dicen que ya no hay turnos que llame que llame a los que me dicen que lo único que tengo que hacer es pagar qué fastidio de banco',
#  'cuando llaman y me piden una cantidad de datos que cada llamada les tengo que suministrar para que la única información que dan es que o pago o me reportan qué fastidio de banco',
#  'quincena o fin de mes la plataforma caída que raro no  grinning squinting face  grinning squinting face  grinning squinting face  grinning squinting face  grinning squinting face ',
#  'cuando solo llaman y dice que si no pago me reportan como si en esta situación eso fuera realmente preocupante antes que otras prioridades qué fastidio de banco',
#  'alivio para ustedes será',
#  'bla bla bla llevamos 5 veces hablando con el banco y no dan solución es un descaro',
#  'se llama camila',
#  'rt asuman su responsabilidad y dejen de robarle a la gente no sean descarados',
#  'perdón que es dm',
#  'ya les escribí por dm',
#  'con hasta 20 llamadas diarias de cobro y siempre se les dice lo mismo qué fastidio de banco',
#  'vergüenza de banco ladrones con permiso para robar',
#  'necesito comunicarme vía telefónica con un asesor y no atienden las llamadas  weary face  weary face  que rabia el caos de',
#  'me dieron hoy una respuesta por cierto carente de información para un evento que terminó ayer mejor dicho de nada sirvieron los canales de comunicación con ustedes',
#  '',
#  'rt que van a revisar si ya descontaron el dinero  woman shrugging light skin tone  acaso lo piensan devolver  woman shrugging light skin tone ',
#  'rt no se preocupe me tomé el trabajo de ir hasta una oficina y ni soluciones ni respuestas claras cuando les pregunté por qué nunca me explicaron desde el principio el escenario real de la situación ustedes son un karma para el usario',
#  'mala mala mala esa app siempre arroja error hasta para hacer el pago de un producto',
#  'que es lo que pasa com esa app no sirve para nada ¿como novedad hoy tambien esta caída',
#  'lo he dicho el banco más ladrón de colombia junto a los del nadie los controla roban a pueblo multiplican el dinero que usaron para comprar la presidencia y mantener el poder de hacer lo que quieran sin control',
#  'escribí hace rato y ahí me quedé igual que en las llamadas que ineptitud la cacha del culo estos pingos',
#  'esto lo he realizado por dm en varias ocasiones y ha todos les explico y luego me dejan disque esperando respuesta del area encargada y así ha pasado casi 3 meses quiero que me contacte un asesor por vía telefónica',
#  'indolentes y alejados de la realidad mundial acosan y lastiman la salud mental de sus clientes que fastidio de banco',
#  'siempre me mandan al dm para no darme ninguna respuesta exacta y correcta me habían dicho una cosa y hoy que llamo a preguntar por el radicado me dicen otra no se quién es más ratero si o',
#  'deberles a ustedes es peor que matar un cura que karma que fastidio',
#  'que desespero tener una mora con ustedes 15 llamadas al día para decir que pague respeten',
#  'yo llevo 9 llamadas a ese dizque centro de ayuda para cancelar una puta tarjeta de crédito que ni la tengo porque me cancelaron el plástico y no lo mandaron pero igual cobran la cuota de manejo después preguntan porque uno apoya los vándalos',
#  'para qué si no hay respuesta',
#  'es que cualquiera puede estrar a mi cuenta un día cualquiera y cogerme lo que les de la gana quien me dice a mi que no fueron ustedes ustedes se lavan las manos que seguridad le están brindando a uno uno no es adivino para saber que era 7n fraude en la semana m',
#  'pido la respuesta formal a mi reclamo de reintegro de hace 2 meses y me envía un email con una respuesta de otro reclamo de hace 3 meses negligencia o burla',
#  'estoy intentando que me envíen un email con la respuesta adjunta de un reclamo de hace 2 meses y mandan el email vacío es una burla o es negligencia del asesor pero igual no logro tener solución a mi reclamo',
#  '3 llamadas a la línea de atención al cliente pero el asesor me deja esperando hasta que se corta la llamada y se pierde todo lo adelantado y lo peor es que los asesores no tienen el mínimo detalle para devolver la llamada y dar solución al problema del cliente',
#  'en el barrio san luis también pasa lo mismo de los dos cajeros sólo está funcionando uno frente al supermercado la canasta campesina',
#  'perdone gustavo la palabra pero mas pendejo usted que no siguió pagando normalmente el tal alívio nunca existió porque simplemente debía seguir acumulando intereses sobre toda el capital desde el inicio cuando lo escuché me pareció la estupidez mas grande',
#  'me van a devolver es una pendejada escribir al interno no solucionan nada solo les preocupa la mala publicidad no van a solucionar nada',
#  'cómo sería',
#  'necesito ayuda por favor dm',
#  'increíble que presten un servicio tan malo no son capaces de solucionar un problema que es de ellos ni siquiera respetan el tiempo de los clientes más de 15 llamadas para que me solucionen y nada pouting face  pouting face  el peor servicio en banca lo tiene',
#  'como puedo cancelar la cuenta sin ir al banco a través de la web',
#  'ya puse las quejas y ya me respondieron que no me podían responder que había sido víctima de un estafador pero quede muy triste que garantías y seguridad le brindan a uno sus cuentas',
#  'son un chiste  face with tears of joy ',
#  'tiene una publicidad que dice esa app se convertiría en el empleado del mes  expressionless face  olvidaron que detrás de una app hay personas que programan piensan y trasnochan rocket  si una app es buena las personas son los las empleados del mes  red heart ',
#  'hola ya el inconveniente fue solucionado',
#  'le está poniendo el alma',
#  'no se preocupe me tomé el trabajo de ir hasta una oficina y ni soluciones ni respuestas claras cuando les pregunté por qué nunca me explicaron desde el principio el escenario real de la situación ustedes son un karma para el usario',
#  'responda que uds le van quitando el dinero a la gente por cada movimiento con su propia plata',
#  'como asi que solo responden por el 50 de la plata si el error fue 100 de ustedes',
#  'hicieron cargo a mi cuenta por una compra en amazon la cual no fue procesada pero bancolombia me debitó el monto y no me lo ha devuelto en los teléfonos que dice debo llamar nadie se digna atender les agradezco procedan a devolver mi dinero de manera inmediata',
#  '¿ya resolvieron esta situación la respuesta debe ser asumir ustedes',
#  'son campeones con el dinero de sus usuarios algo parecido sucede cuando los cajeros automáticos no entregan el dinero el usuario debe de esperar un día hábil para devolver el dinero pero cuando es el cliente que se demora un día ellos te cobran intereses',
#  'llevo pidiendo días un extracto del mes de enero y siempre me envían el de febrero y marzo sean serios lo necesito urgente',
#  'cúcuta norte de santander y en el municipio de bochalema el ubicado parque central quedo atento a su respuesta',
#  'me están pidiendo datos de mi sitio de trabajo',
#  'les sobra una r en el correo',
#  'yo tengo un préstamo con sofi y no tengo empleo y siempre que me llaman me ofrecen ciertos alivios que realmente lo que me ofrecen es extender las cuotas con doble interés vivasos por cierto ya me tienen aburrido cada 3 días llamando',
#  'alivios me hicieron préstamo 20mll en marzo comenzó la pandemia me dieron el alivio ahora ya van en 3 millones de intereses y me llaman xa financiar toda la deuda disque no me cobran un mes y los intereses por las nubes pido envíen estracto de intereses y nada',
#  'bank in the world just like is the worst airline in the world how do these companies that provide shit service stay in business well it wont be much longer for avianca and maybe will be soon after service',
#  'operates the worst bank in the world nothing ever changes with this crap bank today in victoria in pereira we waited over 2 hrs in line with hundreds of people and even though they accepted us on the line for hours the bank closed and they said no more people shit',
#  'ratas',
#  'bancolombia roban por todos lados por tarjetas extranjeras cobran por transacción hasta 18 mil eso es un descaro ahora todas las arandelas que hacen para ir sacando dinero de cada cuenta un robo totál',
#  'y flypass cerrarán negociaciones con nuevos parqueaderos en bogotá y medellín  automobile  sport utility vehicle  que aceptarán este medio de pago sin contacto  high voltage  high voltage  actualmente los estacionamientos de oviedo y el aeropark  deciduous tree  deciduous tree  tienen el servicio disponible',
#  'movilizará 140 000 millones de dólares en servicios financieros en los próximos 10 años el anuncio se dio en el encuentro de la alianza global de inversores para el desarrollo sostenible de la onu lee aquí cómo se orientarán estos recursos  backhand index pointing down  …',
#  'muy alegres ante la desgracia ajena que ustedes empeoran se les recomienda no ser tan festivos y más nuevos buscar soluciones en las que honren la confianza y la buena fe de quienes ponemos nuestro dinero en sus manos al menos para no lucir como cínicos',
#  'lo paso por un sandbox y luego trato de notificarlo a pero como sus plataformas nunca sirven pues dejo así',
#  'rt para qué le van a devolver la plata díganlo enseguida o le va a repetir la misma información que ya le dieron y ya sabe',
#  'esto lo puedes realizar en la configuración de tu dispositivo móvil saludos',
#  'no tienen en cuenta la posible reactivacion economica no todos son empleados del estado  pouting face  pouting face  pouting face  pouting face ',
#  'coloca la actividad económica 0090 de rentista de capital ya que no hay una que indique que es sostenida por sus padres mentiras lee bien los ciiu previamente a tramitar el rut sino quieres es mas fácil aperturar nequi pero si te recomiendo luego migrar a un banco',
#  'nunca fueron claros en las líneas telefónicas decían una cosa y por correo decían otra ante tanta incoherencia e información tan poco clara lo mejor era si se podía cancelar cualquier deuda',
#  'rt para qué le van a devolver la plata díganlo enseguida o le va a repetir la misma información que ya le dieron y ya sabe',
#  'de esta dirección me llegan bastantes correos informacion@mailgrupobancolombia com co',
#  'jajajajajajaja',
#  'ahhhh bueno fue solo un problema de falta de claridad de información la próxima vez sean mas claros a la hora de desplumar a la gente',
#  'devuelvan el dinero',
#  'rt para qué le van a devolver la plata díganlo enseguida o le va a repetir la misma información que ya le dieron y ya sabe',
#  'eso es lo único que hace bancolombia quitar el dinero cobrar mal dar mala información y ahora todos los usuarios están quedados menos mal están demostrando como son tendencia por mal banco y como están llegando competencias fuertes para tumbarlos no mas bancolombia',
#  'rt cuantos favs y condonan en su totalidad una deuda con ustedes',
#  'hijueputas',
#  'mil gracias',
#  'el sitio es de ustedes si sí muy extraño que requiera un login por fuera del sitio de sucursal virtual personas si no están enviando correos que tienen mala pinta',
#  'es tendencia solocitar a empresas o personas determinada cantidad de me gusta likes favs para obtener algo a cambio dicho esto ¿cuantos me gusta likes favs para condonar una deuda que tengo con ustedes',
#  'rt para qué le van a devolver la plata díganlo enseguida o le va a repetir la misma información que ya le dieron y ya sabe',
#  'yo tenia que abrir otra ventana de mi celular para ver la dinámica',
#  'no sean ratas',
#  'lo abro les mento la madre a los ladrones les pregunto por acá a ustedes cuál es el correo para informar lo del pishing ya luego lo reenvío y lo elimino',
#  'pero yo no trabajo mis papás me mantienen todavía jajj',
#  'rt para qué le van a devolver la plata díganlo enseguida o le va a repetir la misma información que ya le dieron y ya sabe',
#  'rt para qué le van a devolver la plata díganlo enseguida o le va a repetir la misma información que ya le dieron y ya sabe',
#  'esa manía de ustedes de querer obligarlo a uno a inscribir las facturas para pagar a través de la sucursal virtual ahora la famosa clave dinámica desde la app no sirve no sé por qué inventan tanto disappointed face ',
#  'depende si es un enlace porno le echo un ojito primero de rapidez y ahí sí lo borro  face with hand over mouth  face with hand over mouth  face with hand over mouth ',
#  'en pocas palabras ratas  mouse ',
#  'les pregunté por acá si necesitaba el rut para crear la cuenta y me dijeron que me tenía que acercar a una sucursal física para que allá me dijeran si era necesario o no',
#  'no me ha querido servir en todo el día  face with rolling eyes  woman facepalming light skin tone ',
#  'que falta de honestidad del banco y de la persona que recibió el dinero por error que  face screaming in fear  face screaming in fear  face screaming in fear  angry face  angry face  angry face ',
#  'pura mierda congelaron el cobro de los créditos pero los intereses crecían como si el cliente hubiera dejado de pagar porque sí troncos de rateros a mí me quitaron 500 mil y punta de interés',
#  'la mejor forma de protegerte del phishing es identificar si es una estafa para hacerlo reenvíalo a corrreosospechoso@bancolombia com co estos son 3 elementos que podrás encontrar en este tipo de correos ʘ˧',
#  'demasiado cínismo  face screaming in fear  face screaming in fear  face screaming in fear ',
#  'son unas ratas mejor busquen otro banco como colpatria o otros estos hp cobran 12 000 de cuota de manejo y sin importar la pandemia ratas hp',
#  'rt ratas hijueputas abusando de la gente',
#  'ratas hijueputas abusando de la gente',
#  'buenas tardes mi esposa y yo tenemos cuentas de ahorro de bancolombia y manejamos un solo celular yo ya tengo registrado la clave dinámica con mi cuenta se puede registrar también la cuenta de mi esposa con el mismo celular no tenemos más celular que hacemos',
#  'responde por eso tal vez el cajero y su gerente para no ponerse en evidencia ante medellin tratan de resolverlo ellos pero la central del banco responde por todo seguro obvio hay perjuicios pero el capital no se pierde duerma tranquila',
#  'cuantos favs y condonan en su totalidad una deuda con ustedes',
#  'le ha bloqueado la cuenta 2 veces a mi mamá no la deja hacer transferencias pagos o lo que sea pero sí reciben la plata que le envían a ella y fue a solucionarlo le cambiaron la tarjeta y al otro día la misma mierda a qué juegan',
#  'les contacte primero por los canales internos y es muy molesta la respuesta de sus asesores toman decisiones unilaterales siempre sin pensar en las personas',
#  'buen dia a mi me han llegado correos parecidos diciendo que digite mi documento para saber el extracto',
#  'seguro me invente la falla',
#  'no carolina nada qué hacer',
#  'otra vez su plataforma de pse fallando como si no fuera importante tener el soporte de pago',
#  'daniel el inconveniente te lo estoy mostrando en la imagen saludos',
#  'ya me he comunicado con anterioridad y en múltiples ocasiones por dm por email por línea telefónica y no pasa nada si de verdad quiere deme indicaciones de la queja y',
#  'un iphone 12 pro plus max xt por favor con la cuota de 9 900 gracias',
#  '1 si el asunto es urgente el destinatario no concuerda y te piden descargar archivos elimínalo \u200b 2 si parece ser del banco y te pide clave usuario y número de la tarjeta reenvíalo a correosospechoso@bancolombia com\u200b ʘ˧',
#  'hola cada que marcó al 5109000 me aparece davivienda y no tengo ese número guardado con nombre de davivienda',
#  'no loren por privado lo vacilan a uno y se hace lo que uds quieran y como uds quieran es mi dinero y deberian sostener las garantias que me ofrecieron al momento de adquirir el producto prefiero cancelar mis productos con uds y presionar la empresa para me pague con otro banco',
#  'estaremos observando cualquier cosa gritas',
#  'de repente y sin autorizacion cambian mi plan de cuenta como les da la gana cobrando extra y me lo tengo que tragar si toca que la empresa me pague la nomina en cheque o en monedas pues lo acepto pero esa cuenta se cancela',
#  'muchas gracias por la información',
#  'y me siguen llamando del 304 550 3348 no quedo claro ayer que no quiero recibir mas este tipo de llamadas no me interesa por que vendieron mis datos',
#  'ni lo recomendaría a bancolombia ni lo recomiendo fue el banco que se aprovechó de la necesidad de sus clientes en la pandemia para hacer de la suya',
#  'ok ya escribí por interno',
#  'buenas tardes hay inconvenientes con la app',
#  'ojalá lo implementarán',
#  'a ver si por aquí responden ¿de cuánto es el descuento ¿cómo se accede a él',
#  'qué está pasando con la seguridad de información de los usuarios ya conozco 3 casos incluyendo el mío sobre el bloqueo de la cuenta porque alguien intentó meterse desde la sucursal virtual por favor expliquen lo que está sucediendo',
#  'buenas tardes muchas gracias en la actualidad tengo dos crediagil y dos créditos tasa fija estoy sin trabajo desde el pasado mes de abril y quiero postularme al congelamiento de la deuda hasta dic es posible ante la incapacidad de pago',
#  'no he podido enviar el mensaje dm',
#  'el peor servicio de bancolombia solo atienden por línea telefónica y dicen que espere su llamada y llevo 5 meses esperando que me llamen',
#  'que servicio tan malo de sus cajeros electrónicos la mayoría de las veces que voy no sirven ¿entonces para qué están lo que hace le hace a uno perder el tiempo  pouting face ',
#  'hola ya respondí por dm espero pronta solución gracias',
#  'eso me llego hoy',
#  'estoy esperando su respuesta por dm nuevamente me acabaron de llamar a preguntar por alguien que no soy yo',
#  'asuman su responsabilidad y dejen de robarle a la gente no sean descarados',
#  'quisiera saber si esta información es verdadera gracias',
#  'pues ya estoy en dm',
#  'hola muy buenas tardes santi me sale un error que me debo inscribirme a la clave dinámica pero lo raro fue que hace unas horas antes había hecho una transferencia y yo ya he llamado y he hecho el procedimiento para la clave dinámica me genera el problema muy seguido',
#  'esto es cierto o es algo anormal',
#  'me llega este mensaje es verdad o es una estafa',
#  'el cajero del parque central del municipio de bochalema también presenta problemas y es el único que hay',
#  'es por el bien de todos que hago esa queja es muy molesto que siempre se vea la aglomeración de personas en los cajeros bancolombia y además se presta para que los amigos de lo ajeno hagan de las suyas faltan protocolos de bioseguridad por lo menos un antibacterial en los cc',
#  'para qué le van a devolver la plata díganlo enseguida o le va a repetir la misma información que ya le dieron y ya sabe',
#  'el numero del celular que envío el mensaje es 316 334 66 30 para que tengan en cuenta y pongan en reporte esta modalidad de fraude gracias',
#  'cúcuta norte de santander',
#  'hola buenos días en la mañana de hoy recibí un mensaje que dice así felicitaciones hoy movistar y bancolombia te felicitan por ser el ganador de 10 000 000 comunicate ya pbx 301248090 cdg 750 aut coljuegos y este es el numero donde me enviaron el mensaje a mi',
#  'ya pude solucionar gracias los tkm',
#  'que servicio de porquería',
#  'cómo sería para desbloquear mi ip y poder entrar a la sucursal desde mi wifi',
#  'buenos días sucede que aparezco en bancolombia beneficiada de ingreso solidario y no me han cancelado ningún giro',
#  'apreciados señores tengo varios créditos con ustedes libreinv y crediágil y desde el mes de abril estoy sin trabajo podrían indicarme que debo hacer en este caso para acogerme al periodo de gracia hasta diciembre de acuerdo a la última circular de la s financiera',
#  'por la pandemia y mi labor no puedo estarme movilizando hasta allá a verificar esos códigos además tengo entendido que para eso tienen personal técnico me parece el colmo del descaro seriedad por favor',
#  'cc unicentro sólo sirve 1 o 2 cc jardín plaza 1 de 4 cc ventura plaza solo sirve 1 barrio san luis solo sirve 1 av libertadores más abajo del cai niza 1 de 4 av cero al lado de mkgusto solo sirven 2 y en el parque central de bochalema el único que hay dañado',
#  ' raising hands  raising hands  raising hands  thumbs up  thumbs up  Colombia  Colombia  Colombia ',
#  'nos van asesorar sobre sus utilidades en la pandemia',
#  'acabo de hacer un pago a por un dispositivo nunca usado y la clave dinámica en el celular funcionó perfectamente sencilla y segura',
#  'estan respondiendo vainas locas que no concuerdan ni con la fecha de compra no saben donde estan parados  pouting face ',
#  'los odio',
#  'privado para que para que no se den cuenta lo ratas que son ustedes',
#  'llevo tres días intentando realizar una transferencia y me indican que me comunique a la línea luego llamo a la línea y me informan que hay un incidente pero no dan información de qué se trata ni para cuando hay una solución para cuándo se soluciona el incidente',
#  'ya les escribo',
#  'señores tengo casi dos meses esperando un reembolso de dinero y aun nada se piensan robar la plata',
#  'phishing llegó a mi correo',
#  'cómo así que debemos migrar la clave dinámica a la app personas desde el 20 de octubre cómo hacen las personas que no tienen teléfonos inteligentes y todo lo haces es a través del pc me toca comprarle un celular a mi abuela para eso o uds se lo regalaran',
#  '3125080487',
#  'entiendo esto pero no me importaría tener un rechazo y generar nuevamente el pago como en otras entidades bancarias es absurdo tener que esperar 3 días para hacer un pago urgente',
#  'gracias pero ayer llame al banco y ya me aclararon la información y me dijeron que se demora hasta tres días la inscripción de una cuenta a otro banco y pues nada me toca salir hoy a retirar y desplazarme hasta el otro banco para hacer la consignación que ayuda en la pandemia',
#  'a mi me parece terrible que inscribir una cuenta de otro banco se demore hasta 3 días y más cuando uno la necesita hacer urgente este es único banco que me encuentro que hace esto y realmente es molesto',
#  'que van a revisar si ya descontaron el dinero  woman shrugging light skin tone  acaso lo piensan devolver  woman shrugging light skin tone ',
#  'ayer al mediodía inscribí una cuenta para hacer un transferencia urgente y esta es la hora que la cuenta no ha quedado inscrita me parece el colmo que me digan que se puede demorar hasta tres días respeten que la necesito hacer urgente soy nueva en bancolombia y no me gusta',
#  'ayer al mediodía inscribí una cuenta para hacer un transferencia urgente y esta es la hora que la cuenta no ha quedado inscrita me parece el colmo que me digan que se puede demorar hasta tres días respeten que la necesito hacer urgente soy nueva en bancolombia y no me gusta',
#  'banco llamé el viernes a cancelar una tarjeta de credito virtual me dijeron que la cancelación se vería reflejada en 1 día hábil hoy miercoles sigo viendo activa esa tarjeta necesito cancelarla antes de que me cobre manejo colaborenme por favor',
#  '1 mes sin solucionar lo del pago total a mi crédito hipotecario quieren más plata quieren robar más',
#  'llevo más de 1 mes sin solucionar mi pago de crédito hipotecario que más quiere robar',
#  'quiere decir que van a dejar a lod adultos mayores sin posibilidad de que les ayudemos a hacer sus pagos ya pensaron en ese segmento de clientes son clientes que no usan la app ni la van a usar uds los están obligando a salir a un banco y nos quitan la posibilidad de ayudarlos',
#  'tu atención al cliente es horrible y tu app es lenta e inoperante como proceso burocrático',
#  'espero que con ese mismo fervor y patriotismo se encarguen de arreglar los cajeros en cúcuta en todos los cc y en general muy pocos sirven y se aglomera la gente por su culpa sean serios y respeten los usuarios',
#  'vamos tigre gracias bancolonbia por ser patrocinador de la selec',
#  'al consultarme me sale esto no entiendo porque dicen que ustedes no me pagan si mis primeros 4 giros los cobre con ustedes',
#  'falcao te mereces otro hijo',
#  'esperanza la que yo tengo de que no empiecen a cobrar las transferencias a otros bancos para robar más plata',
#  'vieron ese gol jajaja eso merece que no le cobren tasa nominal en el mes de octubre  hundred points  victory hand  Colombia ',
#  'grande falcao tigre de tigres',
#  '4',
#  'me gané mi primera polla  yellow heart  yellow heart  blue heart  red heart ',
#  'ustedes procuren mejorar la aplicación que bien lenta si está',
#  '6',
#  '6  index pointing up medium-light skin tone  index pointing up medium-light skin tone ',
#  '5  flexed biceps light skin tone ',
#  'ladrones',
#  '2  backhand index pointing up  folded hands medium-light skin tone  red heart ',
#  '5  flexed biceps ',
#  'obviamente no están teniendo en cuenta a estos 10 millones de hijueputas que grandes',
#  'arreglen esa porquería de app en vez de estar twiteando maricadas',
#  '5 vamos por el empate',
#  '1',
#  'rt en su comercial dice que vuelven a latir 40 millones de corazones y los otros 10 millones  pleading face ',
#  '1  raising hands ',
#  '1 a echarle cabeza mijos thinking face  thinking face ',
#  '1 cabeza fría',
#  'no es cierto',
#  '7',
#  'y esto que es de nuevo app bancolombia caida',
#  'otra vez caida la app de bancolombia',
#  'rt ladrones',
#  'hoy se anotó dos golazos en mí cuenta debitandome sin mí permiso 200 000',
#  'ladrones',
#  'promocionando fútbol mientras las personas que tienen su dinero en tienen que hacer enormes filas en cartago bajo el inclemente sol soportando por horas temperaturas superiores a los 30° pésimo y nefasto servicio',
#  'ladrones',
#  'me acaba de debitar 200 000 sin justificación alguna y no me dan razón en la línea telefónica ¿ahora sus formas de ganar utilidades es literalmente robándole al ciudadano',
#  'dudas no tengo pereza de usarla pero pues toca porque uds no escuchan a los usuarios hay algo fundamental en el diseño de cualquier cosa y es la usabilidad parece que los diseñadores de su app desconocen el término',
#  'solucionado gracias',
#  'me están llegando estos mensajes al correo',
#  'y flypass cerrarán negociaciones con nuevos parqueaderos en bogotá y medellín  automobile  sport utility vehicle  que aceptarán este medio de pago sin contacto  high voltage  high voltage  actualmente los estacionamientos de oviedo y el aeropark  deciduous tree  deciduous tree  tienen el servicio disponible',
#  'porque no me dan la opción de descargar certificado de crédito hipotecario lo requiero para declarar renta ya que no lo reportan en la rete fuente que me enviaron solicite por teléfono el documento dijeron que tardaba 6 horas aún no llega',
#  'me ha quitado más plata de la que saco',
#  'otra vez falla en la app no me deja trasferir',
#  'todas sus campañas de alivio son una mentira si de la sucursal telefónica nos envían al punto físico no saben dar explicaciones es mentira sus alivios y hacen que los productos entren en mora para cobrar intereses',
#  'ah claro me imagino que a él nunca se le ocurrió comunicarse con el banco',
#  'el banco que dice colocarle el alma a los colombianos más bien le está partiendo la madre a los colombianos',
#  'o me solucionan la@situación o me encargaré de llevar esto hasta las últimas consecuencias mi hija viaja y la única tarjeta que tiene es con bancolombia y es un deber de axa expedirme el certificado de asistencia',
#  'que el el dm otras 5 horas colgada al teléfono por qué sume que se que quiere decir ese término',
#  'inaudito que una entidad tan prestigiosa como la de ustedes jueguen con el cliente de la forma como lo hacen llevo tres días solicitando certificado de viaje internacional y me ponen al teléfono 60 minutos y cuelgan la llamada es una obligación y lo exijo',
#  'como es posible que he solicitado la cancelación de una tarjeta de crédito 3 veces con bancolombia y siempre me dan vueltas y me sacan peros y no finalizan el proceso esto es un atropello al consumidor',
#  'cuanto hay que reclamar para que una persona le cancelen una tarjeta de crédito que ya no desea que tomadera de pelo es increíble',
#  'debo expresar públicamente que ante el problema manifestado y a pesar de estar en el exterior el equipo bancolombia me a contactado y me ha brindado un servicio de atención rápido y excelente quedo muy agradecido y espero muy pronto una resolución satisfactoria del caso',
#  'me realizaron un giro desde canadá el día 01 del mes en curso a la fecha no se registra en mi cuenta debo ir a una oficina para retirar o puedo hacerlo consignar en mi cuenta por medios electrónicos',
#  'les dejé mis datos de contacto por dm espero que esta vez sí pregunten por mí',
#  'que pasa con la aplicación que no aparece la clave dinámica y uno con afán de pagar sus obligaciones',
#  'les envíe el dm hace 10 mins',
#  'sucursal virtual web y móvil por ningún lado funciona',
#  'daniel es tu compañero yo soy ricardo he hablado durante un mes con personal de las áreas de servicio al cliente y conciliación y no tienen una solución quiero conocer los procedimientos de',
#  'porque no me deja ingresar con mi huella  exploding head  exploding head  exploding head ',
#  'enviado',
#  'puedo saber por que me dejan esperando en linea mas de 1 hora esta es la segunda llamada q hago y me dejan en linea por q no puedo cancelar esa tarjeta de crédito del demonio ni tiempo también merece respeto',
#  'daniel ya lo he hecho y no me dan solución me dicen que esta persona debe actualizar sus datos él ya lo hizo pero ustedes no retiran mi número del sistema ya he hablado con el área de servicio al cliente y tampoco tienen una solución por eso le escribí a',
#  'bobo aquel que caiga en sus trampas',
#  'pues aún estoy esperando que me atiendan llamo a la línea de atención al cliente escribo al dm y nada absolutamente nada me han ayudado',
#  'me agenda citas para que sus agentes me llamen y me cuelguen  face with tears of joy  a ver si me contestan',
#  'que sea por el correo por la app ha sido mi peor experiencia pense que iba a ser mas facil y resulta que meto la clave que aparece y nunca es valida ya estoy estresado con esa situacion no puedo movilizar mi dinero',
#  'yo llevo todo el día tratando de que me informen porqué me están cobrando 500 mil pesos por el congelamiento de mi crédito hipotecario y nadie me sabe explicar absolutamente nada esa es la ayuda que le dan a los colombianos',
#  'cambien esas máquinas eso ya tecnología vieja',
#  'ustedes tienen esa información ahorita me desplazo los 10 kilometros desde donde vivo que desgracia perder el tiempo con ustedes',
#  'entonces porque me llaman a vender seguros de parte de una entidad relacionada con banclombia yo no les di permiso para eso',
#  'mary ya escribí espero pueda obtener una respuesta por este medio',
#  'que hace con mis datos personales ¿por qué los venden a empresas que venden seguros quien regula esto la que inseguridad quien más tendrá mis datos',
#  '¿es legal que me pida más datos personales como mi número de cédula para dejar de llamarme cuando no tengo ni tendré ningun producto con ellos',
#  '¿donde puedo llamar',
#  'lo sentimos usted no está autorizado para marcar este número  person shrugging medium-dark skin tone ',
#  'ya les envié la información espero que no me llamen más cc',
#  'scar una tarjeta',
#  'la única validación que tienen que hacer es eliminar mi número telefónico de su sistema',
#  'señores es hora de cambien los cajeros de la calera por tecnología nueva las que están son maquinas obsoletas',
#  'quiero saber si me enviaran mensaje de texto para cobrar mis giros por nequi freddy lizarazo',
#  'lo que uds hacen con los adultos mayores es irresponsable el viernes tuvieron a mi papá adulto mayor 2 horas para abrir una cuenta de ahorros y desbloquear otra cuenta hoy le volvieron a bloquear sus cuentas la solución ir nuevamente al banco',
#  'hasta cuando los abusos incumplen promesas y acuerdos te hacen pagar corriendo a “su tiempo” y nunca cumplen lo que se supone me “otorgaron” desde julio',
#  'señores ustedes son lo peor como institución fuera la primera vez esto ocurre cada 8 dias',
#  'la nueva aplicación es un problema no una ayuda para los clientes',
#  'son sus políticas institucionales y las entiendo pero no las comparto me parece una falta de empatía que en semejante contingencia uno tenga que ir a ponerse en riesgo a una sucursal porque ustedes no aceptan abonos a capital por ningún otro medio',
#  'hola tati ya se arregló jejeje besitos',
#  'llamo desde su página me tienen 20 minutos como una estúpida cuando por fin me atiende el que se supone me resuelve dice cliente no responde y yo a el lo escucho perfecto los odio como le van a bajar el rendimiento a una inversion porque sí',
#  'el servicio de atención al cliente por teléfono es tan nefasto que marca una alguna de las opciones y lo que hacen es cancelar la llamada',
#  'me pasa lo mismo',
#  'queremos que la app funcione bien y sin tanto error ya viene la quincena',
#  'quieres saber de bugs en producción  rolling on the floor laughing   rolling on the floor laughing   rolling on the floor laughing ',
#  'seguridad bancolombia no brinda eso más de 15 días para devolverme 150 mil pesos que descontaron abusivamente de mi cuenta',
#  'no obliguen a la gente a abrir una cuenta para reclamar giros sucursales pereira si a alguien lo estan obligando ante quien puede poner la queja para q sancione el banco q gracias y a los lectores no usen giros bancolombia',
#  'quisieras conocer buen servicio al cliente yo te puedo ayudar',
#  'recuerda que ya no tienes que llamar a la línea telefónica para resolver tus dudas sobre la nueva app personas aquí te ayudamos a responder a todas tus preguntas ʘ˩',
#  'respuesta \u200b cualquier transacción que hagas desde app personas se validará automáticamente ya no hace falta esperar a que te notifiquen para usarla ʘ˩',
#  '¿si haces un pago desde app personas deberás esperar a recibirla por correo o mensaje de texto \u200b ʘ˩',
#  'respuesta ¡es muy fácil entra desde tu celular a app personas y en el home podrás ver los 6 dígitos sin necesidad de ingresar tu usuario o clave ʘ˩',
#  'si estás realizando un pago desde otro canal y te pide la clave dinámica ¿cómo puedes consultarla ʘ˩',
#  'qué hay una entrada específica y es por fuera del centro comercial',
#  'si señores también ando en el dm esperando a que me hablen pero tampoco',
#  'señores ya les hable por dm pero no hay respuesta',
#  'ya estoy realizando la transacción pero uds no pueden imponer más barreras especialmente para las personas de la tercera edad',
#  'señores dejen de burlarse de los usuarios ya me he comunicado con su dm pero no resuelven nada se quedan callados pareciera que el interés de ustedes es desviar la discusión que pone en evidencia lo mala empresa que son',
#  'centro comercial santa fe en la ciudad de bogotá el guarda también impide el ingreso a los acompañantes de las personas de la tercera edad es el colmo',
#  'he tenido muchos y no me interesa si cambian o no me da embarrada la gente que tiene cuenta en ese banco gracias luis',
#  'resolví mover mi cuenta de nómina a otro banco no tiene sentido tener una cuenta de ahorro en un banco y creditos en otro en bancolombia siempre ha sido un problema el tema de solicitar créditos se demoran mucho o no responden',
#  'alguna falla en la app que no deja transferir dinero',
#  'estamos llamando desde la semana pasada a la sucursal telefónica y ninguna opción es validad',
#  'mi esposa está intentando ingresar a la app pero no recuerda la clave',
#  'por favor se pueden comunicar con mi esposa 3046121174',
#  'necesitamos cambiar la clave personal',
#  'buenos días cuando dice dm que página es',
#  'quién castiga a los que se dedican al',
#  'consejo número un no ahorre en bancolombia',
#  'bancolombia lavándose las manos como siempre',
#  'su chat no sirve para nada pido asesor y finalizan el chat',
#  'esta llegando este correo lo reporte en correosospechoso@bancolombia com co y es una estafa no lo abran no den ningún dato inmediatamente lo reportan y lo eliminan',
#  'correosospechoso@bancolombia sin com co o loquesea',
#  'ahí están en las fotos',
#  'hola kevyn pude llamar a la línea de fraudes antes de hacer cualquier otra cosa y ellos me indicaron el proceso a seguir pude darme cuenta del fraude de igual forma te comparto el correo que me llegó',
#  'hola desde el viernes me estoy comunicando con ustedes mediante el chat de esta red pero los asesores que responden solo bromean conmigo no entiendo que es lo que pasa',
#  'hola pasa algo con la app de ahorro a la mano ya van varias semanas que no puedo entrar que hago',
#  'dm no entiendo srta laura',
#  'no puedo abrir mi app bancolombia a la mano que puedo hacer',
#  'tengo un cxc pendiente quiero saber que significa',
#  'hola bancolombia quisiera preguntar cuando inicia el 7 pago de ingreso solidario muchas gracias',
#  'sigo sin recibir respuesta',
#  'buenos días quería saber si está semana son los pagos del ingreso solidario por nequi y bancolombia a la mano y si son solamente los bancarizados o aquellos que no se le venían dando por giró agradezco de su información',
#  'me están cobrando un cobro de cxc retiro por cajero pero no he realizado ningún retiro no entiendo porqué este cobro gracias',
#  'listo ya se los mandé por dm',
#  ' seedling  herb  sheaf of rice ',
#  'hola yo tengo ahorro en la mano lo habri el dia vierne 9',
#  'se que este correo es falso pero miren lo que están haciendo',
#  'y ahi que procede esten pendientes de renovar esos jijueputas certificados',
#  'que beneficio me trae el cobro de cuita de manejo que me los van juntando y generando interés en la cuenta me abren un cdt o algo así comentame el “paquete de beneficios” no roben mas a la gente',
#  'cual paquete de servicios yo el único servicio que necesito es usar mi tarjeta sin que me roben mi dinero',
#  'les comparto correo que me llego hoy',
#  'mintieron no atendieron mi problema',
#  'esto fue una bola de humo no me atendieron',
#  'para que para que me sigan diciendo tienes que esperar 15 días para que el me devuelva mi dinero de verdad que mal servicio',
#  'a mi tampoco me llego el ingreso solidario desde agosto',
#  'buenos días',
#  'sigue el error pero yo mejor espero es muy temprano para oscurecer mi día gra iss feliz día',
#  '6 17min en error no se pa q dicen q escribir en dm si por ahí es q dicen no se preocupe estamos trabajando y por fuera hacen creer a todos q el problema se solucionó',
#  'se necesita promedio 40 000 000 de ahorro para cubrir todos los cobros que hace este banco',
#  'con bancolombia uno no ahorra uno pierde su capital se desvaloriza el dinero',
#  'tiemblen bancos usureros llega nubank banco sin filas sin cuota de manejo sin ningun cobro inicialmente tarjeta de crédito el futuro de bancos a favor de la gente no más bancos usureros llegó nubank',
#  'esta violando mi derecho al trabajo parece ser q esta dando referencias falsas y negativas de mi persona o no las da el sindicato antioqueño anda rabon lavaron la plata de pablito y ahora se las dan de puros y cristalino devuelvan el predio donde construyeron',
#  'rt',
#  'hola buenas noches que porcentaje manejan',
#  '',
#  'si quiere que le saquen plata por todo déjelo en un banco  see-no-evil monkey ',
#  'tengo problemas para vincular mi tarjeta de crédito a paypal ¿qué puedo hacer',
#  'pongan una opción que diga menos de un mes',
#  'el viernes me envían un email dónde me informan que adjunto va la respuesta a mi reclamacion de hace mes y dió pero al asesor se le olvidó enviármela ayer mandé un mensaje y no tuve respuesta hoy llamé dos veces y me dan vueltas y no dan solución que más esperar',
#  'con esos intereses de 1 peso mensuales para qué',
#  'espero desde lo más profundo de mi corazón que cambien la app',
#  'a pesar de la resolución 0918 no me dejan movilizar mi dinero en bancolombia respeten mis derechos',
#  'lo ir',
#  'recibí un correo que simula ser de bancolombia con un enlace sospechoso ¿cómo denunciar estos intentos de fraude electrónico el correo de orígen es contacto@co bancofalabella com y el enlace remite a',
#  'y lo malo de es que tarde mas de15 días en devolver el dinero que descuenta de la cuenta de ahorro cuando el crédito hipotecario está al día bravo bancolombia',
#  'rt aún no me da solución pese al comunicado de 0918 y no me permite movilizar mi dinero no es esto una violación de los derechos civiles',
#  'dm',
#  'bancolombia yo he cobrado por modalidad de giro con ustedes en corresponsal pero hace pocos días cree el ahorro a la mano en este pago que se aproxima ya me lo pueden pagar por ahorro a la mano o sigue por giro',
#  'buenas tardes bancolombia qué fecha empiezan a pagar el 7 pago de ingreso solidario para los bancarizados gracias',
#  '12 mil y pico de pesos de manejo de una tarjeta que yo les pagué ustedes son muy hampones',
#  'por favor confirmar si esta notificación es de ustedes',
#  'ok gracias por la colaboración',
#  'srs bancolombia quisiera saber si uds saben algo de este tipo de mensajes con premios',
#  'aún no me da solución pese al comunicado de 0918 y no me permite movilizar mi dinero no es esto una violación de los derechos civiles',
# ...
#  'cerraron una sucursal en yopal por que no se le estaba amontonando los clientes estamos en tiempo de distanciamiento social',
#  'si',
#  'como es posible que estoy haciendo un reclamo y el asesor me cuelgue cuando empiezo a nombrarle mis derechos',
#  'solo con un reclamo y le van a dar gerencia ah no así si me le quejo al que sea',
#  'se volvieron enemigos',
#  'inconforme decepción tristeza d ver una corporación de ladrones ladrones profesionales como el país lleno de corrupción',
#  'cual proceso uds no respetan ni a su madre',
#  'andan mandando estos correos como si fueran ustedes hay manera de denunciar esas cuentas',
#  'delincuentes',
#  'mentirosos dijeron que congelarian las cuotas 3 meses créditos personales y 6 micros hoy están cobrando intereses de esos meses dicen que son atrasados sin abono al capital para quedar bien',
#  'sucedió que son unos putos ladrones 14 años manteniendo mis productos con ustedes 14 años y uds trabajan a sus clientes como ladrones putos mentirosos estafadores',
#  'putos mentirosos explotadores desgraciados',
#  'no no tengo dudas pero no entiendo por qué volver a cobrar si ya probamos que no es necesario los bancos quieren ganar por todo lado podrían dar ejemplo',
#  'mi café favorito  red heart  sparkles ',
#  'hola para abrir una cuenta de ahorros necesito monto de apertura soy venezolano con pep y pasaporte vigente',
#  'que es el dm',
#  'buenas tardes me han generado un descuento de mi cuánta de ahorros de 105000 sin explicación alguna',
#  'la solución de la persona de servicio al cliente fue que llamara a poner la queja después de 2 horas el sistema si estaba lento para las quejas',
#  '',
#  'pésimo servicio 2 horas y no me solucionaron absolutamente nada me van a generar cobros por errores de ustedes mismos y me hacen cobros de manejo de una tarjeta que no me han querido renovar',
#  'buenas tardes que debo hacer para cancelar una cuenta de ahorros',
#  'ya les escribí',
#  'llegó este mensaje de correo y al ingresar a la plataforma apareció error fue en mi primer intento',
#  'siempre pasa lo mismo voy a revisar una referencia bancaria y se bloquea el usuario se bloqueó al primer intento de registro será que me pueden ayudar',
#  'buenos días consulta si una persona tuvo inconvenientes con la justicia y ya no no puede abrir una cuenta de ahorros con el banco por estar en alguna lista lo consulto por qué una persona que conozco le paso ayer fue y le dijeron que no por eso',
#  'buen día me informan que sucede con la fiducuenta intento consultarla y sale un error aparte que muestra saldo en 0',
#  'voy 42 min y contando en la línea de los cuales llevo 38 escuchando música de espera que falta de respeto y cómo cuelgo si puse que quería calificar la pésima atención',
#  'no me están dando solución le repito no he autorizado ningún débito',
#  'la app está caída',
#  'ya lo hice y de ustedes me respondieron que es los que deben solucionar',
#  'para qué me citan al dm si me van a dejar en visto le recuerdo que me están robando 5 millones necesito solución urgente',
#  'ya lo envíe luis sería bueno notificar a banco farabella',
#  'de nada sirve tener muchos de estos pacs s pero todos haciendo lo mismo que mamera de verdad buenos días para cliente no tengo cupo bancolombia',
#  'buenos días me llegó por correo este correo de ustedes falso por favor revisarlo y mirar si pueden hacer algo para que los incautos no le roben de mi parte bloqueo estás cuentas ya no tengo cuenta con ustedes',
#  'llevo más de un mes tratando de que un papel salga con una dirección correcta ha sido imposible 8 horas perdidas al teléfono y en chats todos los asesores salen con excusas diferentes eso es ponerle el alma para aburrirlo a uno',
#  'ya fui a una oficina y me hicieron esperar 8 días para responder que no van a hacer nada',
#  'les escribí por dm',
#  'jajajajaja si vió habló el robot  face with tears of joy  face with tears of joy  face with tears of joy  face with tears of joy  face with tears of joy ',
#  'hace 1 mes solicite tarjeta de crédito y está no ha llegado y lo peor es que a mi correo ya me llegó extracto he llamado 2 veces a la línea telefónica y no me solucionan',
#  'pagué el 2 de oct mi tarjeta directamente desde el dinero al siguiente dia se veia reflejado como pagado aunque uds no me dejaban hacer uso de los fondos hoy 8 de oct me dicen que la plata no ha entrado un mov negativo me van a robar de frente',
#  'y es así como los delincuentes envían correos para engañar y robar a la gente por internet me bloquearon la cuenta que no tengo con bancolombia jajajajaja',
#  'buena aleja  rolling on the floor laughing ',
#  'lo mas charro es que estas cosas que responden uno no sabe si son un robot o qué responden por acá cada pemdejada pero en la vida real no se hablan con el banco igual no resuelven',
#  'súper déspotas las personas que trabajan en atención al cliente y lo mínimo que deberían enseñarle a los empleados es a identificarse ya que si la persona está dando información lo ideal sería poder verificarla definitivamente',
#  'definitivamente les quedó grande la app no pudieron',
#  'un asco que le quiten servicios es injusto que no se pueda hacer una compra de cartera con los servicios del banco la solución es hacer un avance en la tv para cobrar un interés más alto gmf y comisión de avance',
#  'gracias',
#  'llevo ya 3 meses esperando una respuesta esto no parece un banco sino el seguro social  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  grinning face with big eyes  grinning face with big eyes ',
#  'y para que invirtieron tanto dinero en la biometria dactilar es que acaso el se va a robar los dedos de otros que poco diligentes son en estas épocas y en todas deverdad que es el peor sistema de atención al cliente',
#  'quisiera saber cuáles es el nombre de la asesora encargada de esta línea persona grosera y altanera no deja encuentra de satisfacción y le cuelga el teléfono a uno en mitad de la llamada y cuál es la forma de poder hacer una queja a esta persona',
#  'están llegando estos correos a mi cuenta personal reviso mi app y no tengo ningún bloqueo consideró que es correo fraudulento',
#  'que tan real es este correo',
#  'ustedes ofrecen servicios de salud y para mascotas',
#  'por favor cancelen quiero cancelar mi requerimiento tomaré el servicio con otro banco',
#  'app bancolombia a ala mano no funciona y ahora con plata y sin plata manda huevo y me dijeron q mejor sacaran la de daviplata apenasa saque el dinero de bancolombia me paso a daviviend',
#  'son comunes este tipo de correos pishing que puede uno hacer frente a esto esa dirección no puede denunciarse',
#  'rt ya',
#  'ya',
#  'proceso de activación de clave dinámica en la app bastante deficiente y doloroso para el usuario en ningún lado avisan q le bloquearán la clave por 2 horas después de activarla',
#  '3198287421 este número pertenece a su empresa me llaman y saben datos de mi tarjeta de crédito',
#  'si conoces algún proyecto del sector agro o turismo rural que genere valor en su cadena productiva invítalo a postularse en la convocatoria de en campo para recibir mentorías financiación y otros beneficios para fortalecer su modelo de negocio ʘ⁞',
#  'tiempo después pude realizar la transferencia',
#  'jajajajajajajajajaja dizque hola mafaldo jajajajajajajajaja',
#  'haciendo declaraciones de renta a 80 mil pesos que piensa la no hay posturas para hacer respetar y valorar la profesión ayuda',
#  'los llame a su línea telefónica y no me dan ninguna solución inmediata y la culpa es al parecer es de ustedes que reverso el@pago a y por eso me va a suspender el servicio porque tengo que pagar doble ahora',
#  'hola este mensaje es real',
#  'este es el mensaje que me sale voy a transferir a la fidecuenta',
#  'tienen un dm',
#  'esto es lo que me sale cada vez que intento pagar una cuota de mi tarjeta de crédito cómo esperan que uno cumpla si su app falla de esta manera pero para llamar y cobrar sí son veloces',
#  'traté de hacer una transferencia y no me dejó',
#  'el séptimo pago será en este mes de octubre',
#  'no estoy solicitando nada saludos',
#  'ojo con este número que está llamando en su nombre proponiendo devoluciones de efectivo y cuantas fantasías más  thumbs up  thumbs up ',
#  'espero que me alléguen el proceso disciplinario o las medidas tomadas respeto al caso',
#  'quiero seguir manejando la clave dinámica por correo electrónico no tengo en el teléfono y tampoco quiero instalar la aplicación que pasos debo de seguir',
#  'menos mal no tengo productos con ustedes',
#  'ya hice todo eso ya hablé con 4 asesores en 2 días y nada la página no funciona que es lo que pasa',
#  'todo el día pasa así entonces no creo que esté funcionando con “normalidad”',
#  'me reporta error tiga001 al tratar de activar la tarjeta débito llevo 3 días intentando en la página',
#  'la app está caída',
#  'gracias ya reenvié el correo',
#  '20 minutos esperando una clave dinámica ¿la están enviando por 4 72 o qué',
#  'y que es dm',
#  'me gustaría saber si la app tiene una funcionalidad para buscar establecimientos cercanos que sean',
#  'reportando esta información que te llegó recuerda adjuntar todos los soportes te invitamos para que ingreses al siguiente enlace y conozcas más sobre seguridad que tengas una linda tarde jacke',
#  'que suplantan la imagen del banco ten presente que nosotros nunca enviamos enlaces ni solicitamos datos personales a través de estos canales te solicitamos que envíes un correo electrónico a la siguiente dirección correosospechoso@bancolombia com co',
#  'veo con preocupación que me llega un correo de phishing pero en esta ocasión me llega directamente a mi correo no a un grupo en especifico solicito que se investigue por qué mi correo personal está filtrado lo raro es q el correo desde donde lo envían es falabella',
#  'que triste saber que no se puede confiar en este banco debitan el dinero de la cuenta sin autorización un verdadero fraude solicito estudio de mi caso y devolución del dinero ya',
#  'no puedo entrar a etrading en linea porque me figura una cuenta de invesbot en vez de mi cuenta original y no puedo cambiarla',
#  'me gustaría saber que pasa con el aporte del ingreso solidario se están tirando la pelotita entre prosperidad social bancolombia y nequi lo único que quiero saber es cuál es el inconveniente',
#  'ustedes que control tienen sobre sus bases de datos me llega un correo diciendo que han bloqueado mi tarjeta que entre a un link y resultó ser un sitio inseguro hace unos días recibí una llamada dónde pretendían que les diera la fecha de vto de la tarjeta ojo',
#  'ahora me sale este error no me permite hacer ninguna transferencia ayuda',
#  'pendientes clientes quieren robar datos con un correo falso',
#  'com co com co reenvía el correo que te llegó a nuestro email correosospechoso@bancolombia com co te saluda luis',
#  'limpio pero si visualmente está saturada de cosas parece un neceser',
#  'que farsa de aplicación llevó varios días tratando de hacer un trámite y no sirve para nada nadie responde',
#  'rt estoy escribiendo al dm allí pero no obtengo respuesta  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face ',
#  'rt que moral  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face ',
#  'me están enviando información fraudulenta por favor indiquen un canal para denunciar',
#  'que moral  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face ',
#  'ya les escribí pero cómo raro sin soluciones',
#  'no me atrevo a enviar al whats app pero esto me llegó hoy no tengo productos con ese banco',
#  'llamó abancolombia a cancelar una tarjeta de crédito pues no la quiero más primero un asesor dice que no tiene línea llamó de nuevo y me dicen que sólo si verifican mi identidad la cancelan apenas me verifican dicen que no me escuchan y cuelgan',
#  'estoy escribiendo al dm allí pero no obtengo respuesta  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face ',
#  'llamó abancolombia a cancelar una tarjeta de crédito pues no la quiero más primero un asesoró dice que no tiene línea llamó de nuevo y me dicen que sólo si verifican mi identidad la cancelan apenas me verifican dicen que no me escuchan y cuelgan',
#  'para consignaren no se puede entrar al banco te obligan a salir a la fila de la peatonal por una ficha para entrar a la misma puerta del banco donde estaba al llegar donde esta la seguridad',
#  'respetuosamente les reporto ataques cibernéticos con suplantación de la razón social de bancolombia',
#  'rt buen día cuando será que me colaboran con la refinanciación de mi producto ya llevo 3 meses rogándoles y no han querido gestionarme unas cuotas que yo pueda pagar  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  todas las veces que me llaman dicen que aún no sale la respuesta',
#  'buen día cuando será que me colaboran con la refinanciación de mi producto ya llevo 3 meses rogándoles y no han querido gestionarme unas cuotas que yo pueda pagar  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  todas las veces que me llaman dicen que aún no sale la respuesta',
#  '',
#  '',
#  'ya',
#  'señores no es que no sepa cómo usarla lo sé y la uso el problema es que es un enredo demasiados pasos para una información muy visual y poco útil demasiada información inútil demasiados pasos para una transacción sencilla la anterior era más sencilla',
#  'bancolombia que sucede con las transferencias internacionales desde ayer estoy tratando y nada es urgente',
#  'eso es lo q nose',
#  'acabo de llamar y me dicen que tienen incidencias en el sistema que ni para poner la queja les sirve este banco es inservible',
#  'mientras los clientes que se defiendan como puedan increíble',
#  'estoy en bogotá entonces no hay pico y cédula estoy en lo correcto',
#  'buen día sebastián ya mire en la página de ingreso y si soy beneficiario como pasó al dm gracias',
#  'como es eso q los giros los hicieron entre el 29 y 30 de sept yo estuve en pendiente y me decían q no habían autozado los pagos',
#  'buenos días el mismo día respondí las preguntas favor revisar',
#  'buenos días el mismo día respondí las preguntas favor revisar']

# %%
text2 = []

for i in tweets:
    if i not in text2:
        text2.append(i)
        
print(text2)
# Out:
# ['el ya radicó la queja lo que hago es avisar a mis amigos de redes que su app es super insegura', 'ya no pudieron eso es de hace mucho tiempo toco llevarnos la cuenta empresa para otro banco muy regulares en todos los aspectos', '', 'varios amigos me reportan que la actualización de la app es muy insegura ayer a un amigo le robaron un iphone y seguido de eso le robaron dinero de su cuenta bancaria por transferencia desde la app pilas con eso', 'rt encontré con sorpresa la implementación de una dmp dentro del portal transaccional de personas quisiera conocer las políticas de manejo de datos digitales y que información nombrada con exactitud está guardando la dmp y para que la están utilizando', 'señores llevan dañados los cajeros automáticos de la calera 8 días co de sus noches pésimo servicio cambien esas máquinas obsoletas', 'paren ya su acoso ya les dije que no me interesa su cupo de crédito ¿cómo más hay que decirlo para que dejen de bombardearme con su publicidad telefónica y de mensajería', 'por que mi tarjeta débito no tiene cvv', 'creemos más que nunca en su fortaleza y queremos acompañarlas a conseguir un mejor futuro por eso creamos la línea de crédito agro para todas una oportunidad para que puedan alcanzar sus sueños y tener un mayor bienestar', 'y su mundo digital para facilitar su trámite imprima el documento llene a mano ponga su huella quien tiene huellero en su casa después escaneé les falta poner “por último radique en el banco”  rolling on the floor laughing  súper digital  clapping hands  thumbs up ', 'la app de ustedes la mayoría del tiempo está fallando mala cosa', 'malo el servicio en el banco físico y ni hablar del soporte por este medio ahí estoy esperando soporte hace horas …', 'ustedes el mismo cuento de siempre escriba por dm lo concreto y lea todos los twittear es que los tres cajeros que hay en la calera llevan una semana sin funcionar', 'es triste que cada quincena sea lo mismo con uds esa sucursal virtual caída estamos mamaos de eso', 'encontré con sorpresa la implementación de una dmp dentro del portal transaccional de personas quisiera conocer las políticas de manejo de datos digitales y que información nombrada con exactitud está guardando la dmp y para que la están utilizando', 'ya ajusto 20 llamadas en un solo día que fastidio de banco', 'pero entonces no es en este momento ha sido en varios momentos ya que el mismo error tanto desde sucursal personas o empresas lo he tenido en más de una oportunidad', 'le han estado cobrando el 4x1000 a mi madre desde que abrió la cuenta en diciembre y no se ha llegado a ese tope ¿lo hacen con todas las cuentas para pensión a padres de otros amigos le han realizado lo mismo', 'claro que si tatiana  winking face ', 'precisamente día de pago de nómina y la sucursal virtual empresas caída', 'yo le llamaria falsa publicidad porque no estan dando este tipo de credito', 'a qué horas se cae la app de bancolombia', 'pueden hacer una bendita aplicación que no se muera cada quincena', 'gracias angie ya respondí por dm', 'cómo es posible que pague el total de mi crédito hipotecario hace más de 1 mes y ahora resultan cobrando sin saber qué es y nadie responde', 'gracias estefa eres muy amable sin embargo el tiempo se ha extendido más de la cuenta cuando la solución debió ser más oportuna temo que el banco me informes que mi dinero se perdió y me toque emprender un proceso judicial', 'muchas gracias por comunicarte conmigo estefa pero tu respuesta no satisface mis pretensiones es posible que me informes las causas o motivos de la demora en resolver mi caso', 'gracias aunque ni siquiera tengo productos con ustedes y eso lo hace aún más gracioso  face with tears of joy ', 'buenas tardes me podrían brindar asesoría realicé un pago de mi tarjeta de crédito mastercard que tengo con ustedes en el banco pero la pague desde la app de otro banco el pago salió y me confirmó pero la tarjeta en la app personas me aparece la deuda aún', 'claramente ya bloqueé la cuenta que envía es ...

# %%
len(text2)
# Out:
# 732

# %%
new_text = list(filter(None, text2))

new_text
# Out:
# ['el ya radicó la queja lo que hago es avisar a mis amigos de redes que su app es super insegura',
#  'ya no pudieron eso es de hace mucho tiempo toco llevarnos la cuenta empresa para otro banco muy regulares en todos los aspectos',
#  'varios amigos me reportan que la actualización de la app es muy insegura ayer a un amigo le robaron un iphone y seguido de eso le robaron dinero de su cuenta bancaria por transferencia desde la app pilas con eso',
#  'rt encontré con sorpresa la implementación de una dmp dentro del portal transaccional de personas quisiera conocer las políticas de manejo de datos digitales y que información nombrada con exactitud está guardando la dmp y para que la están utilizando',
#  'señores llevan dañados los cajeros automáticos de la calera 8 días co de sus noches pésimo servicio cambien esas máquinas obsoletas',
#  'paren ya su acoso ya les dije que no me interesa su cupo de crédito ¿cómo más hay que decirlo para que dejen de bombardearme con su publicidad telefónica y de mensajería',
#  'por que mi tarjeta débito no tiene cvv',
#  'creemos más que nunca en su fortaleza y queremos acompañarlas a conseguir un mejor futuro por eso creamos la línea de crédito agro para todas una oportunidad para que puedan alcanzar sus sueños y tener un mayor bienestar',
#  'y su mundo digital para facilitar su trámite imprima el documento llene a mano ponga su huella quien tiene huellero en su casa después escaneé les falta poner “por último radique en el banco”  rolling on the floor laughing  súper digital  clapping hands  thumbs up ',
#  'la app de ustedes la mayoría del tiempo está fallando mala cosa',
#  'malo el servicio en el banco físico y ni hablar del soporte por este medio ahí estoy esperando soporte hace horas …',
#  'ustedes el mismo cuento de siempre escriba por dm lo concreto y lea todos los twittear es que los tres cajeros que hay en la calera llevan una semana sin funcionar',
#  'es triste que cada quincena sea lo mismo con uds esa sucursal virtual caída estamos mamaos de eso',
#  'encontré con sorpresa la implementación de una dmp dentro del portal transaccional de personas quisiera conocer las políticas de manejo de datos digitales y que información nombrada con exactitud está guardando la dmp y para que la están utilizando',
#  'ya ajusto 20 llamadas en un solo día que fastidio de banco',
#  'pero entonces no es en este momento ha sido en varios momentos ya que el mismo error tanto desde sucursal personas o empresas lo he tenido en más de una oportunidad',
#  'le han estado cobrando el 4x1000 a mi madre desde que abrió la cuenta en diciembre y no se ha llegado a ese tope ¿lo hacen con todas las cuentas para pensión a padres de otros amigos le han realizado lo mismo',
#  'claro que si tatiana  winking face ',
#  'precisamente día de pago de nómina y la sucursal virtual empresas caída',
#  'yo le llamaria falsa publicidad porque no estan dando este tipo de credito',
#  'a qué horas se cae la app de bancolombia',
#  'pueden hacer una bendita aplicación que no se muera cada quincena',
#  'gracias angie ya respondí por dm',
#  'cómo es posible que pague el total de mi crédito hipotecario hace más de 1 mes y ahora resultan cobrando sin saber qué es y nadie responde',
#  'gracias estefa eres muy amable sin embargo el tiempo se ha extendido más de la cuenta cuando la solución debió ser más oportuna temo que el banco me informes que mi dinero se perdió y me toque emprender un proceso judicial',
#  'muchas gracias por comunicarte conmigo estefa pero tu respuesta no satisface mis pretensiones es posible que me informes las causas o motivos de la demora en resolver mi caso',
#  'gracias aunque ni siquiera tengo productos con ustedes y eso lo hace aún más gracioso  face with tears of joy ',
#  'buenas tardes me podrían brindar asesoría realicé un pago de mi tarjeta de crédito mastercard que tengo con ustedes en el banco pero la pague desde la app de otro banco el pago salió y me confirmó pero la tarjeta en la app personas me aparece la deuda aún',
#  'claramente ya bloqueé la cuenta que envía esos mensajes me causa gracia que ni siquiera se esfuerzan en cambiar el dominio del remitente y dejan banco falabella  rolling on the floor laughing  rolling on the floor laughing  woman facepalming ',
#  'ellos cajeros fallan y se quedan con la plata los aplicativos de consulta en el call center no funcionan de la personal cero actitud de servicio disculpen srs que les sirve',
#  'buenas tardes bancolombia yo cobro por modalidad de giro con ustedes y hace 1 mes abrí una cuenta de ahorro a la mano en este pago que se aproxima ya me empezan a pagar x cuenta o me van a trasladar a supergiros gracias',
#  'por favor me confirma si el tiene el absurdo cobro por retirar de cajero en otras ciudades por favor explicar ese atropello cómo validar los topes de estas injustificadas y desmotivantes políticas de la banca en colombia',
#  'que ya la tengo inscrita',
#  'yo te escribí por dm',
#  'no me solicitaron pago mínimo',
#  'deisyb si alguna vez te hace una marranada financiera recuerda muy bien este tw es un sentimiento de impotencia solo espero hacer lo posible para pagar y nunca mas volver a verlos la gente sabe que como banco no tienen nada que perder que nadie les pague',
#  'reexpedición',
#  'buenas tardes me gustaría saber el horario de atención de la sucursal en zipaquira gracias',
#  'no amiguitos esas excusas ya no valen ustedes reflejaron las porquerias que son con los colombianos no les importo que muchos estuvieran endeudados otros pasando necesidades pero vaya uno no pague lo que ustedes dicen y verá asco de banco',
#  'si lo lamentan pero no hacen nada para solucionar  face with rolling eyes ',
#  'ya estoy inscrito estoy tratando de hacer un pago pero la clave dinámica no llega o llega media hora después cuando ya no sirve',
#  'buenas tardes ya les respondí por dm toda la información q solicitan para q de manera inmediata me devuelvan mi dinero información que ustedes deben tener pero por su ineficiencia y para ganar tiempo se les hace más fácil que el cliente se las suministre',
#  'ajaaaaaaaaaaaajaaaaa',
#  'me ayudan tengo que activar una cuenta que abrí por medios digitales y no he podido',
#  'respondí por dm',
#  'un crédito de libre inversión interpuse un dp con uno de sus asesores telefónicos después de que alguien de redes sociales me llamará y no pueden encontrar el requerimiento sin el número de radicado en pleno siglo xxi que empresa no puedo encontrar un radicado con otros datos',
#  'la gerente dice que es el protocolo de bioseguridad le pregunto donde esta exhibido y dice lo tengo en el computador',
#  'bancolombia sucursal parway media hora para que la gerente salga brava a atender y decir que nonabre la puerta no dejan entrar al banco',
#  'es el 4to mes en donde estoy pagando los intereses de un periodo de gracia de 3 meses que no pedí hasta cuándo voy a pagar esos intereses',
#  'ya le escribí por dm espero su pronta respuesta',
#  'reyes del pésimo servicio cambian para empeorar',
#  'hay problemas con clave dinamica',
#  'buenos días una pregunta ¿que es el débito sucursal bancolombia y ¿cuánto e el monto máximo a descontar gracias',
#  'no funciona esa clave dinámica',
#  'que fea mala lenta en 15na bancolombia muere',
#  'cuando me acerco a sus oficinas a buscar una alternativa y me dicen que ya no hay turnos que llame que llame a los que me dicen que lo único que tengo que hacer es pagar qué fastidio de banco',
#  'cuando llaman y me piden una cantidad de datos que cada llamada les tengo que suministrar para que la única información que dan es que o pago o me reportan qué fastidio de banco',
#  'quincena o fin de mes la plataforma caída que raro no  grinning squinting face  grinning squinting face  grinning squinting face  grinning squinting face  grinning squinting face ',
#  'cuando solo llaman y dice que si no pago me reportan como si en esta situación eso fuera realmente preocupante antes que otras prioridades qué fastidio de banco',
#  'alivio para ustedes será',
#  'bla bla bla llevamos 5 veces hablando con el banco y no dan solución es un descaro',
#  'se llama camila',
#  'rt asuman su responsabilidad y dejen de robarle a la gente no sean descarados',
#  'perdón que es dm',
#  'ya les escribí por dm',
#  'con hasta 20 llamadas diarias de cobro y siempre se les dice lo mismo qué fastidio de banco',
#  'vergüenza de banco ladrones con permiso para robar',
#  'necesito comunicarme vía telefónica con un asesor y no atienden las llamadas  weary face  weary face  que rabia el caos de',
#  'me dieron hoy una respuesta por cierto carente de información para un evento que terminó ayer mejor dicho de nada sirvieron los canales de comunicación con ustedes',
#  'rt que van a revisar si ya descontaron el dinero  woman shrugging light skin tone  acaso lo piensan devolver  woman shrugging light skin tone ',
#  'rt no se preocupe me tomé el trabajo de ir hasta una oficina y ni soluciones ni respuestas claras cuando les pregunté por qué nunca me explicaron desde el principio el escenario real de la situación ustedes son un karma para el usario',
#  'mala mala mala esa app siempre arroja error hasta para hacer el pago de un producto',
#  'que es lo que pasa com esa app no sirve para nada ¿como novedad hoy tambien esta caída',
#  'lo he dicho el banco más ladrón de colombia junto a los del nadie los controla roban a pueblo multiplican el dinero que usaron para comprar la presidencia y mantener el poder de hacer lo que quieran sin control',
#  'escribí hace rato y ahí me quedé igual que en las llamadas que ineptitud la cacha del culo estos pingos',
#  'esto lo he realizado por dm en varias ocasiones y ha todos les explico y luego me dejan disque esperando respuesta del area encargada y así ha pasado casi 3 meses quiero que me contacte un asesor por vía telefónica',
#  'indolentes y alejados de la realidad mundial acosan y lastiman la salud mental de sus clientes que fastidio de banco',
#  'siempre me mandan al dm para no darme ninguna respuesta exacta y correcta me habían dicho una cosa y hoy que llamo a preguntar por el radicado me dicen otra no se quién es más ratero si o',
#  'deberles a ustedes es peor que matar un cura que karma que fastidio',
#  'que desespero tener una mora con ustedes 15 llamadas al día para decir que pague respeten',
#  'yo llevo 9 llamadas a ese dizque centro de ayuda para cancelar una puta tarjeta de crédito que ni la tengo porque me cancelaron el plástico y no lo mandaron pero igual cobran la cuota de manejo después preguntan porque uno apoya los vándalos',
#  'para qué si no hay respuesta',
#  'es que cualquiera puede estrar a mi cuenta un día cualquiera y cogerme lo que les de la gana quien me dice a mi que no fueron ustedes ustedes se lavan las manos que seguridad le están brindando a uno uno no es adivino para saber que era 7n fraude en la semana m',
#  'pido la respuesta formal a mi reclamo de reintegro de hace 2 meses y me envía un email con una respuesta de otro reclamo de hace 3 meses negligencia o burla',
#  'estoy intentando que me envíen un email con la respuesta adjunta de un reclamo de hace 2 meses y mandan el email vacío es una burla o es negligencia del asesor pero igual no logro tener solución a mi reclamo',
#  '3 llamadas a la línea de atención al cliente pero el asesor me deja esperando hasta que se corta la llamada y se pierde todo lo adelantado y lo peor es que los asesores no tienen el mínimo detalle para devolver la llamada y dar solución al problema del cliente',
#  'en el barrio san luis también pasa lo mismo de los dos cajeros sólo está funcionando uno frente al supermercado la canasta campesina',
#  'perdone gustavo la palabra pero mas pendejo usted que no siguió pagando normalmente el tal alívio nunca existió porque simplemente debía seguir acumulando intereses sobre toda el capital desde el inicio cuando lo escuché me pareció la estupidez mas grande',
#  'me van a devolver es una pendejada escribir al interno no solucionan nada solo les preocupa la mala publicidad no van a solucionar nada',
#  'cómo sería',
#  'necesito ayuda por favor dm',
#  'increíble que presten un servicio tan malo no son capaces de solucionar un problema que es de ellos ni siquiera respetan el tiempo de los clientes más de 15 llamadas para que me solucionen y nada pouting face  pouting face  el peor servicio en banca lo tiene',
#  'como puedo cancelar la cuenta sin ir al banco a través de la web',
#  'ya puse las quejas y ya me respondieron que no me podían responder que había sido víctima de un estafador pero quede muy triste que garantías y seguridad le brindan a uno sus cuentas',
#  'son un chiste  face with tears of joy ',
#  'tiene una publicidad que dice esa app se convertiría en el empleado del mes  expressionless face  olvidaron que detrás de una app hay personas que programan piensan y trasnochan rocket  si una app es buena las personas son los las empleados del mes  red heart ',
#  'hola ya el inconveniente fue solucionado',
#  'le está poniendo el alma',
#  'no se preocupe me tomé el trabajo de ir hasta una oficina y ni soluciones ni respuestas claras cuando les pregunté por qué nunca me explicaron desde el principio el escenario real de la situación ustedes son un karma para el usario',
#  'responda que uds le van quitando el dinero a la gente por cada movimiento con su propia plata',
#  'como asi que solo responden por el 50 de la plata si el error fue 100 de ustedes',
#  'hicieron cargo a mi cuenta por una compra en amazon la cual no fue procesada pero bancolombia me debitó el monto y no me lo ha devuelto en los teléfonos que dice debo llamar nadie se digna atender les agradezco procedan a devolver mi dinero de manera inmediata',
#  '¿ya resolvieron esta situación la respuesta debe ser asumir ustedes',
#  'son campeones con el dinero de sus usuarios algo parecido sucede cuando los cajeros automáticos no entregan el dinero el usuario debe de esperar un día hábil para devolver el dinero pero cuando es el cliente que se demora un día ellos te cobran intereses',
#  'llevo pidiendo días un extracto del mes de enero y siempre me envían el de febrero y marzo sean serios lo necesito urgente',
#  'cúcuta norte de santander y en el municipio de bochalema el ubicado parque central quedo atento a su respuesta',
#  'me están pidiendo datos de mi sitio de trabajo',
#  'les sobra una r en el correo',
#  'yo tengo un préstamo con sofi y no tengo empleo y siempre que me llaman me ofrecen ciertos alivios que realmente lo que me ofrecen es extender las cuotas con doble interés vivasos por cierto ya me tienen aburrido cada 3 días llamando',
#  'alivios me hicieron préstamo 20mll en marzo comenzó la pandemia me dieron el alivio ahora ya van en 3 millones de intereses y me llaman xa financiar toda la deuda disque no me cobran un mes y los intereses por las nubes pido envíen estracto de intereses y nada',
#  'bank in the world just like is the worst airline in the world how do these companies that provide shit service stay in business well it wont be much longer for avianca and maybe will be soon after service',
#  'operates the worst bank in the world nothing ever changes with this crap bank today in victoria in pereira we waited over 2 hrs in line with hundreds of people and even though they accepted us on the line for hours the bank closed and they said no more people shit',
#  'ratas',
#  'bancolombia roban por todos lados por tarjetas extranjeras cobran por transacción hasta 18 mil eso es un descaro ahora todas las arandelas que hacen para ir sacando dinero de cada cuenta un robo totál',
#  'y flypass cerrarán negociaciones con nuevos parqueaderos en bogotá y medellín  automobile  sport utility vehicle  que aceptarán este medio de pago sin contacto  high voltage  high voltage  actualmente los estacionamientos de oviedo y el aeropark  deciduous tree  deciduous tree  tienen el servicio disponible',
#  'movilizará 140 000 millones de dólares en servicios financieros en los próximos 10 años el anuncio se dio en el encuentro de la alianza global de inversores para el desarrollo sostenible de la onu lee aquí cómo se orientarán estos recursos  backhand index pointing down  …',
#  'muy alegres ante la desgracia ajena que ustedes empeoran se les recomienda no ser tan festivos y más nuevos buscar soluciones en las que honren la confianza y la buena fe de quienes ponemos nuestro dinero en sus manos al menos para no lucir como cínicos',
#  'lo paso por un sandbox y luego trato de notificarlo a pero como sus plataformas nunca sirven pues dejo así',
#  'rt para qué le van a devolver la plata díganlo enseguida o le va a repetir la misma información que ya le dieron y ya sabe',
#  'esto lo puedes realizar en la configuración de tu dispositivo móvil saludos',
#  'no tienen en cuenta la posible reactivacion economica no todos son empleados del estado  pouting face  pouting face  pouting face  pouting face ',
#  'coloca la actividad económica 0090 de rentista de capital ya que no hay una que indique que es sostenida por sus padres mentiras lee bien los ciiu previamente a tramitar el rut sino quieres es mas fácil aperturar nequi pero si te recomiendo luego migrar a un banco',
#  'nunca fueron claros en las líneas telefónicas decían una cosa y por correo decían otra ante tanta incoherencia e información tan poco clara lo mejor era si se podía cancelar cualquier deuda',
#  'de esta dirección me llegan bastantes correos informacion@mailgrupobancolombia com co',
#  'jajajajajajaja',
#  'ahhhh bueno fue solo un problema de falta de claridad de información la próxima vez sean mas claros a la hora de desplumar a la gente',
#  'devuelvan el dinero',
#  'eso es lo único que hace bancolombia quitar el dinero cobrar mal dar mala información y ahora todos los usuarios están quedados menos mal están demostrando como son tendencia por mal banco y como están llegando competencias fuertes para tumbarlos no mas bancolombia',
#  'rt cuantos favs y condonan en su totalidad una deuda con ustedes',
#  'hijueputas',
#  'mil gracias',
#  'el sitio es de ustedes si sí muy extraño que requiera un login por fuera del sitio de sucursal virtual personas si no están enviando correos que tienen mala pinta',
#  'es tendencia solocitar a empresas o personas determinada cantidad de me gusta likes favs para obtener algo a cambio dicho esto ¿cuantos me gusta likes favs para condonar una deuda que tengo con ustedes',
#  'yo tenia que abrir otra ventana de mi celular para ver la dinámica',
#  'no sean ratas',
#  'lo abro les mento la madre a los ladrones les pregunto por acá a ustedes cuál es el correo para informar lo del pishing ya luego lo reenvío y lo elimino',
#  'pero yo no trabajo mis papás me mantienen todavía jajj',
#  'esa manía de ustedes de querer obligarlo a uno a inscribir las facturas para pagar a través de la sucursal virtual ahora la famosa clave dinámica desde la app no sirve no sé por qué inventan tanto disappointed face ',
#  'depende si es un enlace porno le echo un ojito primero de rapidez y ahí sí lo borro  face with hand over mouth  face with hand over mouth  face with hand over mouth ',
#  'en pocas palabras ratas  mouse ',
#  'les pregunté por acá si necesitaba el rut para crear la cuenta y me dijeron que me tenía que acercar a una sucursal física para que allá me dijeran si era necesario o no',
#  'no me ha querido servir en todo el día  face with rolling eyes  woman facepalming light skin tone ',
#  'que falta de honestidad del banco y de la persona que recibió el dinero por error que  face screaming in fear  face screaming in fear  face screaming in fear  angry face  angry face  angry face ',
#  'pura mierda congelaron el cobro de los créditos pero los intereses crecían como si el cliente hubiera dejado de pagar porque sí troncos de rateros a mí me quitaron 500 mil y punta de interés',
#  'la mejor forma de protegerte del phishing es identificar si es una estafa para hacerlo reenvíalo a corrreosospechoso@bancolombia com co estos son 3 elementos que podrás encontrar en este tipo de correos ʘ˧',
#  'demasiado cínismo  face screaming in fear  face screaming in fear  face screaming in fear ',
#  'son unas ratas mejor busquen otro banco como colpatria o otros estos hp cobran 12 000 de cuota de manejo y sin importar la pandemia ratas hp',
#  'rt ratas hijueputas abusando de la gente',
#  'ratas hijueputas abusando de la gente',
#  'buenas tardes mi esposa y yo tenemos cuentas de ahorro de bancolombia y manejamos un solo celular yo ya tengo registrado la clave dinámica con mi cuenta se puede registrar también la cuenta de mi esposa con el mismo celular no tenemos más celular que hacemos',
#  'responde por eso tal vez el cajero y su gerente para no ponerse en evidencia ante medellin tratan de resolverlo ellos pero la central del banco responde por todo seguro obvio hay perjuicios pero el capital no se pierde duerma tranquila',
#  'cuantos favs y condonan en su totalidad una deuda con ustedes',
#  'le ha bloqueado la cuenta 2 veces a mi mamá no la deja hacer transferencias pagos o lo que sea pero sí reciben la plata que le envían a ella y fue a solucionarlo le cambiaron la tarjeta y al otro día la misma mierda a qué juegan',
#  'les contacte primero por los canales internos y es muy molesta la respuesta de sus asesores toman decisiones unilaterales siempre sin pensar en las personas',
#  'buen dia a mi me han llegado correos parecidos diciendo que digite mi documento para saber el extracto',
#  'seguro me invente la falla',
#  'no carolina nada qué hacer',
#  'otra vez su plataforma de pse fallando como si no fuera importante tener el soporte de pago',
#  'daniel el inconveniente te lo estoy mostrando en la imagen saludos',
#  'ya me he comunicado con anterioridad y en múltiples ocasiones por dm por email por línea telefónica y no pasa nada si de verdad quiere deme indicaciones de la queja y',
#  'un iphone 12 pro plus max xt por favor con la cuota de 9 900 gracias',
#  '1 si el asunto es urgente el destinatario no concuerda y te piden descargar archivos elimínalo \u200b 2 si parece ser del banco y te pide clave usuario y número de la tarjeta reenvíalo a correosospechoso@bancolombia com\u200b ʘ˧',
#  'hola cada que marcó al 5109000 me aparece davivienda y no tengo ese número guardado con nombre de davivienda',
#  'no loren por privado lo vacilan a uno y se hace lo que uds quieran y como uds quieran es mi dinero y deberian sostener las garantias que me ofrecieron al momento de adquirir el producto prefiero cancelar mis productos con uds y presionar la empresa para me pague con otro banco',
#  'estaremos observando cualquier cosa gritas',
#  'de repente y sin autorizacion cambian mi plan de cuenta como les da la gana cobrando extra y me lo tengo que tragar si toca que la empresa me pague la nomina en cheque o en monedas pues lo acepto pero esa cuenta se cancela',
#  'muchas gracias por la información',
#  'y me siguen llamando del 304 550 3348 no quedo claro ayer que no quiero recibir mas este tipo de llamadas no me interesa por que vendieron mis datos',
#  'ni lo recomendaría a bancolombia ni lo recomiendo fue el banco que se aprovechó de la necesidad de sus clientes en la pandemia para hacer de la suya',
#  'ok ya escribí por interno',
#  'buenas tardes hay inconvenientes con la app',
#  'ojalá lo implementarán',
#  'a ver si por aquí responden ¿de cuánto es el descuento ¿cómo se accede a él',
#  'qué está pasando con la seguridad de información de los usuarios ya conozco 3 casos incluyendo el mío sobre el bloqueo de la cuenta porque alguien intentó meterse desde la sucursal virtual por favor expliquen lo que está sucediendo',
#  'buenas tardes muchas gracias en la actualidad tengo dos crediagil y dos créditos tasa fija estoy sin trabajo desde el pasado mes de abril y quiero postularme al congelamiento de la deuda hasta dic es posible ante la incapacidad de pago',
#  'no he podido enviar el mensaje dm',
#  'el peor servicio de bancolombia solo atienden por línea telefónica y dicen que espere su llamada y llevo 5 meses esperando que me llamen',
#  'que servicio tan malo de sus cajeros electrónicos la mayoría de las veces que voy no sirven ¿entonces para qué están lo que hace le hace a uno perder el tiempo  pouting face ',
#  'hola ya respondí por dm espero pronta solución gracias',
#  'eso me llego hoy',
#  'estoy esperando su respuesta por dm nuevamente me acabaron de llamar a preguntar por alguien que no soy yo',
#  'asuman su responsabilidad y dejen de robarle a la gente no sean descarados',
#  'quisiera saber si esta información es verdadera gracias',
#  'pues ya estoy en dm',
#  'hola muy buenas tardes santi me sale un error que me debo inscribirme a la clave dinámica pero lo raro fue que hace unas horas antes había hecho una transferencia y yo ya he llamado y he hecho el procedimiento para la clave dinámica me genera el problema muy seguido',
#  'esto es cierto o es algo anormal',
#  'me llega este mensaje es verdad o es una estafa',
#  'el cajero del parque central del municipio de bochalema también presenta problemas y es el único que hay',
#  'es por el bien de todos que hago esa queja es muy molesto que siempre se vea la aglomeración de personas en los cajeros bancolombia y además se presta para que los amigos de lo ajeno hagan de las suyas faltan protocolos de bioseguridad por lo menos un antibacterial en los cc',
#  'para qué le van a devolver la plata díganlo enseguida o le va a repetir la misma información que ya le dieron y ya sabe',
#  'el numero del celular que envío el mensaje es 316 334 66 30 para que tengan en cuenta y pongan en reporte esta modalidad de fraude gracias',
#  'cúcuta norte de santander',
#  'hola buenos días en la mañana de hoy recibí un mensaje que dice así felicitaciones hoy movistar y bancolombia te felicitan por ser el ganador de 10 000 000 comunicate ya pbx 301248090 cdg 750 aut coljuegos y este es el numero donde me enviaron el mensaje a mi',
#  'ya pude solucionar gracias los tkm',
#  'que servicio de porquería',
#  'cómo sería para desbloquear mi ip y poder entrar a la sucursal desde mi wifi',
#  'buenos días sucede que aparezco en bancolombia beneficiada de ingreso solidario y no me han cancelado ningún giro',
#  'apreciados señores tengo varios créditos con ustedes libreinv y crediágil y desde el mes de abril estoy sin trabajo podrían indicarme que debo hacer en este caso para acogerme al periodo de gracia hasta diciembre de acuerdo a la última circular de la s financiera',
#  'por la pandemia y mi labor no puedo estarme movilizando hasta allá a verificar esos códigos además tengo entendido que para eso tienen personal técnico me parece el colmo del descaro seriedad por favor',
#  'cc unicentro sólo sirve 1 o 2 cc jardín plaza 1 de 4 cc ventura plaza solo sirve 1 barrio san luis solo sirve 1 av libertadores más abajo del cai niza 1 de 4 av cero al lado de mkgusto solo sirven 2 y en el parque central de bochalema el único que hay dañado',
#  ' raising hands  raising hands  raising hands  thumbs up  thumbs up  Colombia  Colombia  Colombia ',
#  'nos van asesorar sobre sus utilidades en la pandemia',
#  'acabo de hacer un pago a por un dispositivo nunca usado y la clave dinámica en el celular funcionó perfectamente sencilla y segura',
#  'estan respondiendo vainas locas que no concuerdan ni con la fecha de compra no saben donde estan parados  pouting face ',
#  'los odio',
#  'privado para que para que no se den cuenta lo ratas que son ustedes',
#  'llevo tres días intentando realizar una transferencia y me indican que me comunique a la línea luego llamo a la línea y me informan que hay un incidente pero no dan información de qué se trata ni para cuando hay una solución para cuándo se soluciona el incidente',
#  'ya les escribo',
#  'señores tengo casi dos meses esperando un reembolso de dinero y aun nada se piensan robar la plata',
#  'phishing llegó a mi correo',
#  'cómo así que debemos migrar la clave dinámica a la app personas desde el 20 de octubre cómo hacen las personas que no tienen teléfonos inteligentes y todo lo haces es a través del pc me toca comprarle un celular a mi abuela para eso o uds se lo regalaran',
#  '3125080487',
#  'entiendo esto pero no me importaría tener un rechazo y generar nuevamente el pago como en otras entidades bancarias es absurdo tener que esperar 3 días para hacer un pago urgente',
#  'gracias pero ayer llame al banco y ya me aclararon la información y me dijeron que se demora hasta tres días la inscripción de una cuenta a otro banco y pues nada me toca salir hoy a retirar y desplazarme hasta el otro banco para hacer la consignación que ayuda en la pandemia',
#  'a mi me parece terrible que inscribir una cuenta de otro banco se demore hasta 3 días y más cuando uno la necesita hacer urgente este es único banco que me encuentro que hace esto y realmente es molesto',
#  'que van a revisar si ya descontaron el dinero  woman shrugging light skin tone  acaso lo piensan devolver  woman shrugging light skin tone ',
#  'ayer al mediodía inscribí una cuenta para hacer un transferencia urgente y esta es la hora que la cuenta no ha quedado inscrita me parece el colmo que me digan que se puede demorar hasta tres días respeten que la necesito hacer urgente soy nueva en bancolombia y no me gusta',
#  'banco llamé el viernes a cancelar una tarjeta de credito virtual me dijeron que la cancelación se vería reflejada en 1 día hábil hoy miercoles sigo viendo activa esa tarjeta necesito cancelarla antes de que me cobre manejo colaborenme por favor',
#  '1 mes sin solucionar lo del pago total a mi crédito hipotecario quieren más plata quieren robar más',
#  'llevo más de 1 mes sin solucionar mi pago de crédito hipotecario que más quiere robar',
#  'quiere decir que van a dejar a lod adultos mayores sin posibilidad de que les ayudemos a hacer sus pagos ya pensaron en ese segmento de clientes son clientes que no usan la app ni la van a usar uds los están obligando a salir a un banco y nos quitan la posibilidad de ayudarlos',
#  'tu atención al cliente es horrible y tu app es lenta e inoperante como proceso burocrático',
#  'espero que con ese mismo fervor y patriotismo se encarguen de arreglar los cajeros en cúcuta en todos los cc y en general muy pocos sirven y se aglomera la gente por su culpa sean serios y respeten los usuarios',
#  'vamos tigre gracias bancolonbia por ser patrocinador de la selec',
#  'al consultarme me sale esto no entiendo porque dicen que ustedes no me pagan si mis primeros 4 giros los cobre con ustedes',
#  'falcao te mereces otro hijo',
#  'esperanza la que yo tengo de que no empiecen a cobrar las transferencias a otros bancos para robar más plata',
#  'vieron ese gol jajaja eso merece que no le cobren tasa nominal en el mes de octubre  hundred points  victory hand  Colombia ',
#  'grande falcao tigre de tigres',
#  '4',
#  'me gané mi primera polla  yellow heart  yellow heart  blue heart  red heart ',
#  'ustedes procuren mejorar la aplicación que bien lenta si está',
#  '6',
#  '6  index pointing up medium-light skin tone  index pointing up medium-light skin tone ',
#  '5  flexed biceps light skin tone ',
#  'ladrones',
#  '2  backhand index pointing up  folded hands medium-light skin tone  red heart ',
#  '5  flexed biceps ',
#  'obviamente no están teniendo en cuenta a estos 10 millones de hijueputas que grandes',
#  'arreglen esa porquería de app en vez de estar twiteando maricadas',
#  '5 vamos por el empate',
#  '1',
#  'rt en su comercial dice que vuelven a latir 40 millones de corazones y los otros 10 millones  pleading face ',
#  '1  raising hands ',
#  '1 a echarle cabeza mijos thinking face  thinking face ',
#  '1 cabeza fría',
#  'no es cierto',
#  '7',
#  'y esto que es de nuevo app bancolombia caida',
#  'otra vez caida la app de bancolombia',
#  'rt ladrones',
#  'hoy se anotó dos golazos en mí cuenta debitandome sin mí permiso 200 000',
#  'promocionando fútbol mientras las personas que tienen su dinero en tienen que hacer enormes filas en cartago bajo el inclemente sol soportando por horas temperaturas superiores a los 30° pésimo y nefasto servicio',
#  'me acaba de debitar 200 000 sin justificación alguna y no me dan razón en la línea telefónica ¿ahora sus formas de ganar utilidades es literalmente robándole al ciudadano',
#  'dudas no tengo pereza de usarla pero pues toca porque uds no escuchan a los usuarios hay algo fundamental en el diseño de cualquier cosa y es la usabilidad parece que los diseñadores de su app desconocen el término',
#  'solucionado gracias',
#  'me están llegando estos mensajes al correo',
#  'porque no me dan la opción de descargar certificado de crédito hipotecario lo requiero para declarar renta ya que no lo reportan en la rete fuente que me enviaron solicite por teléfono el documento dijeron que tardaba 6 horas aún no llega',
#  'me ha quitado más plata de la que saco',
#  'otra vez falla en la app no me deja trasferir',
#  'todas sus campañas de alivio son una mentira si de la sucursal telefónica nos envían al punto físico no saben dar explicaciones es mentira sus alivios y hacen que los productos entren en mora para cobrar intereses',
#  'ah claro me imagino que a él nunca se le ocurrió comunicarse con el banco',
#  'el banco que dice colocarle el alma a los colombianos más bien le está partiendo la madre a los colombianos',
#  'o me solucionan la@situación o me encargaré de llevar esto hasta las últimas consecuencias mi hija viaja y la única tarjeta que tiene es con bancolombia y es un deber de axa expedirme el certificado de asistencia',
#  'que el el dm otras 5 horas colgada al teléfono por qué sume que se que quiere decir ese término',
#  'inaudito que una entidad tan prestigiosa como la de ustedes jueguen con el cliente de la forma como lo hacen llevo tres días solicitando certificado de viaje internacional y me ponen al teléfono 60 minutos y cuelgan la llamada es una obligación y lo exijo',
#  'como es posible que he solicitado la cancelación de una tarjeta de crédito 3 veces con bancolombia y siempre me dan vueltas y me sacan peros y no finalizan el proceso esto es un atropello al consumidor',
#  'cuanto hay que reclamar para que una persona le cancelen una tarjeta de crédito que ya no desea que tomadera de pelo es increíble',
#  'debo expresar públicamente que ante el problema manifestado y a pesar de estar en el exterior el equipo bancolombia me a contactado y me ha brindado un servicio de atención rápido y excelente quedo muy agradecido y espero muy pronto una resolución satisfactoria del caso',
#  'me realizaron un giro desde canadá el día 01 del mes en curso a la fecha no se registra en mi cuenta debo ir a una oficina para retirar o puedo hacerlo consignar en mi cuenta por medios electrónicos',
#  'les dejé mis datos de contacto por dm espero que esta vez sí pregunten por mí',
#  'que pasa con la aplicación que no aparece la clave dinámica y uno con afán de pagar sus obligaciones',
#  'les envíe el dm hace 10 mins',
#  'sucursal virtual web y móvil por ningún lado funciona',
#  'daniel es tu compañero yo soy ricardo he hablado durante un mes con personal de las áreas de servicio al cliente y conciliación y no tienen una solución quiero conocer los procedimientos de',
#  'porque no me deja ingresar con mi huella  exploding head  exploding head  exploding head ',
#  'enviado',
#  'puedo saber por que me dejan esperando en linea mas de 1 hora esta es la segunda llamada q hago y me dejan en linea por q no puedo cancelar esa tarjeta de crédito del demonio ni tiempo también merece respeto',
#  'daniel ya lo he hecho y no me dan solución me dicen que esta persona debe actualizar sus datos él ya lo hizo pero ustedes no retiran mi número del sistema ya he hablado con el área de servicio al cliente y tampoco tienen una solución por eso le escribí a',
#  'bobo aquel que caiga en sus trampas',
#  'pues aún estoy esperando que me atiendan llamo a la línea de atención al cliente escribo al dm y nada absolutamente nada me han ayudado',
#  'me agenda citas para que sus agentes me llamen y me cuelguen  face with tears of joy  a ver si me contestan',
#  'que sea por el correo por la app ha sido mi peor experiencia pense que iba a ser mas facil y resulta que meto la clave que aparece y nunca es valida ya estoy estresado con esa situacion no puedo movilizar mi dinero',
#  'yo llevo todo el día tratando de que me informen porqué me están cobrando 500 mil pesos por el congelamiento de mi crédito hipotecario y nadie me sabe explicar absolutamente nada esa es la ayuda que le dan a los colombianos',
#  'cambien esas máquinas eso ya tecnología vieja',
#  'ustedes tienen esa información ahorita me desplazo los 10 kilometros desde donde vivo que desgracia perder el tiempo con ustedes',
#  'entonces porque me llaman a vender seguros de parte de una entidad relacionada con banclombia yo no les di permiso para eso',
#  'mary ya escribí espero pueda obtener una respuesta por este medio',
#  'que hace con mis datos personales ¿por qué los venden a empresas que venden seguros quien regula esto la que inseguridad quien más tendrá mis datos',
#  '¿es legal que me pida más datos personales como mi número de cédula para dejar de llamarme cuando no tengo ni tendré ningun producto con ellos',
#  '¿donde puedo llamar',
#  'lo sentimos usted no está autorizado para marcar este número  person shrugging medium-dark skin tone ',
#  'ya les envié la información espero que no me llamen más cc',
#  'scar una tarjeta',
#  'la única validación que tienen que hacer es eliminar mi número telefónico de su sistema',
#  'señores es hora de cambien los cajeros de la calera por tecnología nueva las que están son maquinas obsoletas',
#  'quiero saber si me enviaran mensaje de texto para cobrar mis giros por nequi freddy lizarazo',
#  'lo que uds hacen con los adultos mayores es irresponsable el viernes tuvieron a mi papá adulto mayor 2 horas para abrir una cuenta de ahorros y desbloquear otra cuenta hoy le volvieron a bloquear sus cuentas la solución ir nuevamente al banco',
#  'hasta cuando los abusos incumplen promesas y acuerdos te hacen pagar corriendo a “su tiempo” y nunca cumplen lo que se supone me “otorgaron” desde julio',
#  'señores ustedes son lo peor como institución fuera la primera vez esto ocurre cada 8 dias',
#  'la nueva aplicación es un problema no una ayuda para los clientes',
#  'son sus políticas institucionales y las entiendo pero no las comparto me parece una falta de empatía que en semejante contingencia uno tenga que ir a ponerse en riesgo a una sucursal porque ustedes no aceptan abonos a capital por ningún otro medio',
#  'hola tati ya se arregló jejeje besitos',
#  'llamo desde su página me tienen 20 minutos como una estúpida cuando por fin me atiende el que se supone me resuelve dice cliente no responde y yo a el lo escucho perfecto los odio como le van a bajar el rendimiento a una inversion porque sí',
#  'el servicio de atención al cliente por teléfono es tan nefasto que marca una alguna de las opciones y lo que hacen es cancelar la llamada',
#  'me pasa lo mismo',
#  'queremos que la app funcione bien y sin tanto error ya viene la quincena',
#  'quieres saber de bugs en producción  rolling on the floor laughing   rolling on the floor laughing   rolling on the floor laughing ',
#  'seguridad bancolombia no brinda eso más de 15 días para devolverme 150 mil pesos que descontaron abusivamente de mi cuenta',
#  'no obliguen a la gente a abrir una cuenta para reclamar giros sucursales pereira si a alguien lo estan obligando ante quien puede poner la queja para q sancione el banco q gracias y a los lectores no usen giros bancolombia',
#  'quisieras conocer buen servicio al cliente yo te puedo ayudar',
#  'recuerda que ya no tienes que llamar a la línea telefónica para resolver tus dudas sobre la nueva app personas aquí te ayudamos a responder a todas tus preguntas ʘ˩',
#  'respuesta \u200b cualquier transacción que hagas desde app personas se validará automáticamente ya no hace falta esperar a que te notifiquen para usarla ʘ˩',
#  '¿si haces un pago desde app personas deberás esperar a recibirla por correo o mensaje de texto \u200b ʘ˩',
#  'respuesta ¡es muy fácil entra desde tu celular a app personas y en el home podrás ver los 6 dígitos sin necesidad de ingresar tu usuario o clave ʘ˩',
#  'si estás realizando un pago desde otro canal y te pide la clave dinámica ¿cómo puedes consultarla ʘ˩',
#  'qué hay una entrada específica y es por fuera del centro comercial',
#  'si señores también ando en el dm esperando a que me hablen pero tampoco',
#  'señores ya les hable por dm pero no hay respuesta',
#  'ya estoy realizando la transacción pero uds no pueden imponer más barreras especialmente para las personas de la tercera edad',
#  'señores dejen de burlarse de los usuarios ya me he comunicado con su dm pero no resuelven nada se quedan callados pareciera que el interés de ustedes es desviar la discusión que pone en evidencia lo mala empresa que son',
#  'centro comercial santa fe en la ciudad de bogotá el guarda también impide el ingreso a los acompañantes de las personas de la tercera edad es el colmo',
#  'he tenido muchos y no me interesa si cambian o no me da embarrada la gente que tiene cuenta en ese banco gracias luis',
#  'resolví mover mi cuenta de nómina a otro banco no tiene sentido tener una cuenta de ahorro en un banco y creditos en otro en bancolombia siempre ha sido un problema el tema de solicitar créditos se demoran mucho o no responden',
#  'alguna falla en la app que no deja transferir dinero',
#  'estamos llamando desde la semana pasada a la sucursal telefónica y ninguna opción es validad',
#  'mi esposa está intentando ingresar a la app pero no recuerda la clave',
#  'por favor se pueden comunicar con mi esposa 3046121174',
#  'necesitamos cambiar la clave personal',
#  'buenos días cuando dice dm que página es',
#  'quién castiga a los que se dedican al',
#  'consejo número un no ahorre en bancolombia',
#  'bancolombia lavándose las manos como siempre',
#  'su chat no sirve para nada pido asesor y finalizan el chat',
#  'esta llegando este correo lo reporte en correosospechoso@bancolombia com co y es una estafa no lo abran no den ningún dato inmediatamente lo reportan y lo eliminan',
#  'correosospechoso@bancolombia sin com co o loquesea',
#  'ahí están en las fotos',
#  'hola kevyn pude llamar a la línea de fraudes antes de hacer cualquier otra cosa y ellos me indicaron el proceso a seguir pude darme cuenta del fraude de igual forma te comparto el correo que me llegó',
#  'hola desde el viernes me estoy comunicando con ustedes mediante el chat de esta red pero los asesores que responden solo bromean conmigo no entiendo que es lo que pasa',
#  'hola pasa algo con la app de ahorro a la mano ya van varias semanas que no puedo entrar que hago',
#  'dm no entiendo srta laura',
#  'no puedo abrir mi app bancolombia a la mano que puedo hacer',
#  'tengo un cxc pendiente quiero saber que significa',
#  'hola bancolombia quisiera preguntar cuando inicia el 7 pago de ingreso solidario muchas gracias',
#  'sigo sin recibir respuesta',
#  'buenos días quería saber si está semana son los pagos del ingreso solidario por nequi y bancolombia a la mano y si son solamente los bancarizados o aquellos que no se le venían dando por giró agradezco de su información',
#  'me están cobrando un cobro de cxc retiro por cajero pero no he realizado ningún retiro no entiendo porqué este cobro gracias',
#  'listo ya se los mandé por dm',
#  ' seedling  herb  sheaf of rice ',
#  'hola yo tengo ahorro en la mano lo habri el dia vierne 9',
#  'se que este correo es falso pero miren lo que están haciendo',
#  'y ahi que procede esten pendientes de renovar esos jijueputas certificados',
#  'que beneficio me trae el cobro de cuita de manejo que me los van juntando y generando interés en la cuenta me abren un cdt o algo así comentame el “paquete de beneficios” no roben mas a la gente',
#  'cual paquete de servicios yo el único servicio que necesito es usar mi tarjeta sin que me roben mi dinero',
#  'les comparto correo que me llego hoy',
#  'mintieron no atendieron mi problema',
#  'esto fue una bola de humo no me atendieron',
#  'para que para que me sigan diciendo tienes que esperar 15 días para que el me devuelva mi dinero de verdad que mal servicio',
#  'a mi tampoco me llego el ingreso solidario desde agosto',
#  'buenos días',
#  'sigue el error pero yo mejor espero es muy temprano para oscurecer mi día gra iss feliz día',
#  '6 17min en error no se pa q dicen q escribir en dm si por ahí es q dicen no se preocupe estamos trabajando y por fuera hacen creer a todos q el problema se solucionó',
#  'se necesita promedio 40 000 000 de ahorro para cubrir todos los cobros que hace este banco',
#  'con bancolombia uno no ahorra uno pierde su capital se desvaloriza el dinero',
#  'tiemblen bancos usureros llega nubank banco sin filas sin cuota de manejo sin ningun cobro inicialmente tarjeta de crédito el futuro de bancos a favor de la gente no más bancos usureros llegó nubank',
#  'esta violando mi derecho al trabajo parece ser q esta dando referencias falsas y negativas de mi persona o no las da el sindicato antioqueño anda rabon lavaron la plata de pablito y ahora se las dan de puros y cristalino devuelvan el predio donde construyeron',
#  'rt',
#  'hola buenas noches que porcentaje manejan',
#  'si quiere que le saquen plata por todo déjelo en un banco  see-no-evil monkey ',
#  'tengo problemas para vincular mi tarjeta de crédito a paypal ¿qué puedo hacer',
#  'pongan una opción que diga menos de un mes',
#  'el viernes me envían un email dónde me informan que adjunto va la respuesta a mi reclamacion de hace mes y dió pero al asesor se le olvidó enviármela ayer mandé un mensaje y no tuve respuesta hoy llamé dos veces y me dan vueltas y no dan solución que más esperar',
#  'con esos intereses de 1 peso mensuales para qué',
#  'espero desde lo más profundo de mi corazón que cambien la app',
#  'a pesar de la resolución 0918 no me dejan movilizar mi dinero en bancolombia respeten mis derechos',
#  'lo ir',
#  'recibí un correo que simula ser de bancolombia con un enlace sospechoso ¿cómo denunciar estos intentos de fraude electrónico el correo de orígen es contacto@co bancofalabella com y el enlace remite a',
#  'y lo malo de es que tarde mas de15 días en devolver el dinero que descuenta de la cuenta de ahorro cuando el crédito hipotecario está al día bravo bancolombia',
#  'rt aún no me da solución pese al comunicado de 0918 y no me permite movilizar mi dinero no es esto una violación de los derechos civiles',
#  'dm',
#  'bancolombia yo he cobrado por modalidad de giro con ustedes en corresponsal pero hace pocos días cree el ahorro a la mano en este pago que se aproxima ya me lo pueden pagar por ahorro a la mano o sigue por giro',
#  'buenas tardes bancolombia qué fecha empiezan a pagar el 7 pago de ingreso solidario para los bancarizados gracias',
#  '12 mil y pico de pesos de manejo de una tarjeta que yo les pagué ustedes son muy hampones',
#  'por favor confirmar si esta notificación es de ustedes',
#  'ok gracias por la colaboración',
#  'srs bancolombia quisiera saber si uds saben algo de este tipo de mensajes con premios',
#  'aún no me da solución pese al comunicado de 0918 y no me permite movilizar mi dinero no es esto una violación de los derechos civiles',
#  'bancolombia no deja ahorrar con cuotas de manejo ilógicas y costos financieros impresionantes',
#  'ya me robaron no me ayudaron no veo por qué les preocupé ahora te roba en la madrugada unos genios',
#  'fui personalmente a hablar con mi ejecutivo durante meses con la gerente de la sucursal y a media noche un día cualquiera me robaron de nada sirve hablar con uds parranda de ladrones lleva el nombre de lo que es este país una mano de ratas',
#  'destina el 50 de tus ingresos para pagos básicos el 20 para ahorrar y el 30 para gustos \u200b elige un destino para tu plata puede ser una cuenta de ahorros un cdt o una inversión \u200b busca qué beneficios te da cada opción y elige ʘ˧',
#  'si eres de los que empieza a ahorrar y falla en el intento necesitas tener claro estas 3 cosas ʘ˧',
#  'cuántos billones recaudan con todos los salditos que se roban de las tarjetas banco ladrón',
#  'cómo vas a robar hoy a tus clientes',
#  'llevo dos días intentando cancelar mi tarjeta de crédito y siempre que me transfieren al área encargada me cuelgan  face with steam from nose ',
#  'cómo es eso de que me van a dar un préstamo de un millón i wanna know about it',
#  'he llamado y cuando parece q me van a ayudar me cuelgan y no me dejan ni la oportunidad de calificar el servicio',
# ...
#  'solo quiero dejar al publico la conversación con ustedes va el siguiente hilo',
#  'ya me comuniqué y dijeron que los intereses corrían si o si pero el documento firmado habla de congelar las cuotas y correr los créditos el tiempo no cobrado',
#  'cerraron una sucursal en yopal por que no se le estaba amontonando los clientes estamos en tiempo de distanciamiento social',
#  'si',
#  'como es posible que estoy haciendo un reclamo y el asesor me cuelgue cuando empiezo a nombrarle mis derechos',
#  'solo con un reclamo y le van a dar gerencia ah no así si me le quejo al que sea',
#  'se volvieron enemigos',
#  'inconforme decepción tristeza d ver una corporación de ladrones ladrones profesionales como el país lleno de corrupción',
#  'cual proceso uds no respetan ni a su madre',
#  'andan mandando estos correos como si fueran ustedes hay manera de denunciar esas cuentas',
#  'delincuentes',
#  'mentirosos dijeron que congelarian las cuotas 3 meses créditos personales y 6 micros hoy están cobrando intereses de esos meses dicen que son atrasados sin abono al capital para quedar bien',
#  'sucedió que son unos putos ladrones 14 años manteniendo mis productos con ustedes 14 años y uds trabajan a sus clientes como ladrones putos mentirosos estafadores',
#  'putos mentirosos explotadores desgraciados',
#  'no no tengo dudas pero no entiendo por qué volver a cobrar si ya probamos que no es necesario los bancos quieren ganar por todo lado podrían dar ejemplo',
#  'mi café favorito  red heart  sparkles ',
#  'hola para abrir una cuenta de ahorros necesito monto de apertura soy venezolano con pep y pasaporte vigente',
#  'que es el dm',
#  'buenas tardes me han generado un descuento de mi cuánta de ahorros de 105000 sin explicación alguna',
#  'la solución de la persona de servicio al cliente fue que llamara a poner la queja después de 2 horas el sistema si estaba lento para las quejas',
#  'pésimo servicio 2 horas y no me solucionaron absolutamente nada me van a generar cobros por errores de ustedes mismos y me hacen cobros de manejo de una tarjeta que no me han querido renovar',
#  'buenas tardes que debo hacer para cancelar una cuenta de ahorros',
#  'ya les escribí',
#  'llegó este mensaje de correo y al ingresar a la plataforma apareció error fue en mi primer intento',
#  'siempre pasa lo mismo voy a revisar una referencia bancaria y se bloquea el usuario se bloqueó al primer intento de registro será que me pueden ayudar',
#  'buenos días consulta si una persona tuvo inconvenientes con la justicia y ya no no puede abrir una cuenta de ahorros con el banco por estar en alguna lista lo consulto por qué una persona que conozco le paso ayer fue y le dijeron que no por eso',
#  'buen día me informan que sucede con la fiducuenta intento consultarla y sale un error aparte que muestra saldo en 0',
#  'voy 42 min y contando en la línea de los cuales llevo 38 escuchando música de espera que falta de respeto y cómo cuelgo si puse que quería calificar la pésima atención',
#  'no me están dando solución le repito no he autorizado ningún débito',
#  'ya lo hice y de ustedes me respondieron que es los que deben solucionar',
#  'para qué me citan al dm si me van a dejar en visto le recuerdo que me están robando 5 millones necesito solución urgente',
#  'ya lo envíe luis sería bueno notificar a banco farabella',
#  'de nada sirve tener muchos de estos pacs s pero todos haciendo lo mismo que mamera de verdad buenos días para cliente no tengo cupo bancolombia',
#  'buenos días me llegó por correo este correo de ustedes falso por favor revisarlo y mirar si pueden hacer algo para que los incautos no le roben de mi parte bloqueo estás cuentas ya no tengo cuenta con ustedes',
#  'llevo más de un mes tratando de que un papel salga con una dirección correcta ha sido imposible 8 horas perdidas al teléfono y en chats todos los asesores salen con excusas diferentes eso es ponerle el alma para aburrirlo a uno',
#  'ya fui a una oficina y me hicieron esperar 8 días para responder que no van a hacer nada',
#  'les escribí por dm',
#  'jajajajaja si vió habló el robot  face with tears of joy  face with tears of joy  face with tears of joy  face with tears of joy  face with tears of joy ',
#  'hace 1 mes solicite tarjeta de crédito y está no ha llegado y lo peor es que a mi correo ya me llegó extracto he llamado 2 veces a la línea telefónica y no me solucionan',
#  'pagué el 2 de oct mi tarjeta directamente desde el dinero al siguiente dia se veia reflejado como pagado aunque uds no me dejaban hacer uso de los fondos hoy 8 de oct me dicen que la plata no ha entrado un mov negativo me van a robar de frente',
#  'y es así como los delincuentes envían correos para engañar y robar a la gente por internet me bloquearon la cuenta que no tengo con bancolombia jajajajaja',
#  'buena aleja  rolling on the floor laughing ',
#  'lo mas charro es que estas cosas que responden uno no sabe si son un robot o qué responden por acá cada pemdejada pero en la vida real no se hablan con el banco igual no resuelven',
#  'súper déspotas las personas que trabajan en atención al cliente y lo mínimo que deberían enseñarle a los empleados es a identificarse ya que si la persona está dando información lo ideal sería poder verificarla definitivamente',
#  'definitivamente les quedó grande la app no pudieron',
#  'un asco que le quiten servicios es injusto que no se pueda hacer una compra de cartera con los servicios del banco la solución es hacer un avance en la tv para cobrar un interés más alto gmf y comisión de avance',
#  'llevo ya 3 meses esperando una respuesta esto no parece un banco sino el seguro social  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  grinning face with big eyes  grinning face with big eyes ',
#  'y para que invirtieron tanto dinero en la biometria dactilar es que acaso el se va a robar los dedos de otros que poco diligentes son en estas épocas y en todas deverdad que es el peor sistema de atención al cliente',
#  'quisiera saber cuáles es el nombre de la asesora encargada de esta línea persona grosera y altanera no deja encuentra de satisfacción y le cuelga el teléfono a uno en mitad de la llamada y cuál es la forma de poder hacer una queja a esta persona',
#  'están llegando estos correos a mi cuenta personal reviso mi app y no tengo ningún bloqueo consideró que es correo fraudulento',
#  'que tan real es este correo',
#  'ustedes ofrecen servicios de salud y para mascotas',
#  'por favor cancelen quiero cancelar mi requerimiento tomaré el servicio con otro banco',
#  'app bancolombia a ala mano no funciona y ahora con plata y sin plata manda huevo y me dijeron q mejor sacaran la de daviplata apenasa saque el dinero de bancolombia me paso a daviviend',
#  'son comunes este tipo de correos pishing que puede uno hacer frente a esto esa dirección no puede denunciarse',
#  'rt ya',
#  'ya',
#  'proceso de activación de clave dinámica en la app bastante deficiente y doloroso para el usuario en ningún lado avisan q le bloquearán la clave por 2 horas después de activarla',
#  '3198287421 este número pertenece a su empresa me llaman y saben datos de mi tarjeta de crédito',
#  'si conoces algún proyecto del sector agro o turismo rural que genere valor en su cadena productiva invítalo a postularse en la convocatoria de en campo para recibir mentorías financiación y otros beneficios para fortalecer su modelo de negocio ʘ⁞',
#  'tiempo después pude realizar la transferencia',
#  'jajajajajajajajajaja dizque hola mafaldo jajajajajajajajaja',
#  'haciendo declaraciones de renta a 80 mil pesos que piensa la no hay posturas para hacer respetar y valorar la profesión ayuda',
#  'los llame a su línea telefónica y no me dan ninguna solución inmediata y la culpa es al parecer es de ustedes que reverso el@pago a y por eso me va a suspender el servicio porque tengo que pagar doble ahora',
#  'hola este mensaje es real',
#  'este es el mensaje que me sale voy a transferir a la fidecuenta',
#  'tienen un dm',
#  'esto es lo que me sale cada vez que intento pagar una cuota de mi tarjeta de crédito cómo esperan que uno cumpla si su app falla de esta manera pero para llamar y cobrar sí son veloces',
#  'traté de hacer una transferencia y no me dejó',
#  'el séptimo pago será en este mes de octubre',
#  'no estoy solicitando nada saludos',
#  'ojo con este número que está llamando en su nombre proponiendo devoluciones de efectivo y cuantas fantasías más  thumbs up  thumbs up ',
#  'espero que me alléguen el proceso disciplinario o las medidas tomadas respeto al caso',
#  'quiero seguir manejando la clave dinámica por correo electrónico no tengo en el teléfono y tampoco quiero instalar la aplicación que pasos debo de seguir',
#  'menos mal no tengo productos con ustedes',
#  'ya hice todo eso ya hablé con 4 asesores en 2 días y nada la página no funciona que es lo que pasa',
#  'todo el día pasa así entonces no creo que esté funcionando con “normalidad”',
#  'me reporta error tiga001 al tratar de activar la tarjeta débito llevo 3 días intentando en la página',
#  'gracias ya reenvié el correo',
#  '20 minutos esperando una clave dinámica ¿la están enviando por 4 72 o qué',
#  'y que es dm',
#  'me gustaría saber si la app tiene una funcionalidad para buscar establecimientos cercanos que sean',
#  'reportando esta información que te llegó recuerda adjuntar todos los soportes te invitamos para que ingreses al siguiente enlace y conozcas más sobre seguridad que tengas una linda tarde jacke',
#  'que suplantan la imagen del banco ten presente que nosotros nunca enviamos enlaces ni solicitamos datos personales a través de estos canales te solicitamos que envíes un correo electrónico a la siguiente dirección correosospechoso@bancolombia com co',
#  'veo con preocupación que me llega un correo de phishing pero en esta ocasión me llega directamente a mi correo no a un grupo en especifico solicito que se investigue por qué mi correo personal está filtrado lo raro es q el correo desde donde lo envían es falabella',
#  'que triste saber que no se puede confiar en este banco debitan el dinero de la cuenta sin autorización un verdadero fraude solicito estudio de mi caso y devolución del dinero ya',
#  'no puedo entrar a etrading en linea porque me figura una cuenta de invesbot en vez de mi cuenta original y no puedo cambiarla',
#  'me gustaría saber que pasa con el aporte del ingreso solidario se están tirando la pelotita entre prosperidad social bancolombia y nequi lo único que quiero saber es cuál es el inconveniente',
#  'ustedes que control tienen sobre sus bases de datos me llega un correo diciendo que han bloqueado mi tarjeta que entre a un link y resultó ser un sitio inseguro hace unos días recibí una llamada dónde pretendían que les diera la fecha de vto de la tarjeta ojo',
#  'ahora me sale este error no me permite hacer ninguna transferencia ayuda',
#  'pendientes clientes quieren robar datos con un correo falso',
#  'com co com co reenvía el correo que te llegó a nuestro email correosospechoso@bancolombia com co te saluda luis',
#  'limpio pero si visualmente está saturada de cosas parece un neceser',
#  'que farsa de aplicación llevó varios días tratando de hacer un trámite y no sirve para nada nadie responde',
#  'rt estoy escribiendo al dm allí pero no obtengo respuesta  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face ',
#  'rt que moral  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face ',
#  'me están enviando información fraudulenta por favor indiquen un canal para denunciar',
#  'que moral  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face ',
#  'ya les escribí pero cómo raro sin soluciones',
#  'no me atrevo a enviar al whats app pero esto me llegó hoy no tengo productos con ese banco',
#  'llamó abancolombia a cancelar una tarjeta de crédito pues no la quiero más primero un asesor dice que no tiene línea llamó de nuevo y me dicen que sólo si verifican mi identidad la cancelan apenas me verifican dicen que no me escuchan y cuelgan',
#  'estoy escribiendo al dm allí pero no obtengo respuesta  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face  thinking face ',
#  'llamó abancolombia a cancelar una tarjeta de crédito pues no la quiero más primero un asesoró dice que no tiene línea llamó de nuevo y me dicen que sólo si verifican mi identidad la cancelan apenas me verifican dicen que no me escuchan y cuelgan',
#  'para consignaren no se puede entrar al banco te obligan a salir a la fila de la peatonal por una ficha para entrar a la misma puerta del banco donde estaba al llegar donde esta la seguridad',
#  'respetuosamente les reporto ataques cibernéticos con suplantación de la razón social de bancolombia',
#  'rt buen día cuando será que me colaboran con la refinanciación de mi producto ya llevo 3 meses rogándoles y no han querido gestionarme unas cuotas que yo pueda pagar  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  todas las veces que me llaman dicen que aún no sale la respuesta',
#  'buen día cuando será que me colaboran con la refinanciación de mi producto ya llevo 3 meses rogándoles y no han querido gestionarme unas cuotas que yo pueda pagar  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  pouting face  todas las veces que me llaman dicen que aún no sale la respuesta',
#  'señores no es que no sepa cómo usarla lo sé y la uso el problema es que es un enredo demasiados pasos para una información muy visual y poco útil demasiada información inútil demasiados pasos para una transacción sencilla la anterior era más sencilla',
#  'bancolombia que sucede con las transferencias internacionales desde ayer estoy tratando y nada es urgente',
#  'eso es lo q nose',
#  'acabo de llamar y me dicen que tienen incidencias en el sistema que ni para poner la queja les sirve este banco es inservible',
#  'mientras los clientes que se defiendan como puedan increíble',
#  'estoy en bogotá entonces no hay pico y cédula estoy en lo correcto',
#  'buen día sebastián ya mire en la página de ingreso y si soy beneficiario como pasó al dm gracias',
#  'como es eso q los giros los hicieron entre el 29 y 30 de sept yo estuve en pendiente y me decían q no habían autozado los pagos',
#  'buenos días el mismo día respondí las preguntas favor revisar']

# %%
len(new_text)
# Out:
# 731

# %%
base = pd.DataFrame(new_text, columns=["tweets"])

# %%
base.to_excel('test.xlsx')

# %% [markdown]
# ## NLP

# %%
import spacy
from spacy import displacy
spacy.load('es_core_news_md')

# %%
nlp = spacy.load('es_core_news_md') #Corpus para análisis y procesamiento

# %%
text = "Hay un gato en la casa. Hay una naranja en la nevera. Esta es una tercera frase"

# %%
orac = nlp.create_pipe('sentencizer')

# %%
nlp.add_pipe(orac, before='parser')

# %%
doc = nlp(text)

# %%
for orac in doc.sents:
    print(orac)
# Out:
# Hay un gato en la casa.
# Hay una naranja en la nevera.
# Esta es una tercera frase

# %%
#Stop Words de es_core_news_sm
from spacy.lang.es.stop_words import STOP_WORDS
stopwords_spacy = list(STOP_WORDS)
print(stopwords_spacy)
len(stopwords_spacy)
# Out:
# ['actualmente', 'dijo', 'quizas', 'creo', 'tengo', 'mí', 'ciertas', 'junto', 'diferentes', 'quizás', 'último', 'detrás', 'esa', 'estoy', 'hacia', 'podrán', 'quiere', 'esos', 'últimas', 'enseguida', 'dio', 'mías', 'los', 'aproximadamente', 'modo', 'éstos', 'puedo', 'despues', 'dias', 'raras', 'tan', 'muchos', 'debido', 'decir', 'consiguen', 'debajo', 'poco', 'era', 'mediante', 'mio', 'mayor', 'una', 'trabajo', 'tuyos', 'grandes', 'tuyo', 'deprisa', 'tendrán', 'le', 'cuál', 'parece', 'verdad', 'tu', 'empleais', 'total', 'dejó', 'hicieron', 'luego', 'conocer', 'trabajamos', 'general', 'tenía', 'estaban', 'dieron', 'fuera', 'eras', 'quien', 'lado', 'consigue', 'excepto', 'ninguno', 'quiza', 'medio', 'aquélla', 'cierto', 'ocho', 'estado', 'ejemplo', 'existen', 'sabemos', 'sigue', 'mia', 'solas', 'dado', 'esas', 'eramos', 'haber', 'agregó', 'delante', 'hubo', 'cuantos', 'desde', 'ustedes', 'pues', 'ante', 'algunos', 'estamos', 'incluso', 'todas', 'otros', 'cinco', 'asi', 'la', 'hay', 'ellos', 'señaló', 'ultimo', 'mal', 'tarde', 'misma', 'cuanto', 'pasado', 'poner', 'consideró', 'un', 'alguno', 'están', 'proximo', 'habrá', 'sus', 'intentar', 'solos', 'afirmó', 'mía', 'todavía', 'contra', 'respecto', 'mas', 'encima', 'cuántas', 'aún', 'usted', 'verdadero', 'ello', 'trabajan', 'emplear', 'peor', 'antano', 'sí', 'mias', 'realizado', 'alguna', 'temprano', 'ningún', 'soy', 'tampoco', 'menos', 'nosotros', 'informo', 'eso', 'mucha', 'os', 'poca', 'ti', 'todo', 'tiene', 'próximo', 'aquéllos', 'sois', 'antaño', 'demás', 'añadió', 'intentas', 'valor', 'saben', 'lejos', 'usas', 'nuestra', 'trata', 'otra', 'podemos', 'ésa', 'claro', 'quedó', 'estuvo', 'son', 'acuerdo', 'intenta', 'pronto', 'hizo', 'haceis', 'quizá', 'serán', 'tendrá', 'con', 'aquél', 'ambos', 'trabajas', 'aseguró', 'segunda', 'mucho', 'más', 'siete', 'gueno', 'alrededor', 'ampleamos', 'nada', 'según', 'cada', 'cierta', 'pueda', 'hoy', 'lo', 'usar', 'considera', 'hace', 'paìs', 'hacemos', 'tuyas', 'vuestros', 'propios', 'este', 'gran', 'podría', 'pais', 'esta', 'bastante', 'parte', 'aquellas', 'arriba', 'cosas', 'será', 'aquellos', 'eres', 'pasada', 'aqui', 'primero', 'aquel', 'donde', 'somos', 'sea', 'poder', 'ha', 'allí', 'tenido', 'tus', 'del', 'adelante', 'ésta', 'lugar', 'pueden', 'explicó', 'tú', 'vuestras', 'mientras', 'hacer', 'nos', 'ese', 'teneis', 'así', 'menudo', 'pero', 'las', 'cual', 'dan', 'tuya', 'vosotras', 'propia', 'cuánto', 'tambien', 'cuatro', 'ex', 'haces', 'despacio', 'dicho', 'anterior', 'estados', 'dia', 'detras', 'manifestó', 'fin', 'sólo', 'mío', 'nueva', 'esto', 'dijeron', 'tienen', 'de', 'mi', 'ahi', 'conseguimos', 'nuestras', 'cualquier', 'unos', 'emplean', 'lleva', 'propio', 'atras', 'estará', 'voy', 'diferente', 'sabe', 'da', 'podeis', 'apenas', 'conseguir', 'si', 'estaba', 'sido', 'ayer', 'cuenta', 'vuestra', 'tras', 'solo', 'podriamos', 'dos', 'arribaabajo', 'mis', 'empleo', 'siguiente', 'verdadera', 'estais', 'unas', 'aunque', 'van', 'ningunas', 'hacerlo', 'breve', 'hago', 'en', 'otras', 'encuentra', 'enfrente', 'aquello', 'ésos', 'mismo', 'aquéllas', 'informó', 'nuestros', 'dar', 'uno', 'primera', 'bien', 'alli', 'también', 'podrá', 'ser', 'está', 'primer', 'igual', 'sabeis', 'nuevas', 'usan', 'he', 'todavia', 'algún', 'además', 'salvo', 'por', 'principalmente', 'ya', 'deben', 'horas', 'dentro', 'eran', 'últimos', 'mencionó', 'seis', 'vais', 'varias', 'quién', 'estos', 'buen', 'hemos', 'queremos', 'muchas', 'buenos', 'han', 'ir', 'dónde', 'tener', 'dicen', 'pudo', 'haya', 'algo', 'vez', 'bueno', 'partir', 'puede', 'usais', 'muy', 'sabes', 'cuánta', 'vamos', 'al', 'suya', 'saber', 'aun', 'segundo', 'ninguna', 'ellas', 'primeros', 'podrían', 'tanto', 'había', 'consigo', 'estan', 'sera', 'siempre', 'va', 'sola', 'hacen', 'otro', 'quiénes', 'solamente', 'mismos', 'míos', 'mios', 'podria', 'podrias', 'propias', 'trabajais', 'habia', 'pesar', 'tiempo', 'hecho', 'haciendo', 'supuesto', 'ése', 'intentais', 'mejor', 'nunca', 'mismas', 'fueron', 'repente ...
# 551

# %%
for token in doc:
    if token.is_stop == False:
        print(token)
# Out:
# gato
# casa
# .
# naranja
# nevera
# .
# frase

# %%
import re, string 
import pandas as pd 
import numpy as np
from time import time  
import re, itertools, random
from collections import defaultdict
import spacy
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.decomposition import TruncatedSVD
from nltk.corpus import stopwords
STOPWORDS = set(stopwords.words('spanish'))
from gensim.models import Word2Vec
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style("darkgrid")
from scipy.spatial.distance import cdist
spacy.load('es_core_news_md')
nlp = spacy.load('es_core_news_md') # disabling Named Entity Recognition for speed

# %%
df = pd.read_excel("Bancolombia.xlsx",sheet_name="Archive") # Importing the database (tweets)

# %%
df.head(10)
# Out:
#                 id_str        from_user  \
# 0  1316907621371314176    Mimi_UVasquez
# 1  1316906522295869445        fredysend
# 2  1316905865040068609   LuchoCandanoza
# 3  1316902640786300930    Mimi_UVasquez
# 4  1316854660121219073      betoacevedo
# 5  1316854329463189505  midasmckalister
# 6  1316854212601491457       redactor24
# 7  1316854111330086914     todoparati23
# 8  1316853604976939008      Bancolombia
# 9  1316853482960322560        JehanAliC
#
#                                                 text  \
# 0  @Bancolombia El ya radicó la queja, lo que hag...
# 1  @Bancolombia Ya no pudieron eso es de hace muc...
# 2                       @Bancolombia @jose_caicedo10
# 3  @Bancolombia varios amigos me reportan que la ...
# 4  RT @CAMT_1_4: @Bancolombia @OracleLatam  encon...
# 5  @Bancolombia Señores @Bancolombia llevan dañad...
# 6  @Bancolombia: paren ya su ACOSO. Ya les dije q...
# 7  @Bancolombia Por que mi tarjeta débito no tien...
# 8  Creemos más que nunca en su fortaleza y querem...
# 9  @Bancolombia y su mundo digital: Para facilita...
#
#                        created_at                time  geo_coordinates  \
# 0  Fri Oct 16 01:03:38 +0000 2020 2020-10-16 02:03:38              NaN
# 1  Fri Oct 16 00:59:16 +0000 2020 2020-10-16 01:59:16              NaN
# 2  Fri Oct 16 00:56:39 +0000 2020 2020-10-16 01:56:39              NaN
# 3  Fri Oct 16 00:43:51 +0000 2020 2020-10-16 01:43:51              NaN
# 4  Thu Oct 15 21:33:11 +0000 2020 2020-10-15 22:33:11              NaN
# 5  Thu Oct 15 21:31:52 +0000 2020 2020-10-15 22:31:52              NaN
# 6  Thu Oct 15 21:31:24 +0000 2020 2020-10-15 22:31:24              NaN
# 7  Thu Oct 15 21:31:00 +0000 2020 2020-10-15 22:31:00              NaN
# 8  Thu Oct 15 21:29:00 +0000 2020 2020-10-15 22:29:00              NaN
# 9  Thu Oct 15 21:28:30 +0000 2020 2020-10-15 22:28:30              NaN
#
#    user_lang  in_reply_to_user_id_str in_reply_to_screen_name  \
# 0        NaN               48014813.0             Bancolombia
# 1        NaN               48014813.0             Bancolombia
# 2        NaN               48014813.0             Bancolombia
# 3        NaN               48014813.0             Bancolombia
# 4        NaN                      NaN                     NaN
# 5        NaN               48014813.0             Bancolombia
# 6        NaN               48014813.0             Bancolombia
# 7        NaN               48014813.0             Bancolombia
# 8        NaN               48014813.0             Bancolombia
# 9        NaN               48014813.0             Bancolombia
#
#       from_user_id_str  in_reply_to_status_id_str  \
# 0            330669613               1.316907e+18
# 1            517679766               1.316900e+18
# 2            109031390               1.316008e+18
# 3            330669613                        NaN
# 4             70786127                        NaN
# 5            160555883               1.316853e+18
# 6  1306314646941560834                        NaN
# 7            169547950               1.068158e+18
# 8             48014813               1.316854e+18
# 9            346335302                        NaN
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/android" ...
# 4  <a href="http://twitter.com/download/iphone" r...
# 5  <a href="http://twitter.com/download/android" ...
# 6  <a href="https://mobile.twitter.com" rel="nofo...
# 7  <a href="https://mobile.twitter.com" rel="nofo...
# 8  <a href="https://mobile.twitter.com" rel="nofo...
# 9  <a href="http://twitter.com/download/iphone" r...
#
#                                    profile_image_url  user_followers_count  \
# 0  http://pbs.twimg.com/profile_images/1299536154...                3906.0
# 1  http://pbs.twimg.com/profile_images/8776703045...                  23.0
# 2  http://pbs.twimg.com/profile_images/1280200494...                 116.0
# 3  http://pbs.twimg.com/profile_images/1299536154...                3906.0
# 4  http://pbs.twimg.com/profile_images/6193437655...                 120.0
# 5  http://pbs.twimg.com/profile_images/1303370627...                1969.0
# 6  http://pbs.twimg.com/profile_images/1306315112...                   8.0
# 7  http://pbs.twimg.com/profile_images/1226129925...                  62.0
# 8  http://pbs.twimg.com/profile_images/1278077511...              349714.0
# 9  http://pbs.twimg.com/profile_images/9158856197...                 487.0
#
#    user_friends_count                user_location  \
# 0              1104.0                    Ravenclaw
# 1               131.0                          NaN
# 2               539.0                          NaN
# 3              1104.0                    Ravenclaw
# 4               188.0                       Bogota
# 5              4327.0          La Calera, Colombia
# 6                86.0                     Colombia
# 7               293.0                      Bogotá
# 8             48612.0  Todos los días 6 am - 10 pm
# 9              1447.0                       Bogota
#
#                                           status_url  \
# 0  http://twitter.com/Mimi_UVasquez/statuses/1316...
# 1  http://twitter.com/fredysend/statuses/13169065...
# 2  http://twitter.com/LuchoCandanoza/statuses/131...
# 3  http://twitter.com/Mimi_UVasquez/statuses/1316...
# 4  http://twitter.com/betoacevedo/statuses/131685...
# 5  http://twitter.com/midasmckalister/statuses/13...
# 6  http://twitter.com/redactor24/statuses/1316854...
# 7  http://twitter.com/todoparati23/statuses/13168...
# 8  http://twitter.com/Bancolombia/statuses/131685...
# 9  http://twitter.com/JehanAliC/statuses/13168534...
#
#                                         entities_str
# 0  {"hashtags":[],"symbols":[],"user_mentions":[{...
# 1  {"hashtags":[],"symbols":[],"user_mentions":[{...
# 2  {"hashtags":[],"symbols":[],"user_mentions":[{...
# 3  {"hashtags":[],"symbols":[],"user_mentions":[{...
# 4  {"hashtags":[],"symbols":[],"user_mentions":[{...
# 5  {"hashtags":[],"symbols":[],"user_mentions":[{...
# 6  {"hashtags":[],"symbols":[],"user_mentions":[{...
# 7  {"hashtags":[],"symbols":[],"user_mentions":[{...
# 8  {"hashtags":[],"symbols":[],"user_mentions":[]...
# 9  {"hashtags":[{"text":"FelizJueves","indices":[...

# %%
def remove_emoji(string):
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               u"\U00002500-\U00002BEF"  # chinese char
                               u"\U00002702-\U000027B0"
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               u"\U0001f926-\U0001f937"
                               u"\U00010000-\U0010ffff"
                               u"\u2640-\u2642"
                               u"\u2600-\u2B55"
                               u"\u200d"
                               u"\u23cf"
                               u"\u23e9"
                               u"\u231a"
                               u"\ufe0f"  # dingbats
                               u"\u3030"
                               "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', string)

df_clean = pd.DataFrame(df.text.apply(lambda x: remove_emoji(x)))
df_clean = df_clean.dropna()
df_clean = df_clean.reset_index(drop=True)

# %%
df_clean.head(100)

# %%
def clean_text(text):
    '''Make text lowercase, remove text in square brackets, remove punctuation and remove words containing numbers.'''
    if text is None:
        return ''
    text = str(text).replace("nan",'').lower()
    text = re.sub(r'\[.*?\]', '', text)
    text = re.sub(r'[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub(r'\w*\d\w*', '', text)
    text = re.sub(r'rt', '', text)
    # Remove a sentence if it is only one word long
    if len(text) >= 2:
        return ' '.join(word for word in text.split() if word not in STOPWORDS)

df_clean = pd.DataFrame(df.text.apply(lambda x: clean_text(x)))
df_clean = df_clean.dropna()
df_clean = df_clean.reset_index(drop=True)

# %%
df_clean.head(10)
# Out:
#                                                 text
# 0  bancolombia radicó queja hago avisar amigos re...
# 1  bancolombia pudieron hace tiempo toco llevarno...
# 2                                        bancolombia
# 3  bancolombia varios amigos repoan actualización...
# 4  bancolombia oraclelatam encontré sorpresa impl...
# 5  bancolombia señores bancolombia llevan dañados...
# 6  bancolombia paren acoso dije interesa cupo cré...
# 7                     bancolombia tarjeta débito cvv
# 8  creemos nunca foaleza queremos acompañarlas co...
# 9  bancolombia mundo digital facilitar trámite im...

# %%
def lemmatizer(text):        
    sent = []
    doc = nlp(text)
    for word in doc:
        sent.append(word.lemma_)
    return " ".join(sent)

df_clean["text_lemmatize"] = df_clean.apply(lambda x: lemmatizer(x['tweet']), axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-f1259505b55c> in <module>
#       6     return " ".join(sent)
#       7
# ----> 8 df_clean["text_lemmatize"] = df_clean.apply(lambda x: lemmatizer(x['tweet']), axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in f(x)
#    3831
#    3832             def f(x):
# -> 3833                 return func(x, *args, **kwds)
#    3834
#    3835         else:
#
# TypeError: <lambda>() got an unexpected keyword argument 'axis'

# %%
df_clean.head(100)
# Out:
#                                                  text  \
# 0   bancolombia radicó queja hago avisar amigos re...
# 1   bancolombia pudieron hace tiempo toco llevarno...
# 2                                         bancolombia
# 3   bancolombia varios amigos repoan actualización...
# 4   bancolombia oraclelatam encontré sorpresa impl...
# ..                                                ...
# 95  bancolombia puse quejas respondieron podían re...
# 96                   bancolombia camiiblanco chiste 😂
# 97  bancolombia publicidad dice app conveiría empl...
# 98         bancolombia hola inconveniente solucionado
# 99                          bancolombia poniendo alma
#
#                                        text_lemmatize
# 0   bancolombia radicar quejar hacer avisar amigo ...
# 1   bancolombia poder hacer tiempo tocar llevarnos...
# 2                                         bancolombia
# 3   bancolombia vario amigo repoan actualización a...
# 4   bancolombia oraclelatam encontrar sorpresa imp...
# ..                                                ...
# 95  bancolombia poner quejar responder poder respo...
# 96                  bancolombia camiiblanco chistar 😂
# 97  bancolombia publicidad decir app conveiría emp...
# 98          bancolombia hola inconveniente solucionar
# 99                             bancolombia poner alma
#
# [100 rows x 2 columns]
